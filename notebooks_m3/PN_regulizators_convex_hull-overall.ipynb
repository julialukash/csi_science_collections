# %% [markdown]
# no reg:
#
# |     |                                  	| 0.2 	| 0.4 	| 0.6 	| 0.8 	|
# |:---:|:--------------------------------:	|:---:	|:---:	|:---:	|:---:	|
# |**20**| 20, 0.66                           |   124  |  .71  |  .79  | -+++- |
# |     |  closest by dist test/original   	|   0 	|  jh2  |  jh4  | jh20  |
# |     |   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
# |     | closest by opt res test/original 	|    	|h20(0.375)|   	|   	|
# |     | closest by opt res original/test 	|     	|   	|   	| h18 	|
# |**50**| 50, 0.77                           |   48  |  .68  |  .80  | -++++ |
# |     |   closestby dist test/original   	|   0	| j8-h12|j30-h49| jh50 	|
# |     |   closest by dist original/test  	|   0	| j6-h12|j31-h48| jh50 	|
# |     | closest by opt res test/original 	|    	|  h46 	|  h50 	|   	|
# |     | closest by opt res original/test 	|  - 	|  h6 	|  h28	|  h48 	|
# |**100**| 99, 0.83                           |   24  |  .68  |  .79  | --+-+ |
# |     |   closestby dist test/original   	| j12-h5|j58-h74|j81-h89|j83-h90|
# |     |   closest by dist original/test  	| j12-h4|j58-h75|j81-h90|j83-h91|
# |     | closest by opt res test/original 	|  h4  	|  h84 	|  h94 	| h100 	|
# |     | closest by opt res original/test 	|  h4 	|  h78 	|  h92	| h100 	|
# |**150**| 135, 0.85                           |   18  |  .63  |  .74  | --+-- |
# |     |   closestby dist test/original   	| j18-h4|j72-h94|j92-h98|j94-h100|
# |     |   closest by dist original/test  	| j18-h6|   -   |   -   |  -    |
# |     | closest by opt res test/original 	|  h4 	|  h72 	|  h82 	| h100 	|
# |     | closest by opt res original/test 	|  h12 	|  h92 	|  h98	| h100 	|
# |**200**| 173, 0.84                           |   14  |  .57  |  .69  | --+-- |
# |     |   closestby dist test/original   	|  j20 	|j78-h92|j94-h99|j94-h100|
# |     |   closest by dist original/test  	|  j18	|j75-h90|j98-h100|j98-h100|
# |     | closest by opt res test/original 	|    	|  h58 	|  h70 	| h100 	|
# |     | closest by opt res original/test 	|  h10	|  h98  |  h100 |    	|
# |**250**| 201, 0.84                           |   12  |  .56  |  .65  | --+-- |
# |     |   closestby dist test/original   	|  j20  |j74-h92|j94-h99|j95-h100|
# |     |   closest by dist original/test  	|  j24	|j75-h92|j92-h98|j98-h100|
# |     | closest by opt res test/original 	|  h2  	|  h50 	|  h64  |  h97   |
# |     | closest by opt res original/test 	|  h10 	|  h100	|   	|    	|
# |**300**| 236, 0.85                           |   10  |  .55  |  .63  | --+-- |
# |     |   closestby dist test/original   	|  j20 	|j76-h84|j97-h98|j98-h100|
# |     |   closest by dist original/test  	|  -	|   -  	|   - 	|   -  	|
# |     | closest by opt res test/original 	|  h2  	|  h38 	|  h62 	|  h92 	|
# |     | closest by opt res original/test 	|  h10 	|  h98 	| h100	|    	|
# |**350**| 265, 0.85                           |   9  |  .53  |  .59  | --+-- |
# |     |   closestby dist test/original   	|  j19 	|j78-h92|  jh98 | jh100 |
# |     |   closest by dist original/test  	|  j20	|   -   |   - 	|  -  	|
# |     | closest by opt res test/original 	|    	|  h40 	|  h62 	|  h94 	|
# |     | closest by opt res original/test 	|  h20	| h100 	|   -	|    	|
# |**400**| 292, 0.85                           |   9  |  .49  |  .56  | ----- |
# |     |   closestby dist test/original   	|  22 	|j74-h84|j98-h100|    	|
# |     |   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
# |     | closest by opt res test/original 	|   0  	|  h36 	|  h56 	|  h90 	|
# |     | closest by opt res original/test 	|  h15 	|  h98 	|  h100	|    	||
#
# ### best
# best_by_dist test/original
#
# |     |                                  	| 0.2 	| 0.4 	| 0.6 	| 0.8 	|
# |:---:|:--------------------------------:	|:---:	|:---:	|:---:	|:---:	|
# |**150**| 135, 0.85                           |   18  |  .63  |  .74  | --+-- |
# |     |   closestby dist test/original   	| j18-h4|j72-h94|j92-h98|j94-h100|
# |     |   closest by dist original/test  	| j18-h6|   -   |   -   |  -    |
# |     | closest by opt res test/original 	|  h4 	|  h72 	|  h82 	| h100 	|
# |     | closest by opt res original/test 	|  h12 	|  h92 	|  h98	| h100 	|
# best_by_opt test/original
#
#
# |     |                                  	| 0.2 	| 0.4 	| 0.6 	| 0.8 	|
# |:---:|:--------------------------------:	|:---:	|:---:	|:---:	|:---:	|
# |**100**| 99, 0.83                           |   24  |  .68  |  .79  | --+-+ |
# |     |   closestby dist test/original   	| j12-h5|j58-h74|j81-h89|j83-h90|
# |     |   closest by dist original/test  	| j12-h4|j58-h75|j81-h90|j83-h91|
# |     | closest by opt res test/original 	|  h4  	|  h84 	|  h94 	| h100 	|
# |     | closest by opt res original/test 	|  h4 	|  h78 	|  h92	| h100 	|
# best_by_opt original/test
#
# |     |                                  	| 0.2 	| 0.4 	| 0.6 	| 0.8 	|
# |:---:|:--------------------------------:	|:---:	|:---:	|:---:	|:---:	|
# |**200**| 173, 0.84                           |   14  |  .57  |  .69  | --+-- |
# |     |   closestby dist test/original   	|  j20 	|j78-h92|j94-h99|j94-h100|
# |     |   closest by dist original/test  	|  j18	|j75-h90|j98-h100|j98-h100|
# |     | closest by opt res test/original 	|    	|  h58 	|  h70 	| h100 	|
# |     | closest by opt res original/test 	|  h10	|  h98  |  h100 |    	||
# 250 - h100

# %% [markdown]
# ### no reg
# * best by dist test/original  48 64; 58 70; 55 70;
#
#
# |                                  	| 0.2 	| 0.4 	| 0.6 	| 0.8 	|
# |:---------------------------------------------:	|:---:	|:---:	|:---:	|:---:	|
# | (; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)	|    |    |    |  |
# | 150 -> 129, 0.98 | 24 vs 17 | .63 vs .63	| .78 vs .79 | --+-- |
# |closest by dist test/original	| j10 | j50-h70	| j90-h96|	||
#
# * best by dist original/test  см. пред.
# * best by opt original/test 72; 55; 62
#
# |                                  	| 0.2 	| 0.4 	| 0.6 	| 0.8 	|
# |:---------------------------------------------:	|:---:	|:---:	|:---:	|:---:	|
# | (; 5) (ts 0.5 -1.5 -1.5; 25)	|    |    |    |  |
# | 100 -> 96, 0.96 | 24 vs 23 | .63 vs .56	| .78 vs .80 | +++++ |
# |closest by opt res original/test	| - | h72	| h90 | h98	||
# * best by opt test/original 64; 82; 90
#
# |                                  	| 0.2 	| 0.4 	| 0.6 	| 0.8 	|
# |:---------------------------------------------:	|:---:	|:---:	|:---:	|:---:	|
# | (; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)	|    |    |    |  |
# | 200 -> 161, 0.98 | 24 vs 14 | .63 vs .54	| .78 vs .74 | --+-- |
# |closest by opt res original/test	| - | h90	| h98 |	||

# %% [markdown]
# **Немного про оригинальные phi**:
#
#
# **Выводы:**
# * по близости между test темами можно сказать, что они ближе, чем оригинальные (при пороге 0.4-0.6 уже есть пару очень близких -> при запуске build convex hull на phi_test некоторые отфильтруются (вопрос, TODO check:: а не ухудшится ли из-за этого smth to original, по идее не должны, так как original довольно-таки разные темы)
# * best by dist to test/original: (150; no reg; 0.4: j72-h94), (150; dec+ts; 0.4: j50-h70)
# * best by opt to test/original: (100; no reg; 0.4: h84), (100; ts; 0.4: h72)
# * best by opt to original/test: (200; no reg; 0.4: h98), (200; dec+ts; 0.4: h90)
# * по всем показателям без регуляризаторов лучше, чем с ними. Не удалось подобрать регуляризатора, который был лучше бы чем без (при фиксированном числе тем)
# * в целом при 0.4 неплохие результаты, находит много тем, + лучше брать много тем и уменьшать их
# * no reg: по dist - при увеличении числа тем, находит всё больше тем, после достижения **150** начинает уменьшаться
# * reg: если сначала обучать без reg - результат лучше

# %%
df_100
# Out:
#                                                            0.2           0.4  \
# () (dec 1.5 -1.5 -1.5; 25) ()                                -             -
# 100 -> 98, 0.98                                     : 24 vs 14  : .63 vs .64
# closest by dist test/original                                0           j20
# closest by dist original/test                                              -
# closest by opt res test/original                                         h22
# closest by opt res original/test                                           -
# (; 5) (dec 3 -1.5 -1.5; 25) ()                               -             -
# 100 -> 99, 0.97                                     : 24 vs 22  : .63 vs .61
# closest by dist test/original                              j10       j40-h60
# closest by dist original/test                                -             -
# closest by opt res test/original                                         h64
# ...

# %%
df_150
# Out:
#                                                            0.2           0.4  \
# () (dec 1.5 -1.5 -1.5; 25) ()                                -             -
# * 150 -> 119, 0.98                                  : 24 vs 10  : .63 vs .57
# closestby dist test/original                              < h5       j12-h10
# closest by dist original/test                                -             -
# closest by opt res test/original                             0           h10
# closest by opt res original/test                             -             -
# (; 5) (dec 3 -1.5 -1.5; 25) ()                               -             -
# * 150 -> 144, 0.98                                  : 24 vs 15  : .63 vs .51
# closestby dist test/original                             < j10       j55-h65
# closest by dist original/test                                -             -
# closest by opt res test/original                             0           h50
# ...

# %%
df_200
# Out:
#                                                            0.2           0.4  \
# () (dec 1.5 -1.5 -1.5; 25) ()                                -             -
# * 200 -> 106, 0.98                                   : 24 vs 9  : .63 vs .55
# closestby dist test/original                                j3         j5-h4
# closest by dist original/test                                -             -
# closest by opt res test/original                             0            h5
# closest by opt res original/test                             -           h10
# (; 5) (dec 3 -1.5 -1.5; 25) ()                               -             -
# * 200 -> 172, 0.98                                  : 24 vs 13  : .63 vs .46
# closestby dist test/original                               j15       j50-h60
# closest by dist original/test                                -             -
# closest by opt res test/original                             0           h42
# ...

# %%
import pandas as pd
def lines_to_df(lines, first_index, second_index, second_line):
    lines = [[val.strip() for val in line.split("|") if len(val) > 1] for line in lines.split("\n") if len(line) > 1]
    df = pd.DataFrame(0, columns=[0.2, 0.4, 0.6, 0.8], index = [])
    df.loc[first_index, :] = ['-','-','-','-']
    df.loc[second_index, :] = get_first_line(second_line)
    for line in lines:
        df.loc[line[0], :] = line[1:5]
    return df
def get_first_line(first_line):
    return [[w for w in val.split('**')][-1].strip() for val in first_line.split(',')]

pd.options.display.max_rows = 999
df_list = []

# %% [markdown]
# # 100

# %%
first_index = '() (dec 1.5 -1.5 -1.5; 25) ()'
second_index = '100 -> 98, 0.98'
second_line =  '* **kernel size**: 24 vs 14, **purity**: .63 vs .64, **contrast** .78 vs .80, **$phi_{ij}$**: похожи '
lines = """
|  closest by dist test/original   	|   0  	|  j20 	|j60-h70| jh84 	|
|   closest by dist original/test  	|     	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|     	|  h22 	|  h74 	|  h96 	|
| closest by opt res original/test 	|     	|   - 	|  h72 	|  h90 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# () (dec 1.5 -1.5 -1.5; 25) ()              -             -           -
# 100 -> 98, 0.98                   : 24 vs 14  : .63 vs .64  .78 vs .80
# closest by dist test/original              0           j20     j60-h70
# closest by dist original/test                            -           -
# closest by opt res test/original                       h22         h74
# closest by opt res original/test                         -         h72
#
#                                        0.8
# () (dec 1.5 -1.5 -1.5; 25) ()            -
# 100 -> 98, 0.98                   : похожи
# closest by dist test/original         jh84
# closest by dist original/test            -
# closest by opt res test/original       h96
# closest by opt res original/test       h90

# %%
first_index = '(; 5) (dec 3 -1.5 -1.5; 25) ()'
second_index = '100 -> 99, 0.97'
second_line =  '* **kernel size**: 24 vs 22, **purity**: .63 vs .61, **contrast** .78 vs .80, **$phi_{ij}$**:  похожи'
lines = """
|  closest by dist test/original   	|  j10 	|j40-h60|j80-h86| jh84 	|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|     	|  h64 	|  h90 	|  h98 	|
| closest by opt res original/test 	|     	|  h60 	|  h90 	| h100 	|

"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (dec 3 -1.5 -1.5; 25) ()             -             -           -
# 100 -> 99, 0.97                   : 24 vs 22  : .63 vs .61  .78 vs .80
# closest by dist test/original            j10       j40-h60     j80-h86
# closest by dist original/test              -             -           -
# closest by opt res test/original                       h64         h90
# closest by opt res original/test                       h60         h90
#
#                                         0.8
# (; 5) (dec 3 -1.5 -1.5; 25) ()            -
# 100 -> 99, 0.97                   :  похожи
# closest by dist test/original          jh84
# closest by dist original/test             -
# closest by opt res test/original        h98
# closest by opt res original/test       h100

# %%
first_index = '(; 5) (dec 6 -1.5 -1.5; 25) ()'
second_index = '* 100 -> 99, 0.97'
second_line =  '* **kernel size**: 24 vs 22, **purity**: .63 vs .61, **contrast** .78 vs .80, **$phi_{ij}$**: похожи '
lines = """
|  closest by dist test/original   	|  j10 	|j40-h60|j80-h84| jh85 	|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|     	|  h68 	|  h90 	|  h98 	|
| closest by opt res original/test 	|     	|  h60 	|  h90 	| h100 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (dec 6 -1.5 -1.5; 25) ()             -             -           -
# * 100 -> 99, 0.97                 : 24 vs 22  : .63 vs .61  .78 vs .80
# closest by dist test/original            j10       j40-h60     j80-h84
# closest by dist original/test              -             -           -
# closest by opt res test/original                       h68         h90
# closest by opt res original/test                       h60         h90
#
#                                        0.8
# (; 5) (dec 6 -1.5 -1.5; 25) ()           -
# * 100 -> 99, 0.97                 : похожи
# closest by dist test/original         jh85
# closest by dist original/test            -
# closest by opt res test/original       h98
# closest by opt res original/test      h100

# %%
first_index = '() (dec 6 -1.5 -1.5; 25) ()'
second_index = '* 100 -> 98, 0.98'
second_line =  '* **kernel size**: 24 vs 14, **purity**: .63 vs .64, **contrast** .78 vs .80, **$phi_{ij}$**: похожи'
lines = """
|  closest by dist test/original   	|  j10 	|j20-h18|j60-h72| jh82 	|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|     	|  h22 	|  h74 	|  h96 	|
| closest by opt res original/test 	|     	|  h22 	|  h72 	| h90 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# () (dec 6 -1.5 -1.5; 25) ()                -             -           -
# * 100 -> 98, 0.98                 : 24 vs 14  : .63 vs .64  .78 vs .80
# closest by dist test/original            j10       j20-h18     j60-h72
# closest by dist original/test              -             -           -
# closest by opt res test/original                       h22         h74
# closest by opt res original/test                       h22         h72
#
#                                        0.8
# () (dec 6 -1.5 -1.5; 25) ()              -
# * 100 -> 98, 0.98                 : похожи
# closest by dist test/original         jh82
# closest by dist original/test            -
# closest by opt res test/original       h96
# closest by opt res original/test       h90

# %%
first_index = '() (ts 0.1 -1.5 -1.5; 25) ()'
second_index = '* 100 -> 94, 0.98'
second_line =  '* **kernel size**: 24 vs 15, **purity**: .63 vs .61, **contrast** .78 vs .78, **$phi_{ij}$**: --+--'
lines = """
|  closest by dist test/original   	|  j2 	|j20-h10|j50-h64| jh80 	|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|     	|  h16 	|  h74 	|  h90 	|
| closest by opt res original/test 	|     	|  h18 	|  h62 	| h90 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# () (ts 0.1 -1.5 -1.5; 25) ()               -             -           -
# * 100 -> 94, 0.98                 : 24 vs 15  : .63 vs .61  .78 vs .78
# closest by dist test/original             j2       j20-h10     j50-h64
# closest by dist original/test              -             -           -
# closest by opt res test/original                       h16         h74
# closest by opt res original/test                       h18         h62
#
#                                       0.8
# () (ts 0.1 -1.5 -1.5; 25) ()            -
# * 100 -> 94, 0.98                 : --+--
# closest by dist test/original        jh80
# closest by dist original/test           -
# closest by opt res test/original      h90
# closest by opt res original/test      h90

# %%
first_index = '(; 5) (ts 0.5 -1.5 -1.5; 25) ()'
second_index = '* 100 -> 96, 0.96'
second_line =  '* **kernel size**: 24 vs 23, **purity**: .63 vs .56, **contrast** .78 vs .80, **$phi_{ij}$**: +++++'
lines = """
|  closest by dist test/original   	|  j8 	|j45-h52|j80-h88| jh89 	|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|     	|  h72 	|  h90 	|  h98 	|
| closest by opt res original/test 	|     	|  h56 	|  h84 	| h100 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (ts 0.5 -1.5 -1.5; 25) ()            -             -           -
# * 100 -> 96, 0.96                 : 24 vs 23  : .63 vs .56  .78 vs .80
# closest by dist test/original             j8       j45-h52     j80-h88
# closest by dist original/test              -             -           -
# closest by opt res test/original                       h72         h90
# closest by opt res original/test                       h56         h84
#
#                                       0.8
# (; 5) (ts 0.5 -1.5 -1.5; 25) ()         -
# * 100 -> 96, 0.96                 : +++++
# closest by dist test/original        jh89
# closest by dist original/test           -
# closest by opt res test/original      h98
# closest by opt res original/test     h100

# %%
first_index = '(; 5) (ts 0.5 -2 -2; 25) ()'
second_index = '* 100 -> 94 (starting fit 25 it 96), 0.96'
second_line =  '* **kernel size**: 24 vs 23, **purity**: .63 vs .55, **contrast** .78 vs .80, **$phi_{ij}$**: +++++ < prev'
lines = """
|  closest by dist test/original   	|  j8 	|  jh44 |j72-h86| jh86 	|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|     	|  h70 	|  h90 	|  h96 	|
| closest by opt res original/test 	|     	|  h46 	|  h84 	| h100 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                   0.2           0.4  \
# (; 5) (ts 0.5 -2 -2; 25) ()                         -             -
# * 100 -> 94 (starting fit 25 it 96), 0.96  : 24 vs 23  : .63 vs .55
# closest by dist test/original                      j8          jh44
# closest by dist original/test                       -             -
# closest by opt res test/original                                h70
# closest by opt res original/test                                h46
#
#                                                   0.6             0.8
# (; 5) (ts 0.5 -2 -2; 25) ()                         -               -
# * 100 -> 94 (starting fit 25 it 96), 0.96  .78 vs .80  : +++++ < prev
# closest by dist test/original                 j72-h86            jh86
# closest by dist original/test                       -               -
# closest by opt res test/original                  h90             h96
# closest by opt res original/test                  h84            h100

# %%
first_index = '(;5 ) (ts 0.7 -2 -2; 25) ()'
second_index = '* 100 -> 92 (95 with 25 starting its), 0.92'
second_line =  '* **kernel size**: 24 vs 23, **purity**: .63 vs .52, **contrast** .78 vs .81, **$phi_{ij}$**: +++++'
lines = """
|  closest by dist test/original   	|  j10 	|j48-h42|j78-h84| jh85 	|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|     	|  h68 	|  h90 	|  h92 	|
| closest by opt res original/test 	|     	|  h41 	|  h80 	|  h98 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                     0.2           0.4  \
# (;5 ) (ts 0.7 -2 -2; 25) ()                           -             -
# * 100 -> 92 (95 with 25 starting its), 0.92  : 24 vs 23  : .63 vs .52
# closest by dist test/original                       j10       j48-h42
# closest by dist original/test                         -             -
# closest by opt res test/original                                  h68
# closest by opt res original/test                                  h41
#
#                                                     0.6      0.8
# (;5 ) (ts 0.7 -2 -2; 25) ()                           -        -
# * 100 -> 92 (95 with 25 starting its), 0.92  .78 vs .81  : +++++
# closest by dist test/original                   j78-h84     jh85
# closest by dist original/test                         -        -
# closest by opt res test/original                    h90      h92
# closest by opt res original/test                    h80      h98

# %%
first_index = '() () ()'
second_index = '* 100 -> 99, 0.83'
second_line =  '* **kernel size**: 24 vs 24, **purity**: .63 vs .68, **contrast** .78 vs .79, **$phi_{ij}$**: --+-+'
lines = """
|  closest by dist test/original   	|  j12 	|j48-h76|j82-h90|j84-h92|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|  h8  	|  h84 	|  h94 	| h100	|
| closest by opt res original/test 	|     	|  h78 	|  h92 	| h100 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# () () ()                                   -             -           -
# * 100 -> 99, 0.83                 : 24 vs 24  : .63 vs .68  .78 vs .79
# closest by dist test/original            j12       j48-h76     j82-h90
# closest by dist original/test              -             -           -
# closest by opt res test/original          h8           h84         h94
# closest by opt res original/test                       h78         h92
#
#                                       0.8
# () () ()                                -
# * 100 -> 99, 0.83                 : --+-+
# closest by dist test/original     j84-h92
# closest by dist original/test           -
# closest by opt res test/original     h100
# closest by opt res original/test     h100

# %%
first_index = '(; 5) (dec 6 -2 -2; 15) (ts 0.7 -0.5 -0.5; 25)'
second_index = '* 100 -> 98, 0.98'
second_line =  '* **kernel size**: 24 vs 23, **purity**: .63 vs .66, **contrast** .78 vs .81, **$phi_{ij}$**: --+-+'
lines = """
|  closest by dist test/original   	|  j10 	|j44-h61|j81-h84|j86-h92|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|  h2  	|  h70 	|  h88 	| h98	|
| closest by opt res original/test 	|     	|  h64 	|  h88 	| h100 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                        0.2           0.4  \
# (; 5) (dec 6 -2 -2; 15) (ts 0.7 -0.5 -0.5; 25)           -             -
# * 100 -> 98, 0.98                               : 24 vs 23  : .63 vs .66
# closest by dist test/original                          j10       j44-h61
# closest by dist original/test                            -             -
# closest by opt res test/original                        h2           h70
# closest by opt res original/test                                     h64
#
#                                                        0.6      0.8
# (; 5) (dec 6 -2 -2; 15) (ts 0.7 -0.5 -0.5; 25)           -        -
# * 100 -> 98, 0.98                               .78 vs .81  : --+-+
# closest by dist test/original                      j81-h84  j86-h92
# closest by dist original/test                            -        -
# closest by opt res test/original                       h88      h98
# ...

# %%
first_index = '(; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)'
second_index = '* 100 -> 97, 0.98'
second_line =  '* **kernel size**: 24 vs 22, **purity**: .63 vs .68, **contrast** .78 vs .82, **$phi_{ij}$**: --+--'
lines = """
|  closest by dist test/original   	|  j10 	|j48-h60|j81-h84|j84-h92|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|  h8  	|  h70 	|  h88 	| h98	|
| closest by opt res original/test 	|     	|  h64 	|  h84 	| h100 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                        0.2           0.4  \
# (; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)           -             -
# * 100 -> 97, 0.98                               : 24 vs 22  : .63 vs .68
# closest by dist test/original                          j10       j48-h60
# closest by dist original/test                            -             -
# closest by opt res test/original                        h8           h70
# closest by opt res original/test                                     h64
#
#                                                        0.6      0.8
# (; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)           -        -
# * 100 -> 97, 0.98                               .78 vs .82  : --+--
# closest by dist test/original                      j81-h84  j84-h92
# closest by dist original/test                            -        -
# closest by opt res test/original                       h88      h98
# ...

# %%
first_index = '(; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)'
second_index = '* 100 -> 98, 0.97'
second_line =  '* **kernel size**: 24 vs 23, **purity**: .63 vs .67, **contrast** .78 vs .82, **$phi_{ij}$**: --+-+'
lines = """
|  closest by dist test/original   	|  j10 	|j42-h64|j81-h86|j84-h92|
|   closest by dist original/test  	|   -  	|   -  	|   - 	|  -  	|
| closest by opt res test/original 	|    	|  h70 	|  h90 	| h98	|
| closest by opt res original/test 	|     	|  h64 	|  h90 	| h100 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                            0.2           0.4  \
# (; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)           -             -
# * 100 -> 98, 0.97                                   : 24 vs 23  : .63 vs .67
# closest by dist test/original                              j10       j42-h64
# closest by dist original/test                                -             -
# closest by opt res test/original                                         h70
# closest by opt res original/test                                         h64
#
#                                                            0.6      0.8
# (; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)           -        -
# * 100 -> 98, 0.97                                   .78 vs .82  : --+-+
# closest by dist test/original                          j81-h86  j84-h92
# closest by dist original/test                                -        -
# ...

# %%
df_list_100 = df_list
df_list = []

# %%
df_100 = pd.concat(df_list_100)
df_100
# Out:
#                                                            0.2           0.4  \
# () (dec 1.5 -1.5 -1.5; 25) ()                                -             -
# 100 -> 98, 0.98                                     : 24 vs 14  : .63 vs .64
# closest by dist test/original                                0           j20
# closest by dist original/test                                              -
# closest by opt res test/original                                         h22
# closest by opt res original/test                                           -
# (; 5) (dec 3 -1.5 -1.5; 25) ()                               -             -
# 100 -> 99, 0.97                                     : 24 vs 22  : .63 vs .61
# closest by dist test/original                              j10       j40-h60
# closest by dist original/test                                -             -
# closest by opt res test/original                                         h64
# ...

# %% [markdown]
# # 150

# %%
first_index = '() (dec 1.5 -1.5 -1.5; 25) ()'
second_index = '* 150 -> 119, 0.98'
second_line = '* **kernel size**: 24 vs 10, **purity**: .63 vs .57, **contrast** .78 vs .73, **$phi_{ij}$**: --+-- '
lines = """
|   closestby dist test/original   	|  < h5	|j12-h10|j50-h60|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h10 	| h70  	| h100 	|
| closest by opt res original/test 	|  - 	|   - 	|  -	| h90  	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# () (dec 1.5 -1.5 -1.5; 25) ()              -             -           -
# * 150 -> 119, 0.98                : 24 vs 10  : .63 vs .57  .78 vs .73
# closestby dist test/original            < h5       j12-h10     j50-h60
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h10         h70
# closest by opt res original/test           -             -           -
#
#                                       0.8
# () (dec 1.5 -1.5 -1.5; 25) ()           -
# * 150 -> 119, 0.98                : --+--
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original     h100
# closest by opt res original/test      h90

# %%
first_index = '(; 5) (dec 3 -1.5 -1.5; 25) ()'
second_index = '* 150 -> 144, 0.98'
second_line = '* **kernel size**: 24 vs 15, **purity**: .63 vs .51, **contrast** .78 vs .74, **$phi_{ij}$**: --+-- '
lines = """
|   closestby dist test/original   	|  < j10|j55-h65|j90-h98|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h50 	| h82  	| h95 	|
| closest by opt res original/test 	|  - 	|  h80 	|  h100	|   	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (dec 3 -1.5 -1.5; 25) ()             -             -           -
# * 150 -> 144, 0.98                : 24 vs 15  : .63 vs .51  .78 vs .74
# closestby dist test/original           < j10       j55-h65     j90-h98
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h50         h82
# closest by opt res original/test           -           h80        h100
#
#                                       0.8
# (; 5) (dec 3 -1.5 -1.5; 25) ()          -
# * 150 -> 144, 0.98                : --+--
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original      h95
# closest by opt res original/test

# %%
first_index = '(; 5) (dec 6 -1.5 -1.5; 25) ()'
second_index = '* 150 -> 144, 0.98'
second_line = '* **kernel size**: 24 vs 15, **purity**: .63 vs .51, **contrast** .78 vs .74, **$phi_{ij}$**: --+-- '
lines = """
|   closestby dist test/original   	|  j10  |j55-h65|j90-h98|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h52 	| h82  	| h95 	|
| closest by opt res original/test 	|  - 	|  h80 	|  h100	|   	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (dec 6 -1.5 -1.5; 25) ()             -             -           -
# * 150 -> 144, 0.98                : 24 vs 15  : .63 vs .51  .78 vs .74
# closestby dist test/original             j10       j55-h65     j90-h98
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h52         h82
# closest by opt res original/test           -           h80        h100
#
#                                       0.8
# (; 5) (dec 6 -1.5 -1.5; 25) ()          -
# * 150 -> 144, 0.98                : --+--
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original      h95
# closest by opt res original/test

# %%
first_index = '() (dec 6 -1.5 -1.5; 25) ()'
second_index = '150 -> 119, 0.98'
second_line = '* **kernel size**: 24 vs 10, **purity**: .63 vs .57, **contrast** .78 vs .73, **$phi_{ij}$**: --+-- '
lines = """
|   closestby dist test/original   	|  j10  |j55-h65|j90-h98|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h10 	|  h60 	| h83 	|
| closest by opt res original/test 	|  - 	|  h10 	|  h60	| h80  	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# () (dec 6 -1.5 -1.5; 25) ()                -             -           -
# 150 -> 119, 0.98                  : 24 vs 10  : .63 vs .57  .78 vs .73
# closestby dist test/original             j10       j55-h65     j90-h98
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h10         h60
# closest by opt res original/test           -           h10         h60
#
#                                       0.8
# () (dec 6 -1.5 -1.5; 25) ()             -
# 150 -> 119, 0.98                  : --+--
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original      h83
# closest by opt res original/test      h80

# %%
first_index = '() (ts 0.1 -1.5 -1.5; 25) ()'
second_index = '150 -> 116'
second_line = '* **kernel size**: 24 vs 9, **purity**: .63 vs .55, **contrast** .78 vs .74, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j4   |j12-h10|j40-h52|  80  	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h10 	| h58  	| h92 	|
| closest by opt res original/test 	|  - 	|  h18 	| h60	| h90  	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                         0.2           0.4         0.6  \
# () (ts 0.1 -1.5 -1.5; 25) ()              -             -           -
# 150 -> 116                        : 24 vs 9  : .63 vs .55  .78 vs .74
# closestby dist test/original             j4       j12-h10     j40-h52
# closest by dist original/test             -             -           -
# closest by opt res test/original          0           h10         h58
# closest by opt res original/test          -           h18         h60
#
#                                        0.8
# () (ts 0.1 -1.5 -1.5; 25) ()             -
# 150 -> 116                        :  --+--
# closestby dist test/original            80
# closest by dist original/test
# closest by opt res test/original       h92
# closest by opt res original/test       h90

# %%
first_index = '(; 5) (ts 0.5 -1.5 -1.5; 25) ()'
second_index = '150 -> 129, 0.97'
second_line = '* **kernel size**: 24 vs 17, **purity**: .63 vs .48, **contrast** .78 vs .74, **$phi_{ij}$**:  +++++'
lines = """
|   closestby dist test/original   	|  j10  |j53-h60|j90-h98|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h55 	| h90  	| h100 	|
| closest by opt res original/test 	|  - 	|  h65 	|  h100	|   	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (ts 0.5 -1.5 -1.5; 25) ()            -             -           -
# 150 -> 129, 0.97                  : 24 vs 17  : .63 vs .48  .78 vs .74
# closestby dist test/original             j10       j53-h60     j90-h98
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h55         h90
# closest by opt res original/test           -           h65        h100
#
#                                        0.8
# (; 5) (ts 0.5 -1.5 -1.5; 25) ()          -
# 150 -> 129, 0.97                  :  +++++
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original      h100
# closest by opt res original/test

# %%
first_index = '(; 5) (ts 0.5 -2 -2; 25) ()'
second_index = '150 -> 123, 0.97'
second_line = '* **kernel size**: 24 vs 17, **purity**: .63 vs .49, **contrast** .78 vs .76, **$phi_{ij}$**:  +++++'
lines = """
|   closestby dist test/original   	|  j15  |j55-h50|j90-h98|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h55 	| h90  	| h100 	|
| closest by opt res original/test 	|  - 	|  h60 	|  h98	|   	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (ts 0.5 -2 -2; 25) ()                -             -           -
# 150 -> 123, 0.97                  : 24 vs 17  : .63 vs .49  .78 vs .76
# closestby dist test/original             j15       j55-h50     j90-h98
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h55         h90
# closest by opt res original/test           -           h60         h98
#
#                                        0.8
# (; 5) (ts 0.5 -2 -2; 25) ()              -
# 150 -> 123, 0.97                  :  +++++
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original      h100
# closest by opt res original/test

# %%
first_index = '(;5 ) (ts 0.7 -2 -2; 25) ()'
second_index = '150 -> 112, 0.96'
second_line = '* **kernel size**: 24 vs 19, **purity**: .63 vs .50, **contrast** .78 vs .79, **$phi_{ij}$**: +++++ (closer)  '
lines = """
|   closestby dist test/original   	|  j10  |j58-h55|j90-h98|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h65 	| h98  	| h100 	|
| closest by opt res original/test 	|  - 	|  h58 	|  h98	|   	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (;5 ) (ts 0.7 -2 -2; 25) ()                -             -           -
# 150 -> 112, 0.96                  : 24 vs 19  : .63 vs .50  .78 vs .79
# closestby dist test/original             j10       j58-h55     j90-h98
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h65         h98
# closest by opt res original/test           -           h58         h98
#
#                                                0.8
# (;5 ) (ts 0.7 -2 -2; 25) ()                      -
# 150 -> 112, 0.96                  : +++++ (closer)
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original              h100
# closest by opt res original/test

# %%
first_index = '() () ()'
second_index = '150 -> 135, 0.85'
second_line = '* **kernel size**: 24 vs 18, **purity**: .63 vs .63, **contrast** .78 vs .74, **$phi_{ij}$**: --+-- '
lines = """
|   closestby dist test/original   	|h5-j18	|j70-h90|j90-h100|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  h5  	| h70  	| h82  	| h100 	|
| closest by opt res original/test 	|  h10 	|  h93 	| h97  	| h100 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# () () ()                                   -             -           -
# 150 -> 135, 0.85                  : 24 vs 18  : .63 vs .63  .78 vs .74
# closestby dist test/original          h5-j18       j70-h90    j90-h100
# closest by dist original/test              -             -           -
# closest by opt res test/original          h5           h70         h82
# closest by opt res original/test         h10           h93         h97
#
#                                       0.8
# () () ()                                -
# 150 -> 135, 0.85                  : --+--
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original     h100
# closest by opt res original/test     h100

# %%
first_index = '(; 5) (dec 6 -2 -2; 15) (ts 0.7 -0.5 -0.5; 25)'
second_index = '150 -> 131, 0.98'
second_line = '* **kernel size**: 24 vs 17, **purity**: .63 vs .62, **contrast** .78 vs .79, **$phi_{ij}$**: --+-- '
lines = """
|   closestby dist test/original   	|  j10  |j53-h68|j90-h98|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h50 	| h85  	| h98 	|
| closest by opt res original/test 	|  - 	|  h82 	|  h98	|   	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                        0.2           0.4  \
# (; 5) (dec 6 -2 -2; 15) (ts 0.7 -0.5 -0.5; 25)           -             -
# 150 -> 131, 0.98                                : 24 vs 17  : .63 vs .62
# closestby dist test/original                           j10       j53-h68
# closest by dist original/test                            -             -
# closest by opt res test/original                         0           h50
# closest by opt res original/test                         -           h82
#
#                                                        0.6      0.8
# (; 5) (dec 6 -2 -2; 15) (ts 0.7 -0.5 -0.5; 25)           -        -
# 150 -> 131, 0.98                                .78 vs .79  : --+--
# closestby dist test/original                       j90-h98
# closest by dist original/test                            -
# closest by opt res test/original                       h85      h98
# closest by opt res original/test                       h98

# %%
first_index = '(; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)'
second_index = '150 -> 129, 0.98'
second_line = '* **kernel size**: 24 vs 17, **purity**: .63 vs .63, **contrast** .78 vs .79, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j10  |j50-h70|j90-h96|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h55 	|  h88 	| h100 	|
| closest by opt res original/test 	|  - 	|  h82 	|  h98	|   	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                        0.2           0.4  \
# (; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)           -             -
# 150 -> 129, 0.98                                : 24 vs 17  : .63 vs .63
# closestby dist test/original                           j10       j50-h70
# closest by dist original/test                            -             -
# closest by opt res test/original                         0           h55
# closest by opt res original/test                         -           h82
#
#                                                        0.6       0.8
# (; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)           -         -
# 150 -> 129, 0.98                                .78 vs .79  :  --+--
# closestby dist test/original                       j90-h96
# closest by dist original/test                            -
# closest by opt res test/original                       h88      h100
# closest by opt res original/test                       h98

# %%
first_index = '(; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)'
second_index = '150 -> 142, 0.98'
second_line = '* **kernel size**: 24 vs 16, **purity**: .63 vs .60, **contrast** .78 vs .76, **$phi_{ij}$**: --+-- '
lines = """
|   closestby dist test/original   	|  j10  |j53-h68|j90-h98|    	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h50 	|  h82 	| h98 	|
| closest by opt res original/test 	|  - 	|  h82 	|  h100	|   	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                            0.2           0.4  \
# (; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)           -             -
# 150 -> 142, 0.98                                    : 24 vs 16  : .63 vs .60
# closestby dist test/original                               j10       j53-h68
# closest by dist original/test                                -             -
# closest by opt res test/original                             0           h50
# closest by opt res original/test                             -           h82
#
#                                                            0.6      0.8
# (; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)           -        -
# 150 -> 142, 0.98                                    .78 vs .76  : --+--
# closestby dist test/original                           j90-h98
# closest by dist original/test                                -
# closest by opt res test/original                           h82      h98
# ...

# %%
df_list_150 = df_list
df_list = []

# %%
df_150 = pd.concat(df_list_150)
df_150
# Out:
#                                                            0.2           0.4  \
# () (dec 1.5 -1.5 -1.5; 25) ()                                -             -
# * 150 -> 119, 0.98                                  : 24 vs 10  : .63 vs .57
# closestby dist test/original                              < h5       j12-h10
# closest by dist original/test                                -             -
# closest by opt res test/original                             0           h10
# closest by opt res original/test                             -             -
# (; 5) (dec 3 -1.5 -1.5; 25) ()                               -             -
# * 150 -> 144, 0.98                                  : 24 vs 15  : .63 vs .51
# closestby dist test/original                             < j10       j55-h65
# closest by dist original/test                                -             -
# closest by opt res test/original                             0           h50
# ...

# %% [markdown]
# # 200

# %%
first_index = '() (dec 1.5 -1.5 -1.5; 25) ()'
second_index = '* 200 -> 106, 0.98'
second_line = '* **kernel size**: 24 vs 9, **purity**: .63 vs .55, **contrast** .78 vs .68, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j3   | j5-h4 |j25-h42| h80  	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h5 	|  h60 	| h98 	|
| closest by opt res original/test 	|  - 	|  h10 	|  h58	| h83  	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                         0.2           0.4         0.6  \
# () (dec 1.5 -1.5 -1.5; 25) ()             -             -           -
# * 200 -> 106, 0.98                : 24 vs 9  : .63 vs .55  .78 vs .68
# closestby dist test/original             j3         j5-h4     j25-h42
# closest by dist original/test             -             -           -
# closest by opt res test/original          0            h5         h60
# closest by opt res original/test          -           h10         h58
#
#                                        0.8
# () (dec 1.5 -1.5 -1.5; 25) ()            -
# * 200 -> 106, 0.98                :  --+--
# closestby dist test/original           h80
# closest by dist original/test
# closest by opt res test/original       h98
# closest by opt res original/test       h83

# %%
first_index = '(; 5) (dec 3 -1.5 -1.5; 25) ()'
second_index = '* 200 -> 172, 0.98'
second_line = '* **kernel size**: 24 vs 13, **purity**: .63 vs .46, **contrast** .78 vs .68, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j15  |j50-h60|j90-h98|   	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h42 	|  h70 	| h98 	|
| closest by opt res original/test 	|  - 	|  h78 	|  h98	|   	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (dec 3 -1.5 -1.5; 25) ()             -             -           -
# * 200 -> 172, 0.98                : 24 vs 13  : .63 vs .46  .78 vs .68
# closestby dist test/original             j15       j50-h60     j90-h98
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h42         h70
# closest by opt res original/test           -           h78         h98
#
#                                        0.8
# (; 5) (dec 3 -1.5 -1.5; 25) ()           -
# * 200 -> 172, 0.98                :  --+--
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original       h98
# closest by opt res original/test

# %%
first_index = '(; 5) (dec 6 -1.5 -1.5; 25) ()'
second_index = '* 200 -> 173, 0.98'
second_line = '* **kernel size**: 24 vs 13, **purity**: .63 vs .46, **contrast** .78 vs .68, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j15  |j50-h60|j90-h95|   	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h40 	|  h70 	| h98 	|
| closest by opt res original/test 	|  - 	|  h80 	|  h99	|   	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (dec 6 -1.5 -1.5; 25) ()             -             -           -
# * 200 -> 173, 0.98                : 24 vs 13  : .63 vs .46  .78 vs .68
# closestby dist test/original             j15       j50-h60     j90-h95
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h40         h70
# closest by opt res original/test           -           h80         h99
#
#                                        0.8
# (; 5) (dec 6 -1.5 -1.5; 25) ()           -
# * 200 -> 173, 0.98                :  --+--
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original       h98
# closest by opt res original/test

# %%
first_index = '() (dec 6 -1.5 -1.5; 25) ()'
second_index = '* 200 -> 106, 0.98'
second_line = '* **kernel size**: 24 vs 9, **purity**: .63 vs .55, **contrast** .78 vs .68, **$phi_{ij}$**:  --+--'
lines = """
|  closest by dist test/original   	|  j3   | j5-h4 |j25-h45| h78  	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h5 	|  h60 	| h98 	|
| closest by opt res original/test 	|  - 	|  h10 	|  h58	| h83  	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                         0.2           0.4         0.6  \
# () (dec 6 -1.5 -1.5; 25) ()               -             -           -
# * 200 -> 106, 0.98                : 24 vs 9  : .63 vs .55  .78 vs .68
# closest by dist test/original            j3         j5-h4     j25-h45
# closest by dist original/test             -             -           -
# closest by opt res test/original          0            h5         h60
# closest by opt res original/test          -           h10         h58
#
#                                        0.8
# () (dec 6 -1.5 -1.5; 25) ()              -
# * 200 -> 106, 0.98                :  --+--
# closest by dist test/original          h78
# closest by dist original/test
# closest by opt res test/original       h98
# closest by opt res original/test       h83

# %%
first_index = '() (ts 0.1 -1.5 -1.5; 25) ()'
second_index = '* 200 -> 97, 0.98'
second_line = '* **kernel size**: 24 vs 9, **purity**: .63 vs .55, **contrast** .78 vs .70, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j3   | j5-h4 |j25-h40| h75  	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h5 	|  h60 	| h98 	|
| closest by opt res original/test 	|  - 	|  h10 	|  h58	| h96  	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                         0.2           0.4         0.6  \
# () (ts 0.1 -1.5 -1.5; 25) ()              -             -           -
# * 200 -> 97, 0.98                 : 24 vs 9  : .63 vs .55  .78 vs .70
# closestby dist test/original             j3         j5-h4     j25-h40
# closest by dist original/test             -             -           -
# closest by opt res test/original          0            h5         h60
# closest by opt res original/test          -           h10         h58
#
#                                        0.8
# () (ts 0.1 -1.5 -1.5; 25) ()             -
# * 200 -> 97, 0.98                 :  --+--
# closestby dist test/original           h75
# closest by dist original/test
# closest by opt res test/original       h98
# closest by opt res original/test       h96

# %%
first_index = '(; 5) (ts 0.5 -1.5 -1.5; 25) ()'
second_index = '* 200 -> 146, 0.97'
second_line = '* **kernel size**: 24 vs 15, **purity**: .63 vs .45, **contrast** .78 vs .70, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j15  |j50-h60|  jh96 |   	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h45 	|  h80 	| h100 	|
| closest by opt res original/test 	|  - 	|  h77 	|  h98	| h100 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (ts 0.5 -1.5 -1.5; 25) ()            -             -           -
# * 200 -> 146, 0.97                : 24 vs 15  : .63 vs .45  .78 vs .70
# closestby dist test/original             j15       j50-h60        jh96
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h45         h80
# closest by opt res original/test           -           h77         h98
#
#                                        0.8
# (; 5) (ts 0.5 -1.5 -1.5; 25) ()          -
# * 200 -> 146, 0.97                :  --+--
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original      h100
# closest by opt res original/test      h100

# %%
first_index = '(; 5) (ts 0.5 -2 -2; 25) ()'
second_index = '* 200 -> 133, 0.97'
second_line = '* **kernel size**: 24 vs 16, **purity**: .50 vs .74, **contrast** .78 vs .70, **$phi_{ij}$**:  +++--'
lines = """
|   closestby dist test/original   	|  j17  |j50-h60|  jh96 |   	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h58 	|  h93 	| h100 	|
| closest by opt res original/test 	|  - 	|  h70 	|  h98	| h100 	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (; 5) (ts 0.5 -2 -2; 25) ()                -             -           -
# * 200 -> 133, 0.97                : 24 vs 16  : .50 vs .74  .78 vs .70
# closestby dist test/original             j17       j50-h60        jh96
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h58         h93
# closest by opt res original/test           -           h70         h98
#
#                                        0.8
# (; 5) (ts 0.5 -2 -2; 25) ()              -
# * 200 -> 133, 0.97                :  +++--
# closestby dist test/original
# closest by dist original/test
# closest by opt res test/original      h100
# closest by opt res original/test      h100

# %%
first_index = '(;5 ) (ts 0.7 -2 -2; 25) ()'
second_index = '* 200 -> 122, 0.97'
second_line = '* **kernel size**: 24 vs 17, **purity**: .63 vs .50, **contrast** .78 vs .77, **$phi_{ij}$**:  +++--'
lines = """
|   closestby dist test/original   	|  j10  |  jh55 |  jh96 | jh98 	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h62 	|  h90 	|    	|
| closest by opt res original/test 	|  - 	|  h62 	|  h98	|    	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# (;5 ) (ts 0.7 -2 -2; 25) ()                -             -           -
# * 200 -> 122, 0.97                : 24 vs 17  : .63 vs .50  .78 vs .77
# closestby dist test/original             j10          jh55        jh96
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h62         h90
# closest by opt res original/test           -           h62         h98
#
#                                        0.8
# (;5 ) (ts 0.7 -2 -2; 25) ()              -
# * 200 -> 122, 0.97                :  +++--
# closestby dist test/original          jh98
# closest by dist original/test
# closest by opt res test/original
# closest by opt res original/test

# %%
first_index = '() () ()'
second_index = '* 200 -> 173, 0.84'
second_line = '* **kernel size**: 24 vs 14, **purity**: .63 vs .57, **contrast** .78 vs .69, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j20  |j78-h92|j92-h99| h100 	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h60 	|  h72 	|  h100	|
| closest by opt res original/test 	|  - 	|  h100	|   	|    	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                          0.2           0.4         0.6  \
# () () ()                                   -             -           -
# * 200 -> 173, 0.84                : 24 vs 14  : .63 vs .57  .78 vs .69
# closestby dist test/original             j20       j78-h92     j92-h99
# closest by dist original/test              -             -           -
# closest by opt res test/original           0           h60         h72
# closest by opt res original/test           -          h100
#
#                                        0.8
# () () ()                                 -
# * 200 -> 173, 0.84                :  --+--
# closestby dist test/original          h100
# closest by dist original/test
# closest by opt res test/original      h100
# closest by opt res original/test

# %%
first_index = '(; 5) (dec 6 -2 -2; 15) (ts 0.7 -0.5 -0.5; 25)'
second_index = '* 200 -> 150, 0.98'
second_line = '* **kernel size**: 24 vs 14, **purity**: .63 vs .58, **contrast** .78 vs .77, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j14  |j48-h68|  jh90 | jh100	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h42 	|  h70 	|  h96 	|
| closest by opt res original/test 	|  - 	|  h84 	|  h98	|    	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                        0.2           0.4  \
# (; 5) (dec 6 -2 -2; 15) (ts 0.7 -0.5 -0.5; 25)           -             -
# * 200 -> 150, 0.98                              : 24 vs 14  : .63 vs .58
# closestby dist test/original                           j14       j48-h68
# closest by dist original/test                            -             -
# closest by opt res test/original                         0           h42
# closest by opt res original/test                         -           h84
#
#                                                        0.6       0.8
# (; 5) (dec 6 -2 -2; 15) (ts 0.7 -0.5 -0.5; 25)           -         -
# * 200 -> 150, 0.98                              .78 vs .77  :  --+--
# closestby dist test/original                          jh90     jh100
# closest by dist original/test                            -
# closest by opt res test/original                       h70       h96
# ...

# %%
first_index = '(; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)'
second_index = '* 200 -> 145, 0.98'
second_line = '* **kernel size**: 24 vs 15, **purity**: .63 vs .60, **contrast** .78 vs .78, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j14  |j50-h64|  jh92 | jh100	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h44 	|  h72 	|  h98 	|
| closest by opt res original/test 	|  - 	|  h84 	|  h98	|    	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                        0.2           0.4  \
# (; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)           -             -
# * 200 -> 145, 0.98                              : 24 vs 15  : .63 vs .60
# closestby dist test/original                           j14       j50-h64
# closest by dist original/test                            -             -
# closest by opt res test/original                         0           h44
# closest by opt res original/test                         -           h84
#
#                                                        0.6       0.8
# (; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)           -         -
# * 200 -> 145, 0.98                              .78 vs .78  :  --+--
# closestby dist test/original                          jh92     jh100
# closest by dist original/test                            -
# closest by opt res test/original                       h72       h98
# ...

# %%
first_index = '(; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)'
second_index = '* 200 -> 161, 0.98'
second_line = '* **kernel size**: 24 vs 14, **purity**: .63 vs .54, **contrast** .78 vs .74, **$phi_{ij}$**:  --+--'
lines = """
|   closestby dist test/original   	|  j14  |j50-h70|  jh92 | jh100	|
|   closest by dist original/test  	|  -	|   -  	|   - 	|    	|
| closest by opt res test/original 	|  0  	|  h42 	|  h70 	|  h96 	|
| closest by opt res original/test 	|  - 	|  h90 	|  h98	|    	|
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df
# Out:
#                                                            0.2           0.4  \
# (; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)           -             -
# * 200 -> 161, 0.98                                  : 24 vs 14  : .63 vs .54
# closestby dist test/original                               j14       j50-h70
# closest by dist original/test                                -             -
# closest by opt res test/original                             0           h42
# closest by opt res original/test                             -           h90
#
#                                                            0.6       0.8
# (; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)           -         -
# * 200 -> 161, 0.98                                  .78 vs .74  :  --+--
# closestby dist test/original                              jh92     jh100
# closest by dist original/test                                -
# closest by opt res test/original                           h70       h96
# ...

# %%
df_list_200 = df_list
df_list = []

# %%
df_200 = pd.concat(df_list_200)
df_200
# Out:
#                                                            0.2           0.4  \
# () (dec 1.5 -1.5 -1.5; 25) ()                                -             -
# * 200 -> 106, 0.98                                   : 24 vs 9  : .63 vs .55
# closestby dist test/original                                j3         j5-h4
# closest by dist original/test                                -             -
# closest by opt res test/original                             0            h5
# closest by opt res original/test                             -           h10
# (; 5) (dec 3 -1.5 -1.5; 25) ()                               -             -
# * 200 -> 172, 0.98                                  : 24 vs 13  : .63 vs .46
# closestby dist test/original                               j15       j50-h60
# closest by dist original/test                                -             -
# closest by opt res test/original                             0           h42
# ...

# %% [markdown]
# # empty

# %%
first_index = '() (dec 1.5 -1.5 -1.5; 25) ()'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '(; 5) (dec 3 -1.5 -1.5; 25) ()'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '(; 5) (dec 6 -1.5 -1.5; 25) ()'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '() (dec 6 -1.5 -1.5; 25) ()'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '() (ts 0.1 -1.5 -1.5; 25) ()'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '(; 5) (ts 0.5 -1.5 -1.5; 25) ()'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '(; 5) (ts 0.5 -2 -2; 25) ()'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '(;5 ) (ts 0.7 -2 -2; 25) ()'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '() () ()'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '(; 5) (dec 6 -2 -2; 15) (ts 0.7 -0.5 -0.5; 25)'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '(; 5) (dec 6 -2 -2; 25) (ts 0.7 -0.5 -0.5; 25)'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

# %%
first_index = '(; 5) (dec 6 -1.5 -1.5; 15) (ts 0.9 -0.5 -0.5; 25)'
second_index = ''
second_line =  ''
lines = """
"""
tmp_df = lines_to_df(lines, first_index, second_index, second_line)
df_list.append(tmp_df)
tmp_df

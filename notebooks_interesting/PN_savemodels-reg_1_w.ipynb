# %%
import pickle
import sys
import numpy as np
import pandas as pd
import artm
import seaborn as sns
import matplotlib.pyplot as plt
print artm.version()

from os import path, mkdir
from datetime import datetime
sys.path.insert(0, '..\\modules\\helpers')

import distances_helper as dh 
import print_helper as ph
import create_model_helper as cmh
import build_convex_hull_helper as bchh
import different_models as dm

from plot_helper import PlotMaker
from config_helper import ConfigPaths
from scipy.optimize import minimize
# Out:
# 0.8.1

# %%
config = ConfigPaths('config_sample_m3.cfg')
print config.models_file_name
models_file = open(config.models_file_name, 'a')

plot_maker = PlotMaker()

batch_vectorizer = artm.BatchVectorizer(data_path=config.output_batches_path,
                                        data_format='batches')
dictionary = artm.Dictionary()
dictionary.load(dictionary_path=config.dictionary_path + '.dict')
# Out:
# F:\\topic_modeling\\csi_science_collections.no_git\experiments\pn_model3\np_09_03_m3_reg_save\models.txt

# %%
def create_model_fn_1(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                             n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20, 
                                  _model_name='model_20_m1_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_2(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=100, n_doc_passes=5, seed_value=100 + n_iteration,
                             n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20, 
                                  _model_name='model_100_m2_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_3(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['decorrelator_phi_regularizer'].tau = 300
    tmp_model.regularizers['ss_theta_regularizer'].tau = -5
    tmp_model.regularizers['ss_phi_regularizer'].tau = -20
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20, 
                                  _model_name='model_20_m3_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_4(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=100, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['decorrelator_phi_regularizer'].tau = 10
    tmp_model.regularizers['ss_theta_regularizer'].tau = -0.5
    tmp_model.regularizers['ss_phi_regularizer'].tau = -2
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20, 
                                  _model_name='model_20_m4_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_1(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -3
    tmp_model.regularizers['ss_phi_regularizer'].tau = -3
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                   tmp_model, _n_iterations=20, 
                                   _model_name='model_20_reg_1_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_2(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -5
    tmp_model.regularizers['ss_phi_regularizer'].tau = -5
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,                               
                                  _model_name='model_20_reg_2_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_3(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -10
    tmp_model.regularizers['ss_phi_regularizer'].tau = -10
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,             
                                  _model_name='model_20_reg_3_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_4(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -5
    tmp_model.regularizers['ss_phi_regularizer'].tau = -5
    tmp_model.regularizers['decorrelator_phi_regularizer'].tau = -10 
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,             
                                  _model_name='model_20_reg_4_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_5(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -20
    tmp_model.regularizers['ss_phi_regularizer'].tau = -20
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,             
                                  _model_name='model_20_reg_5_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_6(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -30
    tmp_model.regularizers['ss_phi_regularizer'].tau = -30
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,             
                                  _model_name='model_20_reg_6_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_reg_8(n_iteration):
    tmp_model = cmh.create_model(current_dictionary=dictionary, n_topics=20, n_doc_passes=5, seed_value=100 + n_iteration,
                            n_top_tokens=15, p_mass_threshold=0.25)
    tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer'))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer', class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer'].tau = -20
    tmp_model.regularizers['ss_phi_regularizer'].tau = -20
    tmp_model.regularizers['decorrelator_phi_regularizer'].tau = -10 
    tmp_model = cmh.fit_one_model(plot_maker, batch_vectorizer, models_file, config, 
                                  tmp_model, _n_iterations=20,             
                                  _model_name='model_20_reg_8_iter_{}'.format(n_iteration))
    return tmp_model

def create_model_fn_20_complex_reg_1(n_iteration):
    n_topics = 20
    common_topics = [u'topic_0', u'topic_1']
    subject_topics = list(set([u'topic_{}'.format(idx) for idx in range(2, 20)]) - set(common_topics))
    tmp_model = create_model_complex(current_dictionary=dictionary, n_topics=n_topics, n_doc_passes=5, 
        seed_value=100 + n_iteration, n_top_tokens=15, p_mass_threshold=0.25, 
        common_topics=common_topics, subject_topics=subject_topics)
    # subject topics
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer_subject', 
        topic_names=subject_topics))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer_subject', 
        topic_names=subject_topics, class_ids=['@default_class']))
    tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer_subject', 
        topic_names=subject_topics, class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer_subject'].tau = -0.5
    tmp_model.regularizers['ss_phi_regularizer_subject'].tau = -0.5
    tmp_model.regularizers['decorrelator_phi_regularizer_subject'].tau = -10

    # common topics
    tmp_model.regularizers.add(artm.SmoothSparseThetaRegularizer(name='ss_theta_regularizer_common', 
        topic_names=subject_topics))
    tmp_model.regularizers.add(artm.SmoothSparsePhiRegularizer(name='ss_phi_regularizer_common', 
        topic_names=subject_topics, class_ids=['@default_class']))
#     tmp_model.regularizers.add(artm.DecorrelatorPhiRegularizer(name='decorrelator_phi_regularizer_common', 
#         topic_names=subject_topics, class_ids=['@default_class']))
    tmp_model.regularizers['ss_theta_regularizer_common'].tau = 0.5
    tmp_model.regularizers['ss_phi_regularizer_common'].tau = 0.5
#     tmp_model.regularizers['decorrelator_phi_regularizer_common'].tau = -10

    tmp_model = fit_one_model_complex(plot_maker, batch_vectorizer, models_file, config, 
                                      tmp_model, _n_iterations=20,             
                                      _model_name='model_20_complex_reg_1_iter_{}'.format(n_iteration))
    return tmp_model

# %%
def save_pickle_file(dists, filename, _path=config.experiment_path):
    pickle_filename = path.join(_path, filename)
    pickle_file = open(pickle_filename, 'wb')
    pickle.dump(dists, pickle_file)
    pickle_file.close()
def load_pickle_file(filename, _path=config.experiment_path):
    pickle_filename = path.join(_path, filename)
    pickle_file = open(pickle_filename, 'rb')
    p_file = pickle.load(pickle_file)
    pickle_file.close()
    return p_file

# %% [markdown]
# ## Save models
# Just make a lot of itaration of creating models and saving their phi matrix. So that later make experiments with different thresholds and distances not creating same models.

# %%
def create_models_range(create_model_fn, models_name, n_iterations=2000):
    models_range = []
    for n_iteration in range(n_iterations):
        model = create_model_fn(n_iteration)
        phi = model.get_phi()
        # rename phi columns 
        phi.columns = [c + '_{}'.format(n_iteration) for c in phi.columns]
        models_range.append(phi)
        print('[{}] current iteration {} / {} '.format(datetime.now(), n_iteration + 1, n_iterations))
        # reserve save        
        if n_iteration % 500 == 0 or n_iteration + 1 == n_iterations:
            save_pickle_file(models_range, 'phi_models_range___' + models_name)
    return models_range

# %%
tmp_models_range = create_models_range(create_model_fn_20_reg_3, 'model_reg3')
# Out:
# name = model_20_reg_3_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:08:45.724000] current iteration 1 / 2000
# name = model_20_reg_3_iter_1, n_topics = 20, n_doc_passes = 5, seed_value = 101, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:08:54.607000] current iteration 2 / 2000
# name = model_20_reg_3_iter_2, n_topics = 20, n_doc_passes = 5, seed_value = 102, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:09:03.581000] current iteration 3 / 2000
# name = model_20_reg_3_iter_3, n_topics = 20, n_doc_passes = 5, seed_value = 103, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:09:12.451000] current iteration 4 / 2000
# name = model_20_reg_3_iter_4, n_topics = 20, n_doc_passes = 5, seed_value = 104, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:09:21.279000] current iteration 5 / 2000
# name = model_20_reg_3_iter_5, n_topics = 20, n_doc_passes = 5, seed_value = 105, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:09:30.078000] current iteration 6 / 2000
# name = model_20_reg_3_iter_6, n_topics = 20, n_doc_passes = 5, seed_value = 106, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:09:38.807000] current iteration 7 / 2000
# name = model_20_reg_3_iter_7, n_topics = 20, n_doc_passes = 5, seed_value = 107, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:09:48.098000] current iteration 8 / 2000
# name = model_20_reg_3_iter_8, n_topics = 20, n_doc_passes = 5, seed_value = 108, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:09:56.990000] current iteration 9 / 2000
# name = model_20_reg_3_iter_9, n_topics = 20, n_doc_passes = 5, seed_value = 109, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:10:05.846000] current iteration 10 / 2000
# name = model_20_reg_3_iter_10, n_topics = 20, n_doc_passes = 5, seed_value = 110, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:10:15] current iteration 11 / 2000
# name = model_20_reg_3_iter_11, n_topics = 20, n_doc_passes = 5, seed_value = 111, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:10:24.010000] current iteration 12 / 2000
# name = model_20_reg_3_iter_12, n_topics = 20, n_doc_passes = 5, seed_value = 112, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:10:34.175000] current iteration 13 / 2000
# name = model_20_reg_3_iter_13, n_topics = 20, n_doc_passes = 5, seed_value = 113, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:10:43.229000] current iteration 14 / 2000
# name = model_20_reg_3_iter_14, n_topics = 20, n_doc_passes = 5, seed_value = 114, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:10:52.267000] current iteration 15 / 2000
# name = model_20_reg_3_iter_15, n_topics = 20, n_doc_passes = 5, seed_value = 115, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:11:01.162000] current iteration 16 / 2000
# name = model_20_reg_3_iter_16, n_topics = 20, n_doc_passes = 5, seed_value = 116, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:11:10.078000] current iteration 17 / 2000
# name = model_20_reg_3_iter_17, n_topics = 20, n_doc_passes = 5, seed_value = 117, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:11:21.625000] current iteration 18 / 2000
# name = model_20_reg_3_iter_18, n_topics = 20, n_doc_passes = 5, seed_value = 118, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:11:31.901000] current iteration 19 / 2000
# name = model_20_reg_3_iter_19, n_topics = 20, n_doc_passes = 5, seed_value = 119, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:11:42.493000] current iteration 20 / 2000
# name = model_20_reg_3_iter_20, n_topics = 20, n_doc_passes = 5, seed_value = 120, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:11:54.795000] current iteration 21 / 2000
# name = model_20_reg_3_iter_21, n_topics = 20, n_doc_passes = 5, seed_value = 121, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:12:04.470000] current iteration 22 / 2000
# name = model_20_reg_3_iter_22, n_topics = 20, n_doc_passes = 5, seed_value = 122, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:12:13.983000] current iteration 23 / 2000
# name = model_20_reg_3_iter_23, n_topics = 20, n_doc_passes = 5, seed_value = 123, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:12:24.142000] current iteration 24 / 2000
# name = model_20_reg_3_iter_24, n_topics = 20, n_doc_passes = 5, seed_value = 124, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:12:33.628000] current iteration 25 / 2000
# name = model_20_reg_3_iter_25, n_topics = 20, n_doc_passes = 5, seed_value = 125, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:12:43.367000] current iteration 26 / 2000
# name = model_20_reg_3_iter_26, n_topics = 20, n_doc_passes = 5, seed_value = 126, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:12:52.798000] current iteration 27 / 2000
# name = model_20_reg_3_iter_27, n_topics = 20, n_doc_passes = 5, seed_value = 127, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:13:02.173000] current iteration 28 / 2000
# name = model_20_reg_3_iter_28, n_topics = 20, n_doc_passes = 5, seed_value = 128, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:13:11.567000] current iteration 29 / 2000
# name = model_20_reg_3_iter_29, n_topics = 20, n_doc_passes = 5, seed_value = 129, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:13:21.148000] current iteration 30 / 2000
# name = model_20_reg_3_iter_30, n_topics = 20, n_doc_passes = 5, seed_value = 130, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:13:30.290000] current iteration 31 / 2000
# name = model_20_reg_3_iter_31, n_topics = 20, n_doc_passes = 5, seed_value = 131, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:13:39.824000] current iteration 32 / 2000
# name = model_20_reg_3_iter_32, n_topics = 20, n_doc_passes = 5, seed_value = 132, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:13:49.260000] current iteration 33 / 2000
# name = model_20_reg_3_iter_33, n_topics = 20, n_doc_passes = 5, seed_value = 133, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:13:58.088000] current iteration 34 / 2000
# name = model_20_reg_3_iter_34, n_topics = 20, n_doc_passes = 5, seed_value = 134, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:14:06.977000] current iteration 35 / 2000
# name = model_20_reg_3_iter_35, n_topics = 20, n_doc_passes = 5, seed_value = 135, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:14:15.728000] current iteration 36 / 2000
# name = model_20_reg_3_iter_36, n_topics = 20, n_doc_passes = 5, seed_value = 136, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:14:25.304000] current iteration 37 / 2000
# name = model_20_reg_3_iter_37, n_topics = 20, n_doc_passes = 5, seed_value = 137, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:14:34.507000] current iteration 38 / 2000
# name = model_20_reg_3_iter_38, n_topics = 20, n_doc_passes = 5, seed_value = 138, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:14:43.485000] current iteration 39 / 2000
# name = model_20_reg_3_iter_39, n_topics = 20, n_doc_passes = 5, seed_value = 139, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:14:52.130000] current iteration 40 / 2000
# name = model_20_reg_3_iter_40, n_topics = 20, n_doc_passes = 5, seed_value = 140, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:15:00.741000] current iteration 41 / 2000
# name = model_20_reg_3_iter_41, n_topics = 20, n_doc_passes = 5, seed_value = 141, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:15:09.318000] current iteration 42 / 2000
# name = model_20_reg_3_iter_42, n_topics = 20, n_doc_passes = 5, seed_value = 142, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:15:17.885000] current iteration 43 / 2000
# name = model_20_reg_3_iter_43, n_topics = 20, n_doc_passes = 5, seed_value = 143, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:15:26.848000] current iteration 44 / 2000
# name = model_20_reg_3_iter_44, n_topics = 20, n_doc_passes = 5, seed_value = 144, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:15:35.598000] current iteration 45 / 2000
# name = model_20_reg_3_iter_45, n_topics = 20, n_doc_passes = 5, seed_value = 145, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:15:44.380000] current iteration 46 / 2000
# name = model_20_reg_3_iter_46, n_topics = 20, n_doc_passes = 5, seed_value = 146, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:15:53.192000] current iteration 47 / 2000
# name = model_20_reg_3_iter_47, n_topics = 20, n_doc_passes = 5, seed_value = 147, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:16:02.145000] current iteration 48 / 2000
# name = model_20_reg_3_iter_48, n_topics = 20, n_doc_passes = 5, seed_value = 148, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:16:11.134000] current iteration 49 / 2000
# name = model_20_reg_3_iter_49, n_topics = 20, n_doc_passes = 5, seed_value = 149, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:16:21.925000] current iteration 50 / 2000
# name = model_20_reg_3_iter_50, n_topics = 20, n_doc_passes = 5, seed_value = 150, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:16:33.860000] current iteration 51 / 2000
# name = model_20_reg_3_iter_51, n_topics = 20, n_doc_passes = 5, seed_value = 151, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:16:45.226000] current iteration 52 / 2000
# name = model_20_reg_3_iter_52, n_topics = 20, n_doc_passes = 5, seed_value = 152, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:16:55.772000] current iteration 53 / 2000
# name = model_20_reg_3_iter_53, n_topics = 20, n_doc_passes = 5, seed_value = 153, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:17:05.846000] current iteration 54 / 2000
# name = model_20_reg_3_iter_54, n_topics = 20, n_doc_passes = 5, seed_value = 154, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:17:14.861000] current iteration 55 / 2000
# name = model_20_reg_3_iter_55, n_topics = 20, n_doc_passes = 5, seed_value = 155, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:17:24.017000] current iteration 56 / 2000
# name = model_20_reg_3_iter_56, n_topics = 20, n_doc_passes = 5, seed_value = 156, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:17:33.328000] current iteration 57 / 2000
# name = model_20_reg_3_iter_57, n_topics = 20, n_doc_passes = 5, seed_value = 157, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:17:42.017000] current iteration 58 / 2000
# name = model_20_reg_3_iter_58, n_topics = 20, n_doc_passes = 5, seed_value = 158, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:17:50.617000] current iteration 59 / 2000
# name = model_20_reg_3_iter_59, n_topics = 20, n_doc_passes = 5, seed_value = 159, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:17:59.219000] current iteration 60 / 2000
# name = model_20_reg_3_iter_60, n_topics = 20, n_doc_passes = 5, seed_value = 160, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:18:07.806000] current iteration 61 / 2000
# name = model_20_reg_3_iter_61, n_topics = 20, n_doc_passes = 5, seed_value = 161, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:18:16.374000] current iteration 62 / 2000
# name = model_20_reg_3_iter_62, n_topics = 20, n_doc_passes = 5, seed_value = 162, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:18:24.890000] current iteration 63 / 2000
# name = model_20_reg_3_iter_63, n_topics = 20, n_doc_passes = 5, seed_value = 163, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:18:33.483000] current iteration 64 / 2000
# name = model_20_reg_3_iter_64, n_topics = 20, n_doc_passes = 5, seed_value = 164, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:18:42.139000] current iteration 65 / 2000
# name = model_20_reg_3_iter_65, n_topics = 20, n_doc_passes = 5, seed_value = 165, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:18:50.799000] current iteration 66 / 2000
# name = model_20_reg_3_iter_66, n_topics = 20, n_doc_passes = 5, seed_value = 166, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:18:59.341000] current iteration 67 / 2000
# name = model_20_reg_3_iter_67, n_topics = 20, n_doc_passes = 5, seed_value = 167, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:19:08.202000] current iteration 68 / 2000
# name = model_20_reg_3_iter_68, n_topics = 20, n_doc_passes = 5, seed_value = 168, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:19:16.809000] current iteration 69 / 2000
# name = model_20_reg_3_iter_69, n_topics = 20, n_doc_passes = 5, seed_value = 169, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:19:25.481000] current iteration 70 / 2000
# name = model_20_reg_3_iter_70, n_topics = 20, n_doc_passes = 5, seed_value = 170, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:19:34.154000] current iteration 71 / 2000
# name = model_20_reg_3_iter_71, n_topics = 20, n_doc_passes = 5, seed_value = 171, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:19:42.840000] current iteration 72 / 2000
# name = model_20_reg_3_iter_72, n_topics = 20, n_doc_passes = 5, seed_value = 172, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:19:51.481000] current iteration 73 / 2000
# name = model_20_reg_3_iter_73, n_topics = 20, n_doc_passes = 5, seed_value = 173, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:20:00.574000] current iteration 74 / 2000
# name = model_20_reg_3_iter_74, n_topics = 20, n_doc_passes = 5, seed_value = 174, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:20:09.589000] current iteration 75 / 2000
# name = model_20_reg_3_iter_75, n_topics = 20, n_doc_passes = 5, seed_value = 175, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:20:18.479000] current iteration 76 / 2000
# name = model_20_reg_3_iter_76, n_topics = 20, n_doc_passes = 5, seed_value = 176, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:20:27.634000] current iteration 77 / 2000
# name = model_20_reg_3_iter_77, n_topics = 20, n_doc_passes = 5, seed_value = 177, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:20:38.399000] current iteration 78 / 2000
# name = model_20_reg_3_iter_78, n_topics = 20, n_doc_passes = 5, seed_value = 178, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:20:47.181000] current iteration 79 / 2000
# name = model_20_reg_3_iter_79, n_topics = 20, n_doc_passes = 5, seed_value = 179, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:20:56.197000] current iteration 80 / 2000
# name = model_20_reg_3_iter_80, n_topics = 20, n_doc_passes = 5, seed_value = 180, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:21:05.149000] current iteration 81 / 2000
# name = model_20_reg_3_iter_81, n_topics = 20, n_doc_passes = 5, seed_value = 181, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:21:14.679000] current iteration 82 / 2000
# name = model_20_reg_3_iter_82, n_topics = 20, n_doc_passes = 5, seed_value = 182, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:21:23.851000] current iteration 83 / 2000
# name = model_20_reg_3_iter_83, n_topics = 20, n_doc_passes = 5, seed_value = 183, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:21:32.758000] current iteration 84 / 2000
# name = model_20_reg_3_iter_84, n_topics = 20, n_doc_passes = 5, seed_value = 184, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:21:41.319000] current iteration 85 / 2000
# name = model_20_reg_3_iter_85, n_topics = 20, n_doc_passes = 5, seed_value = 185, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:21:50.236000] current iteration 86 / 2000
# name = model_20_reg_3_iter_86, n_topics = 20, n_doc_passes = 5, seed_value = 186, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:21:59.335000] current iteration 87 / 2000
# name = model_20_reg_3_iter_87, n_topics = 20, n_doc_passes = 5, seed_value = 187, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:22:08.247000] current iteration 88 / 2000
# name = model_20_reg_3_iter_88, n_topics = 20, n_doc_passes = 5, seed_value = 188, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:22:17.145000] current iteration 89 / 2000
# name = model_20_reg_3_iter_89, n_topics = 20, n_doc_passes = 5, seed_value = 189, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:22:25.963000] current iteration 90 / 2000
# name = model_20_reg_3_iter_90, n_topics = 20, n_doc_passes = 5, seed_value = 190, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:22:35.067000] current iteration 91 / 2000
# name = model_20_reg_3_iter_91, n_topics = 20, n_doc_passes = 5, seed_value = 191, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:22:44.239000] current iteration 92 / 2000
# name = model_20_reg_3_iter_92, n_topics = 20, n_doc_passes = 5, seed_value = 192, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:22:53.367000] current iteration 93 / 2000
# name = model_20_reg_3_iter_93, n_topics = 20, n_doc_passes = 5, seed_value = 193, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:23:02.265000] current iteration 94 / 2000
# name = model_20_reg_3_iter_94, n_topics = 20, n_doc_passes = 5, seed_value = 194, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:23:10.816000] current iteration 95 / 2000
# name = model_20_reg_3_iter_95, n_topics = 20, n_doc_passes = 5, seed_value = 195, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:23:19.486000] current iteration 96 / 2000
# name = model_20_reg_3_iter_96, n_topics = 20, n_doc_passes = 5, seed_value = 196, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:23:28.378000] current iteration 97 / 2000
# name = model_20_reg_3_iter_97, n_topics = 20, n_doc_passes = 5, seed_value = 197, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:23:37.050000] current iteration 98 / 2000
# name = model_20_reg_3_iter_98, n_topics = 20, n_doc_passes = 5, seed_value = 198, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:23:45.816000] current iteration 99 / 2000
# name = model_20_reg_3_iter_99, n_topics = 20, n_doc_passes = 5, seed_value = 199, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:23:54.611000] current iteration 100 / 2000
# name = model_20_reg_3_iter_100, n_topics = 20, n_doc_passes = 5, seed_value = 200, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:24:03.330000] current iteration 101 / 2000
# name = model_20_reg_3_iter_101, n_topics = 20, n_doc_passes = 5, seed_value = 201, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:24:12.205000] current iteration 102 / 2000
# name = model_20_reg_3_iter_102, n_topics = 20, n_doc_passes = 5, seed_value = 202, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:24:21.126000] current iteration 103 / 2000
# name = model_20_reg_3_iter_103, n_topics = 20, n_doc_passes = 5, seed_value = 203, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:24:30.034000] current iteration 104 / 2000
# name = model_20_reg_3_iter_104, n_topics = 20, n_doc_passes = 5, seed_value = 204, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:24:38.829000] current iteration 105 / 2000
# name = model_20_reg_3_iter_105, n_topics = 20, n_doc_passes = 5, seed_value = 205, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:24:47.829000] current iteration 106 / 2000
# name = model_20_reg_3_iter_106, n_topics = 20, n_doc_passes = 5, seed_value = 206, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:24:57.220000] current iteration 107 / 2000
# name = model_20_reg_3_iter_107, n_topics = 20, n_doc_passes = 5, seed_value = 207, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:25:07.530000] current iteration 108 / 2000
# name = model_20_reg_3_iter_108, n_topics = 20, n_doc_passes = 5, seed_value = 208, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:25:16.638000] current iteration 109 / 2000
# name = model_20_reg_3_iter_109, n_topics = 20, n_doc_passes = 5, seed_value = 209, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:25:27.105000] current iteration 110 / 2000
# name = model_20_reg_3_iter_110, n_topics = 20, n_doc_passes = 5, seed_value = 210, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:25:36.030000] current iteration 111 / 2000
# name = model_20_reg_3_iter_111, n_topics = 20, n_doc_passes = 5, seed_value = 211, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:25:45.206000] current iteration 112 / 2000
# name = model_20_reg_3_iter_112, n_topics = 20, n_doc_passes = 5, seed_value = 212, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:25:54.287000] current iteration 113 / 2000
# name = model_20_reg_3_iter_113, n_topics = 20, n_doc_passes = 5, seed_value = 213, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:26:03.643000] current iteration 114 / 2000
# name = model_20_reg_3_iter_114, n_topics = 20, n_doc_passes = 5, seed_value = 214, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:26:12.610000] current iteration 115 / 2000
# name = model_20_reg_3_iter_115, n_topics = 20, n_doc_passes = 5, seed_value = 215, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:26:21.109000] current iteration 116 / 2000
# name = model_20_reg_3_iter_116, n_topics = 20, n_doc_passes = 5, seed_value = 216, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:26:30.129000] current iteration 117 / 2000
# name = model_20_reg_3_iter_117, n_topics = 20, n_doc_passes = 5, seed_value = 217, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:26:39.377000] current iteration 118 / 2000
# name = model_20_reg_3_iter_118, n_topics = 20, n_doc_passes = 5, seed_value = 218, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:26:48.555000] current iteration 119 / 2000
# name = model_20_reg_3_iter_119, n_topics = 20, n_doc_passes = 5, seed_value = 219, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:26:58.030000] current iteration 120 / 2000
# name = model_20_reg_3_iter_120, n_topics = 20, n_doc_passes = 5, seed_value = 220, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:27:07.301000] current iteration 121 / 2000
# name = model_20_reg_3_iter_121, n_topics = 20, n_doc_passes = 5, seed_value = 221, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:27:16.864000] current iteration 122 / 2000
# name = model_20_reg_3_iter_122, n_topics = 20, n_doc_passes = 5, seed_value = 222, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:27:26.213000] current iteration 123 / 2000
# name = model_20_reg_3_iter_123, n_topics = 20, n_doc_passes = 5, seed_value = 223, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:27:36.526000] current iteration 124 / 2000
# name = model_20_reg_3_iter_124, n_topics = 20, n_doc_passes = 5, seed_value = 224, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:27:45.415000] current iteration 125 / 2000
# name = model_20_reg_3_iter_125, n_topics = 20, n_doc_passes = 5, seed_value = 225, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:27:55.147000] current iteration 126 / 2000
# name = model_20_reg_3_iter_126, n_topics = 20, n_doc_passes = 5, seed_value = 226, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:28:05.571000] current iteration 127 / 2000
# name = model_20_reg_3_iter_127, n_topics = 20, n_doc_passes = 5, seed_value = 227, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:28:16.220000] current iteration 128 / 2000
# name = model_20_reg_3_iter_128, n_topics = 20, n_doc_passes = 5, seed_value = 228, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:28:26.172000] current iteration 129 / 2000
# name = model_20_reg_3_iter_129, n_topics = 20, n_doc_passes = 5, seed_value = 229, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:28:35.165000] current iteration 130 / 2000
# name = model_20_reg_3_iter_130, n_topics = 20, n_doc_passes = 5, seed_value = 230, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:28:43.962000] current iteration 131 / 2000
# name = model_20_reg_3_iter_131, n_topics = 20, n_doc_passes = 5, seed_value = 231, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:28:53.452000] current iteration 132 / 2000
# name = model_20_reg_3_iter_132, n_topics = 20, n_doc_passes = 5, seed_value = 232, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:29:02.897000] current iteration 133 / 2000
# name = model_20_reg_3_iter_133, n_topics = 20, n_doc_passes = 5, seed_value = 233, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:29:11.661000] current iteration 134 / 2000
# name = model_20_reg_3_iter_134, n_topics = 20, n_doc_passes = 5, seed_value = 234, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:29:20.361000] current iteration 135 / 2000
# name = model_20_reg_3_iter_135, n_topics = 20, n_doc_passes = 5, seed_value = 235, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:29:29.260000] current iteration 136 / 2000
# name = model_20_reg_3_iter_136, n_topics = 20, n_doc_passes = 5, seed_value = 236, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:29:37.966000] current iteration 137 / 2000
# name = model_20_reg_3_iter_137, n_topics = 20, n_doc_passes = 5, seed_value = 237, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:29:46.785000] current iteration 138 / 2000
# name = model_20_reg_3_iter_138, n_topics = 20, n_doc_passes = 5, seed_value = 238, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:29:56.198000] current iteration 139 / 2000
# name = model_20_reg_3_iter_139, n_topics = 20, n_doc_passes = 5, seed_value = 239, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:30:05.056000] current iteration 140 / 2000
# name = model_20_reg_3_iter_140, n_topics = 20, n_doc_passes = 5, seed_value = 240, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:30:13.728000] current iteration 141 / 2000
# name = model_20_reg_3_iter_141, n_topics = 20, n_doc_passes = 5, seed_value = 241, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:30:22.400000] current iteration 142 / 2000
# name = model_20_reg_3_iter_142, n_topics = 20, n_doc_passes = 5, seed_value = 242, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:30:31.325000] current iteration 143 / 2000
# name = model_20_reg_3_iter_143, n_topics = 20, n_doc_passes = 5, seed_value = 243, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:30:40.252000] current iteration 144 / 2000
# name = model_20_reg_3_iter_144, n_topics = 20, n_doc_passes = 5, seed_value = 244, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:30:49.326000] current iteration 145 / 2000
# name = model_20_reg_3_iter_145, n_topics = 20, n_doc_passes = 5, seed_value = 245, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:30:58.395000] current iteration 146 / 2000
# name = model_20_reg_3_iter_146, n_topics = 20, n_doc_passes = 5, seed_value = 246, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:31:07.314000] current iteration 147 / 2000
# name = model_20_reg_3_iter_147, n_topics = 20, n_doc_passes = 5, seed_value = 247, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:31:16.331000] current iteration 148 / 2000
# name = model_20_reg_3_iter_148, n_topics = 20, n_doc_passes = 5, seed_value = 248, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:31:25.205000] current iteration 149 / 2000
# name = model_20_reg_3_iter_149, n_topics = 20, n_doc_passes = 5, seed_value = 249, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:31:34.460000] current iteration 150 / 2000
# name = model_20_reg_3_iter_150, n_topics = 20, n_doc_passes = 5, seed_value = 250, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:31:43.315000] current iteration 151 / 2000
# name = model_20_reg_3_iter_151, n_topics = 20, n_doc_passes = 5, seed_value = 251, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:31:52.320000] current iteration 152 / 2000
# name = model_20_reg_3_iter_152, n_topics = 20, n_doc_passes = 5, seed_value = 252, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:32:01.216000] current iteration 153 / 2000
# name = model_20_reg_3_iter_153, n_topics = 20, n_doc_passes = 5, seed_value = 253, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:32:10.148000] current iteration 154 / 2000
# name = model_20_reg_3_iter_154, n_topics = 20, n_doc_passes = 5, seed_value = 254, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:32:18.966000] current iteration 155 / 2000
# name = model_20_reg_3_iter_155, n_topics = 20, n_doc_passes = 5, seed_value = 255, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:32:27.764000] current iteration 156 / 2000
# name = model_20_reg_3_iter_156, n_topics = 20, n_doc_passes = 5, seed_value = 256, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:32:36.723000] current iteration 157 / 2000
# name = model_20_reg_3_iter_157, n_topics = 20, n_doc_passes = 5, seed_value = 257, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:32:45.371000] current iteration 158 / 2000
# name = model_20_reg_3_iter_158, n_topics = 20, n_doc_passes = 5, seed_value = 258, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:32:54.145000] current iteration 159 / 2000
# name = model_20_reg_3_iter_159, n_topics = 20, n_doc_passes = 5, seed_value = 259, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:33:03.739000] current iteration 160 / 2000
# name = model_20_reg_3_iter_160, n_topics = 20, n_doc_passes = 5, seed_value = 260, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:33:12.421000] current iteration 161 / 2000
# name = model_20_reg_3_iter_161, n_topics = 20, n_doc_passes = 5, seed_value = 261, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:33:21.640000] current iteration 162 / 2000
# name = model_20_reg_3_iter_162, n_topics = 20, n_doc_passes = 5, seed_value = 262, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:33:31.317000] current iteration 163 / 2000
# name = model_20_reg_3_iter_163, n_topics = 20, n_doc_passes = 5, seed_value = 263, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:33:40.008000] current iteration 164 / 2000
# name = model_20_reg_3_iter_164, n_topics = 20, n_doc_passes = 5, seed_value = 264, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:33:49.490000] current iteration 165 / 2000
# name = model_20_reg_3_iter_165, n_topics = 20, n_doc_passes = 5, seed_value = 265, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:34:00.010000] current iteration 166 / 2000
# name = model_20_reg_3_iter_166, n_topics = 20, n_doc_passes = 5, seed_value = 266, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:34:09.635000] current iteration 167 / 2000
# name = model_20_reg_3_iter_167, n_topics = 20, n_doc_passes = 5, seed_value = 267, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:34:19.170000] current iteration 168 / 2000
# name = model_20_reg_3_iter_168, n_topics = 20, n_doc_passes = 5, seed_value = 268, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:34:28.956000] current iteration 169 / 2000
# name = model_20_reg_3_iter_169, n_topics = 20, n_doc_passes = 5, seed_value = 269, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:34:38.782000] current iteration 170 / 2000
# name = model_20_reg_3_iter_170, n_topics = 20, n_doc_passes = 5, seed_value = 270, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:34:48.615000] current iteration 171 / 2000
# name = model_20_reg_3_iter_171, n_topics = 20, n_doc_passes = 5, seed_value = 271, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:34:58.712000] current iteration 172 / 2000
# name = model_20_reg_3_iter_172, n_topics = 20, n_doc_passes = 5, seed_value = 272, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:35:08.630000] current iteration 173 / 2000
# name = model_20_reg_3_iter_173, n_topics = 20, n_doc_passes = 5, seed_value = 273, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:35:17.700000] current iteration 174 / 2000
# name = model_20_reg_3_iter_174, n_topics = 20, n_doc_passes = 5, seed_value = 274, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:35:26.494000] current iteration 175 / 2000
# name = model_20_reg_3_iter_175, n_topics = 20, n_doc_passes = 5, seed_value = 275, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 10:35:35.668000] current iteration 176 / 2000
# name = model_20_reg_3_iter_176, n_topics = 20, n_doc_passes = 5, seed_value = 276, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ...
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:50:43.262000] current iteration 1943 / 2000
# name = model_20_reg_3_iter_1943, n_topics = 20, n_doc_passes = 5, seed_value = 2043, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:50:51.998000] current iteration 1944 / 2000
# name = model_20_reg_3_iter_1944, n_topics = 20, n_doc_passes = 5, seed_value = 2044, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:51:00.850000] current iteration 1945 / 2000
# name = model_20_reg_3_iter_1945, n_topics = 20, n_doc_passes = 5, seed_value = 2045, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:51:09.520000] current iteration 1946 / 2000
# name = model_20_reg_3_iter_1946, n_topics = 20, n_doc_passes = 5, seed_value = 2046, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:51:18.241000] current iteration 1947 / 2000
# name = model_20_reg_3_iter_1947, n_topics = 20, n_doc_passes = 5, seed_value = 2047, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:51:26.976000] current iteration 1948 / 2000
# name = model_20_reg_3_iter_1948, n_topics = 20, n_doc_passes = 5, seed_value = 2048, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:51:35.645000] current iteration 1949 / 2000
# name = model_20_reg_3_iter_1949, n_topics = 20, n_doc_passes = 5, seed_value = 2049, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:51:44.349000] current iteration 1950 / 2000
# name = model_20_reg_3_iter_1950, n_topics = 20, n_doc_passes = 5, seed_value = 2050, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:51:52.987000] current iteration 1951 / 2000
# name = model_20_reg_3_iter_1951, n_topics = 20, n_doc_passes = 5, seed_value = 2051, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:52:01.724000] current iteration 1952 / 2000
# name = model_20_reg_3_iter_1952, n_topics = 20, n_doc_passes = 5, seed_value = 2052, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:52:10.364000] current iteration 1953 / 2000
# name = model_20_reg_3_iter_1953, n_topics = 20, n_doc_passes = 5, seed_value = 2053, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:52:19.298000] current iteration 1954 / 2000
# name = model_20_reg_3_iter_1954, n_topics = 20, n_doc_passes = 5, seed_value = 2054, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:52:28.428000] current iteration 1955 / 2000
# name = model_20_reg_3_iter_1955, n_topics = 20, n_doc_passes = 5, seed_value = 2055, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:52:37.436000] current iteration 1956 / 2000
# name = model_20_reg_3_iter_1956, n_topics = 20, n_doc_passes = 5, seed_value = 2056, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:52:46.359000] current iteration 1957 / 2000
# name = model_20_reg_3_iter_1957, n_topics = 20, n_doc_passes = 5, seed_value = 2057, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:52:55.455000] current iteration 1958 / 2000
# name = model_20_reg_3_iter_1958, n_topics = 20, n_doc_passes = 5, seed_value = 2058, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:53:04.177000] current iteration 1959 / 2000
# name = model_20_reg_3_iter_1959, n_topics = 20, n_doc_passes = 5, seed_value = 2059, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:53:13.017000] current iteration 1960 / 2000
# name = model_20_reg_3_iter_1960, n_topics = 20, n_doc_passes = 5, seed_value = 2060, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:53:22.211000] current iteration 1961 / 2000
# name = model_20_reg_3_iter_1961, n_topics = 20, n_doc_passes = 5, seed_value = 2061, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:53:31.298000] current iteration 1962 / 2000
# name = model_20_reg_3_iter_1962, n_topics = 20, n_doc_passes = 5, seed_value = 2062, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:53:40.155000] current iteration 1963 / 2000
# name = model_20_reg_3_iter_1963, n_topics = 20, n_doc_passes = 5, seed_value = 2063, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:53:49.197000] current iteration 1964 / 2000
# name = model_20_reg_3_iter_1964, n_topics = 20, n_doc_passes = 5, seed_value = 2064, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:53:58.038000] current iteration 1965 / 2000
# name = model_20_reg_3_iter_1965, n_topics = 20, n_doc_passes = 5, seed_value = 2065, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:54:06.859000] current iteration 1966 / 2000
# name = model_20_reg_3_iter_1966, n_topics = 20, n_doc_passes = 5, seed_value = 2066, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:54:15.513000] current iteration 1967 / 2000
# name = model_20_reg_3_iter_1967, n_topics = 20, n_doc_passes = 5, seed_value = 2067, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:54:24.584000] current iteration 1968 / 2000
# name = model_20_reg_3_iter_1968, n_topics = 20, n_doc_passes = 5, seed_value = 2068, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:54:33.601000] current iteration 1969 / 2000
# name = model_20_reg_3_iter_1969, n_topics = 20, n_doc_passes = 5, seed_value = 2069, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:54:42.407000] current iteration 1970 / 2000
# name = model_20_reg_3_iter_1970, n_topics = 20, n_doc_passes = 5, seed_value = 2070, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:54:51.283000] current iteration 1971 / 2000
# name = model_20_reg_3_iter_1971, n_topics = 20, n_doc_passes = 5, seed_value = 2071, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:55:00.152000] current iteration 1972 / 2000
# name = model_20_reg_3_iter_1972, n_topics = 20, n_doc_passes = 5, seed_value = 2072, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:55:08.966000] current iteration 1973 / 2000
# name = model_20_reg_3_iter_1973, n_topics = 20, n_doc_passes = 5, seed_value = 2073, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:55:17.633000] current iteration 1974 / 2000
# name = model_20_reg_3_iter_1974, n_topics = 20, n_doc_passes = 5, seed_value = 2074, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:55:26.769000] current iteration 1975 / 2000
# name = model_20_reg_3_iter_1975, n_topics = 20, n_doc_passes = 5, seed_value = 2075, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:55:35.806000] current iteration 1976 / 2000
# name = model_20_reg_3_iter_1976, n_topics = 20, n_doc_passes = 5, seed_value = 2076, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:55:44.724000] current iteration 1977 / 2000
# name = model_20_reg_3_iter_1977, n_topics = 20, n_doc_passes = 5, seed_value = 2077, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:55:53.563000] current iteration 1978 / 2000
# name = model_20_reg_3_iter_1978, n_topics = 20, n_doc_passes = 5, seed_value = 2078, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:56:02.717000] current iteration 1979 / 2000
# name = model_20_reg_3_iter_1979, n_topics = 20, n_doc_passes = 5, seed_value = 2079, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:56:11.677000] current iteration 1980 / 2000
# name = model_20_reg_3_iter_1980, n_topics = 20, n_doc_passes = 5, seed_value = 2080, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:56:20.460000] current iteration 1981 / 2000
# name = model_20_reg_3_iter_1981, n_topics = 20, n_doc_passes = 5, seed_value = 2081, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:56:29.707000] current iteration 1982 / 2000
# name = model_20_reg_3_iter_1982, n_topics = 20, n_doc_passes = 5, seed_value = 2082, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:56:38.648000] current iteration 1983 / 2000
# name = model_20_reg_3_iter_1983, n_topics = 20, n_doc_passes = 5, seed_value = 2083, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:56:47.561000] current iteration 1984 / 2000
# name = model_20_reg_3_iter_1984, n_topics = 20, n_doc_passes = 5, seed_value = 2084, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:56:56.273000] current iteration 1985 / 2000
# name = model_20_reg_3_iter_1985, n_topics = 20, n_doc_passes = 5, seed_value = 2085, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:57:05.202000] current iteration 1986 / 2000
# name = model_20_reg_3_iter_1986, n_topics = 20, n_doc_passes = 5, seed_value = 2086, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:57:14.124000] current iteration 1987 / 2000
# name = model_20_reg_3_iter_1987, n_topics = 20, n_doc_passes = 5, seed_value = 2087, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:57:23.192000] current iteration 1988 / 2000
# name = model_20_reg_3_iter_1988, n_topics = 20, n_doc_passes = 5, seed_value = 2088, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:57:32.110000] current iteration 1989 / 2000
# name = model_20_reg_3_iter_1989, n_topics = 20, n_doc_passes = 5, seed_value = 2089, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:57:40.989000] current iteration 1990 / 2000
# name = model_20_reg_3_iter_1990, n_topics = 20, n_doc_passes = 5, seed_value = 2090, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:57:50.329000] current iteration 1991 / 2000
# name = model_20_reg_3_iter_1991, n_topics = 20, n_doc_passes = 5, seed_value = 2091, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:57:59.410000] current iteration 1992 / 2000
# name = model_20_reg_3_iter_1992, n_topics = 20, n_doc_passes = 5, seed_value = 2092, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:58:08.558000] current iteration 1993 / 2000
# name = model_20_reg_3_iter_1993, n_topics = 20, n_doc_passes = 5, seed_value = 2093, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:58:17.530000] current iteration 1994 / 2000
# name = model_20_reg_3_iter_1994, n_topics = 20, n_doc_passes = 5, seed_value = 2094, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:58:26.269000] current iteration 1995 / 2000
# name = model_20_reg_3_iter_1995, n_topics = 20, n_doc_passes = 5, seed_value = 2095, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:58:35.054000] current iteration 1996 / 2000
# name = model_20_reg_3_iter_1996, n_topics = 20, n_doc_passes = 5, seed_value = 2096, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:58:43.865000] current iteration 1997 / 2000
# name = model_20_reg_3_iter_1997, n_topics = 20, n_doc_passes = 5, seed_value = 2097, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:58:52.840000] current iteration 1998 / 2000
# name = model_20_reg_3_iter_1998, n_topics = 20, n_doc_passes = 5, seed_value = 2098, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:59:01.934000] current iteration 1999 / 2000
# name = model_20_reg_3_iter_1999, n_topics = 20, n_doc_passes = 5, seed_value = 2099, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -10
# ss_phi_regularizer, tau = -10
#
# [2017-03-09 15:59:10.905000] current iteration 2000 / 2000

# %%
tmp_models_range = create_models_range(create_model_fn_20_reg_6, 'model_reg6')
# Out:
# name = model_20_reg_6_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:22:08.513000] current iteration 1 / 2000
# name = model_20_reg_6_iter_1, n_topics = 20, n_doc_passes = 5, seed_value = 101, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:22:17.139000] current iteration 2 / 2000
# name = model_20_reg_6_iter_2, n_topics = 20, n_doc_passes = 5, seed_value = 102, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:22:25.341000] current iteration 3 / 2000
# name = model_20_reg_6_iter_3, n_topics = 20, n_doc_passes = 5, seed_value = 103, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:22:33.982000] current iteration 4 / 2000
# name = model_20_reg_6_iter_4, n_topics = 20, n_doc_passes = 5, seed_value = 104, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:22:42.164000] current iteration 5 / 2000
# name = model_20_reg_6_iter_5, n_topics = 20, n_doc_passes = 5, seed_value = 105, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:22:50.734000] current iteration 6 / 2000
# name = model_20_reg_6_iter_6, n_topics = 20, n_doc_passes = 5, seed_value = 106, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:22:59.208000] current iteration 7 / 2000
# name = model_20_reg_6_iter_7, n_topics = 20, n_doc_passes = 5, seed_value = 107, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:23:07.672000] current iteration 8 / 2000
# name = model_20_reg_6_iter_8, n_topics = 20, n_doc_passes = 5, seed_value = 108, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:23:15.792000] current iteration 9 / 2000
# name = model_20_reg_6_iter_9, n_topics = 20, n_doc_passes = 5, seed_value = 109, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:23:23.944000] current iteration 10 / 2000
# name = model_20_reg_6_iter_10, n_topics = 20, n_doc_passes = 5, seed_value = 110, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:23:32.112000] current iteration 11 / 2000
# name = model_20_reg_6_iter_11, n_topics = 20, n_doc_passes = 5, seed_value = 111, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:23:40.261000] current iteration 12 / 2000
# name = model_20_reg_6_iter_12, n_topics = 20, n_doc_passes = 5, seed_value = 112, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:23:48.309000] current iteration 13 / 2000
# name = model_20_reg_6_iter_13, n_topics = 20, n_doc_passes = 5, seed_value = 113, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:23:56.312000] current iteration 14 / 2000
# name = model_20_reg_6_iter_14, n_topics = 20, n_doc_passes = 5, seed_value = 114, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:24:04.304000] current iteration 15 / 2000
# name = model_20_reg_6_iter_15, n_topics = 20, n_doc_passes = 5, seed_value = 115, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:24:12.432000] current iteration 16 / 2000
# name = model_20_reg_6_iter_16, n_topics = 20, n_doc_passes = 5, seed_value = 116, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:24:20.225000] current iteration 17 / 2000
# name = model_20_reg_6_iter_17, n_topics = 20, n_doc_passes = 5, seed_value = 117, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:24:27.986000] current iteration 18 / 2000
# name = model_20_reg_6_iter_18, n_topics = 20, n_doc_passes = 5, seed_value = 118, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:24:35.993000] current iteration 19 / 2000
# name = model_20_reg_6_iter_19, n_topics = 20, n_doc_passes = 5, seed_value = 119, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:24:43.916000] current iteration 20 / 2000
# name = model_20_reg_6_iter_20, n_topics = 20, n_doc_passes = 5, seed_value = 120, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:24:51.843000] current iteration 21 / 2000
# name = model_20_reg_6_iter_21, n_topics = 20, n_doc_passes = 5, seed_value = 121, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:24:59.974000] current iteration 22 / 2000
# name = model_20_reg_6_iter_22, n_topics = 20, n_doc_passes = 5, seed_value = 122, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:25:08.108000] current iteration 23 / 2000
# name = model_20_reg_6_iter_23, n_topics = 20, n_doc_passes = 5, seed_value = 123, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:25:16.193000] current iteration 24 / 2000
# name = model_20_reg_6_iter_24, n_topics = 20, n_doc_passes = 5, seed_value = 124, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:25:24.319000] current iteration 25 / 2000
# name = model_20_reg_6_iter_25, n_topics = 20, n_doc_passes = 5, seed_value = 125, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:25:32.274000] current iteration 26 / 2000
# name = model_20_reg_6_iter_26, n_topics = 20, n_doc_passes = 5, seed_value = 126, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:25:40.307000] current iteration 27 / 2000
# name = model_20_reg_6_iter_27, n_topics = 20, n_doc_passes = 5, seed_value = 127, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:25:48.688000] current iteration 28 / 2000
# name = model_20_reg_6_iter_28, n_topics = 20, n_doc_passes = 5, seed_value = 128, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:25:56.614000] current iteration 29 / 2000
# name = model_20_reg_6_iter_29, n_topics = 20, n_doc_passes = 5, seed_value = 129, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:26:04.619000] current iteration 30 / 2000
# name = model_20_reg_6_iter_30, n_topics = 20, n_doc_passes = 5, seed_value = 130, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:26:12.532000] current iteration 31 / 2000
# name = model_20_reg_6_iter_31, n_topics = 20, n_doc_passes = 5, seed_value = 131, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:26:20.531000] current iteration 32 / 2000
# name = model_20_reg_6_iter_32, n_topics = 20, n_doc_passes = 5, seed_value = 132, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:26:28.815000] current iteration 33 / 2000
# name = model_20_reg_6_iter_33, n_topics = 20, n_doc_passes = 5, seed_value = 133, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:26:37.153000] current iteration 34 / 2000
# name = model_20_reg_6_iter_34, n_topics = 20, n_doc_passes = 5, seed_value = 134, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:26:45.305000] current iteration 35 / 2000
# name = model_20_reg_6_iter_35, n_topics = 20, n_doc_passes = 5, seed_value = 135, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:26:53.278000] current iteration 36 / 2000
# name = model_20_reg_6_iter_36, n_topics = 20, n_doc_passes = 5, seed_value = 136, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:27:01.496000] current iteration 37 / 2000
# name = model_20_reg_6_iter_37, n_topics = 20, n_doc_passes = 5, seed_value = 137, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:27:09.696000] current iteration 38 / 2000
# name = model_20_reg_6_iter_38, n_topics = 20, n_doc_passes = 5, seed_value = 138, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:27:17.602000] current iteration 39 / 2000
# name = model_20_reg_6_iter_39, n_topics = 20, n_doc_passes = 5, seed_value = 139, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:27:25.734000] current iteration 40 / 2000
# name = model_20_reg_6_iter_40, n_topics = 20, n_doc_passes = 5, seed_value = 140, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:27:34.135000] current iteration 41 / 2000
# name = model_20_reg_6_iter_41, n_topics = 20, n_doc_passes = 5, seed_value = 141, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:27:42.287000] current iteration 42 / 2000
# name = model_20_reg_6_iter_42, n_topics = 20, n_doc_passes = 5, seed_value = 142, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:27:50.378000] current iteration 43 / 2000
# name = model_20_reg_6_iter_43, n_topics = 20, n_doc_passes = 5, seed_value = 143, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:27:58.611000] current iteration 44 / 2000
# name = model_20_reg_6_iter_44, n_topics = 20, n_doc_passes = 5, seed_value = 144, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:28:06.737000] current iteration 45 / 2000
# name = model_20_reg_6_iter_45, n_topics = 20, n_doc_passes = 5, seed_value = 145, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:28:14.727000] current iteration 46 / 2000
# name = model_20_reg_6_iter_46, n_topics = 20, n_doc_passes = 5, seed_value = 146, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:28:22.818000] current iteration 47 / 2000
# name = model_20_reg_6_iter_47, n_topics = 20, n_doc_passes = 5, seed_value = 147, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:28:30.779000] current iteration 48 / 2000
# name = model_20_reg_6_iter_48, n_topics = 20, n_doc_passes = 5, seed_value = 148, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:28:38.675000] current iteration 49 / 2000
# name = model_20_reg_6_iter_49, n_topics = 20, n_doc_passes = 5, seed_value = 149, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:28:46.789000] current iteration 50 / 2000
# name = model_20_reg_6_iter_50, n_topics = 20, n_doc_passes = 5, seed_value = 150, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:28:54.738000] current iteration 51 / 2000
# name = model_20_reg_6_iter_51, n_topics = 20, n_doc_passes = 5, seed_value = 151, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:29:02.644000] current iteration 52 / 2000
# name = model_20_reg_6_iter_52, n_topics = 20, n_doc_passes = 5, seed_value = 152, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:29:10.650000] current iteration 53 / 2000
# name = model_20_reg_6_iter_53, n_topics = 20, n_doc_passes = 5, seed_value = 153, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:29:18.652000] current iteration 54 / 2000
# name = model_20_reg_6_iter_54, n_topics = 20, n_doc_passes = 5, seed_value = 154, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:29:26.786000] current iteration 55 / 2000
# name = model_20_reg_6_iter_55, n_topics = 20, n_doc_passes = 5, seed_value = 155, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:29:34.800000] current iteration 56 / 2000
# name = model_20_reg_6_iter_56, n_topics = 20, n_doc_passes = 5, seed_value = 156, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:29:42.664000] current iteration 57 / 2000
# name = model_20_reg_6_iter_57, n_topics = 20, n_doc_passes = 5, seed_value = 157, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:29:50.819000] current iteration 58 / 2000
# name = model_20_reg_6_iter_58, n_topics = 20, n_doc_passes = 5, seed_value = 158, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:29:58.837000] current iteration 59 / 2000
# name = model_20_reg_6_iter_59, n_topics = 20, n_doc_passes = 5, seed_value = 159, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:30:06.743000] current iteration 60 / 2000
# name = model_20_reg_6_iter_60, n_topics = 20, n_doc_passes = 5, seed_value = 160, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:30:14.846000] current iteration 61 / 2000
# name = model_20_reg_6_iter_61, n_topics = 20, n_doc_passes = 5, seed_value = 161, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:30:22.786000] current iteration 62 / 2000
# name = model_20_reg_6_iter_62, n_topics = 20, n_doc_passes = 5, seed_value = 162, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:30:30.877000] current iteration 63 / 2000
# name = model_20_reg_6_iter_63, n_topics = 20, n_doc_passes = 5, seed_value = 163, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:30:38.907000] current iteration 64 / 2000
# name = model_20_reg_6_iter_64, n_topics = 20, n_doc_passes = 5, seed_value = 164, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:30:47.239000] current iteration 65 / 2000
# name = model_20_reg_6_iter_65, n_topics = 20, n_doc_passes = 5, seed_value = 165, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:30:55.468000] current iteration 66 / 2000
# name = model_20_reg_6_iter_66, n_topics = 20, n_doc_passes = 5, seed_value = 166, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:31:03.665000] current iteration 67 / 2000
# name = model_20_reg_6_iter_67, n_topics = 20, n_doc_passes = 5, seed_value = 167, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:31:11.835000] current iteration 68 / 2000
# name = model_20_reg_6_iter_68, n_topics = 20, n_doc_passes = 5, seed_value = 168, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:31:19.710000] current iteration 69 / 2000
# name = model_20_reg_6_iter_69, n_topics = 20, n_doc_passes = 5, seed_value = 169, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:31:27.774000] current iteration 70 / 2000
# name = model_20_reg_6_iter_70, n_topics = 20, n_doc_passes = 5, seed_value = 170, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:31:35.940000] current iteration 71 / 2000
# name = model_20_reg_6_iter_71, n_topics = 20, n_doc_passes = 5, seed_value = 171, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:31:43.906000] current iteration 72 / 2000
# name = model_20_reg_6_iter_72, n_topics = 20, n_doc_passes = 5, seed_value = 172, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:31:51.901000] current iteration 73 / 2000
# name = model_20_reg_6_iter_73, n_topics = 20, n_doc_passes = 5, seed_value = 173, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:32:00.032000] current iteration 74 / 2000
# name = model_20_reg_6_iter_74, n_topics = 20, n_doc_passes = 5, seed_value = 174, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:32:08.142000] current iteration 75 / 2000
# name = model_20_reg_6_iter_75, n_topics = 20, n_doc_passes = 5, seed_value = 175, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:32:15.989000] current iteration 76 / 2000
# name = model_20_reg_6_iter_76, n_topics = 20, n_doc_passes = 5, seed_value = 176, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:32:24.150000] current iteration 77 / 2000
# name = model_20_reg_6_iter_77, n_topics = 20, n_doc_passes = 5, seed_value = 177, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:32:32.145000] current iteration 78 / 2000
# name = model_20_reg_6_iter_78, n_topics = 20, n_doc_passes = 5, seed_value = 178, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:32:40.264000] current iteration 79 / 2000
# name = model_20_reg_6_iter_79, n_topics = 20, n_doc_passes = 5, seed_value = 179, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:32:48.293000] current iteration 80 / 2000
# name = model_20_reg_6_iter_80, n_topics = 20, n_doc_passes = 5, seed_value = 180, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:32:56.478000] current iteration 81 / 2000
# name = model_20_reg_6_iter_81, n_topics = 20, n_doc_passes = 5, seed_value = 181, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:33:04.397000] current iteration 82 / 2000
# name = model_20_reg_6_iter_82, n_topics = 20, n_doc_passes = 5, seed_value = 182, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:33:12.346000] current iteration 83 / 2000
# name = model_20_reg_6_iter_83, n_topics = 20, n_doc_passes = 5, seed_value = 183, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:33:21.002000] current iteration 84 / 2000
# name = model_20_reg_6_iter_84, n_topics = 20, n_doc_passes = 5, seed_value = 184, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:33:29.326000] current iteration 85 / 2000
# name = model_20_reg_6_iter_85, n_topics = 20, n_doc_passes = 5, seed_value = 185, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:33:37.782000] current iteration 86 / 2000
# name = model_20_reg_6_iter_86, n_topics = 20, n_doc_passes = 5, seed_value = 186, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:33:45.861000] current iteration 87 / 2000
# name = model_20_reg_6_iter_87, n_topics = 20, n_doc_passes = 5, seed_value = 187, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:33:53.875000] current iteration 88 / 2000
# name = model_20_reg_6_iter_88, n_topics = 20, n_doc_passes = 5, seed_value = 188, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:34:01.953000] current iteration 89 / 2000
# name = model_20_reg_6_iter_89, n_topics = 20, n_doc_passes = 5, seed_value = 189, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:34:10.082000] current iteration 90 / 2000
# name = model_20_reg_6_iter_90, n_topics = 20, n_doc_passes = 5, seed_value = 190, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:34:18.357000] current iteration 91 / 2000
# name = model_20_reg_6_iter_91, n_topics = 20, n_doc_passes = 5, seed_value = 191, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:34:26.462000] current iteration 92 / 2000
# name = model_20_reg_6_iter_92, n_topics = 20, n_doc_passes = 5, seed_value = 192, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:34:34.475000] current iteration 93 / 2000
# name = model_20_reg_6_iter_93, n_topics = 20, n_doc_passes = 5, seed_value = 193, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:34:42.550000] current iteration 94 / 2000
# name = model_20_reg_6_iter_94, n_topics = 20, n_doc_passes = 5, seed_value = 194, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:34:50.656000] current iteration 95 / 2000
# name = model_20_reg_6_iter_95, n_topics = 20, n_doc_passes = 5, seed_value = 195, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:34:58.872000] current iteration 96 / 2000
# name = model_20_reg_6_iter_96, n_topics = 20, n_doc_passes = 5, seed_value = 196, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:35:06.831000] current iteration 97 / 2000
# name = model_20_reg_6_iter_97, n_topics = 20, n_doc_passes = 5, seed_value = 197, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:35:14.680000] current iteration 98 / 2000
# name = model_20_reg_6_iter_98, n_topics = 20, n_doc_passes = 5, seed_value = 198, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:35:22.799000] current iteration 99 / 2000
# name = model_20_reg_6_iter_99, n_topics = 20, n_doc_passes = 5, seed_value = 199, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:35:31.047000] current iteration 100 / 2000
# name = model_20_reg_6_iter_100, n_topics = 20, n_doc_passes = 5, seed_value = 200, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:35:39.201000] current iteration 101 / 2000
# name = model_20_reg_6_iter_101, n_topics = 20, n_doc_passes = 5, seed_value = 201, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:35:47.329000] current iteration 102 / 2000
# name = model_20_reg_6_iter_102, n_topics = 20, n_doc_passes = 5, seed_value = 202, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:35:55.208000] current iteration 103 / 2000
# name = model_20_reg_6_iter_103, n_topics = 20, n_doc_passes = 5, seed_value = 203, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:36:03.208000] current iteration 104 / 2000
# name = model_20_reg_6_iter_104, n_topics = 20, n_doc_passes = 5, seed_value = 204, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:36:11.247000] current iteration 105 / 2000
# name = model_20_reg_6_iter_105, n_topics = 20, n_doc_passes = 5, seed_value = 205, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:36:19.332000] current iteration 106 / 2000
# name = model_20_reg_6_iter_106, n_topics = 20, n_doc_passes = 5, seed_value = 206, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:36:27.317000] current iteration 107 / 2000
# name = model_20_reg_6_iter_107, n_topics = 20, n_doc_passes = 5, seed_value = 207, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:36:35.517000] current iteration 108 / 2000
# name = model_20_reg_6_iter_108, n_topics = 20, n_doc_passes = 5, seed_value = 208, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:36:43.482000] current iteration 109 / 2000
# name = model_20_reg_6_iter_109, n_topics = 20, n_doc_passes = 5, seed_value = 209, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:36:51.679000] current iteration 110 / 2000
# name = model_20_reg_6_iter_110, n_topics = 20, n_doc_passes = 5, seed_value = 210, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:36:59.816000] current iteration 111 / 2000
# name = model_20_reg_6_iter_111, n_topics = 20, n_doc_passes = 5, seed_value = 211, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:37:07.957000] current iteration 112 / 2000
# name = model_20_reg_6_iter_112, n_topics = 20, n_doc_passes = 5, seed_value = 212, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:37:16.198000] current iteration 113 / 2000
# name = model_20_reg_6_iter_113, n_topics = 20, n_doc_passes = 5, seed_value = 213, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:37:24.526000] current iteration 114 / 2000
# name = model_20_reg_6_iter_114, n_topics = 20, n_doc_passes = 5, seed_value = 214, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:37:32.981000] current iteration 115 / 2000
# name = model_20_reg_6_iter_115, n_topics = 20, n_doc_passes = 5, seed_value = 215, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:37:41.469000] current iteration 116 / 2000
# name = model_20_reg_6_iter_116, n_topics = 20, n_doc_passes = 5, seed_value = 216, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:37:50.199000] current iteration 117 / 2000
# name = model_20_reg_6_iter_117, n_topics = 20, n_doc_passes = 5, seed_value = 217, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:37:58.416000] current iteration 118 / 2000
# name = model_20_reg_6_iter_118, n_topics = 20, n_doc_passes = 5, seed_value = 218, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:38:06.652000] current iteration 119 / 2000
# name = model_20_reg_6_iter_119, n_topics = 20, n_doc_passes = 5, seed_value = 219, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:38:14.723000] current iteration 120 / 2000
# name = model_20_reg_6_iter_120, n_topics = 20, n_doc_passes = 5, seed_value = 220, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:38:23.364000] current iteration 121 / 2000
# name = model_20_reg_6_iter_121, n_topics = 20, n_doc_passes = 5, seed_value = 221, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:38:31.585000] current iteration 122 / 2000
# name = model_20_reg_6_iter_122, n_topics = 20, n_doc_passes = 5, seed_value = 222, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:38:39.693000] current iteration 123 / 2000
# name = model_20_reg_6_iter_123, n_topics = 20, n_doc_passes = 5, seed_value = 223, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:38:47.863000] current iteration 124 / 2000
# name = model_20_reg_6_iter_124, n_topics = 20, n_doc_passes = 5, seed_value = 224, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:38:55.965000] current iteration 125 / 2000
# name = model_20_reg_6_iter_125, n_topics = 20, n_doc_passes = 5, seed_value = 225, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:39:04.304000] current iteration 126 / 2000
# name = model_20_reg_6_iter_126, n_topics = 20, n_doc_passes = 5, seed_value = 226, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:39:12.485000] current iteration 127 / 2000
# name = model_20_reg_6_iter_127, n_topics = 20, n_doc_passes = 5, seed_value = 227, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:39:20.722000] current iteration 128 / 2000
# name = model_20_reg_6_iter_128, n_topics = 20, n_doc_passes = 5, seed_value = 228, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:39:29.086000] current iteration 129 / 2000
# name = model_20_reg_6_iter_129, n_topics = 20, n_doc_passes = 5, seed_value = 229, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:39:37.247000] current iteration 130 / 2000
# name = model_20_reg_6_iter_130, n_topics = 20, n_doc_passes = 5, seed_value = 230, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:39:45.377000] current iteration 131 / 2000
# name = model_20_reg_6_iter_131, n_topics = 20, n_doc_passes = 5, seed_value = 231, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:39:53.719000] current iteration 132 / 2000
# name = model_20_reg_6_iter_132, n_topics = 20, n_doc_passes = 5, seed_value = 232, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:40:01.801000] current iteration 133 / 2000
# name = model_20_reg_6_iter_133, n_topics = 20, n_doc_passes = 5, seed_value = 233, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:40:09.815000] current iteration 134 / 2000
# name = model_20_reg_6_iter_134, n_topics = 20, n_doc_passes = 5, seed_value = 234, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:40:17.720000] current iteration 135 / 2000
# name = model_20_reg_6_iter_135, n_topics = 20, n_doc_passes = 5, seed_value = 235, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:40:25.761000] current iteration 136 / 2000
# name = model_20_reg_6_iter_136, n_topics = 20, n_doc_passes = 5, seed_value = 236, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:40:33.833000] current iteration 137 / 2000
# name = model_20_reg_6_iter_137, n_topics = 20, n_doc_passes = 5, seed_value = 237, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:40:41.725000] current iteration 138 / 2000
# name = model_20_reg_6_iter_138, n_topics = 20, n_doc_passes = 5, seed_value = 238, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:40:49.866000] current iteration 139 / 2000
# name = model_20_reg_6_iter_139, n_topics = 20, n_doc_passes = 5, seed_value = 239, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:40:57.832000] current iteration 140 / 2000
# name = model_20_reg_6_iter_140, n_topics = 20, n_doc_passes = 5, seed_value = 240, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:41:05.862000] current iteration 141 / 2000
# name = model_20_reg_6_iter_141, n_topics = 20, n_doc_passes = 5, seed_value = 241, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:41:14.096000] current iteration 142 / 2000
# name = model_20_reg_6_iter_142, n_topics = 20, n_doc_passes = 5, seed_value = 242, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:41:22.309000] current iteration 143 / 2000
# name = model_20_reg_6_iter_143, n_topics = 20, n_doc_passes = 5, seed_value = 243, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:41:30.294000] current iteration 144 / 2000
# name = model_20_reg_6_iter_144, n_topics = 20, n_doc_passes = 5, seed_value = 244, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:41:38.315000] current iteration 145 / 2000
# name = model_20_reg_6_iter_145, n_topics = 20, n_doc_passes = 5, seed_value = 245, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:41:46.353000] current iteration 146 / 2000
# name = model_20_reg_6_iter_146, n_topics = 20, n_doc_passes = 5, seed_value = 246, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:41:54.416000] current iteration 147 / 2000
# name = model_20_reg_6_iter_147, n_topics = 20, n_doc_passes = 5, seed_value = 247, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:42:02.403000] current iteration 148 / 2000
# name = model_20_reg_6_iter_148, n_topics = 20, n_doc_passes = 5, seed_value = 248, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:42:10.426000] current iteration 149 / 2000
# name = model_20_reg_6_iter_149, n_topics = 20, n_doc_passes = 5, seed_value = 249, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:42:18.480000] current iteration 150 / 2000
# name = model_20_reg_6_iter_150, n_topics = 20, n_doc_passes = 5, seed_value = 250, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:42:26.485000] current iteration 151 / 2000
# name = model_20_reg_6_iter_151, n_topics = 20, n_doc_passes = 5, seed_value = 251, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:42:34.362000] current iteration 152 / 2000
# name = model_20_reg_6_iter_152, n_topics = 20, n_doc_passes = 5, seed_value = 252, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:42:42.550000] current iteration 153 / 2000
# name = model_20_reg_6_iter_153, n_topics = 20, n_doc_passes = 5, seed_value = 253, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:42:50.483000] current iteration 154 / 2000
# name = model_20_reg_6_iter_154, n_topics = 20, n_doc_passes = 5, seed_value = 254, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:42:58.573000] current iteration 155 / 2000
# name = model_20_reg_6_iter_155, n_topics = 20, n_doc_passes = 5, seed_value = 255, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:43:06.529000] current iteration 156 / 2000
# name = model_20_reg_6_iter_156, n_topics = 20, n_doc_passes = 5, seed_value = 256, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:43:14.547000] current iteration 157 / 2000
# name = model_20_reg_6_iter_157, n_topics = 20, n_doc_passes = 5, seed_value = 257, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:43:22.618000] current iteration 158 / 2000
# name = model_20_reg_6_iter_158, n_topics = 20, n_doc_passes = 5, seed_value = 258, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:43:30.667000] current iteration 159 / 2000
# name = model_20_reg_6_iter_159, n_topics = 20, n_doc_passes = 5, seed_value = 259, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:43:38.755000] current iteration 160 / 2000
# name = model_20_reg_6_iter_160, n_topics = 20, n_doc_passes = 5, seed_value = 260, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:43:46.876000] current iteration 161 / 2000
# name = model_20_reg_6_iter_161, n_topics = 20, n_doc_passes = 5, seed_value = 261, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:43:54.958000] current iteration 162 / 2000
# name = model_20_reg_6_iter_162, n_topics = 20, n_doc_passes = 5, seed_value = 262, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:44:02.958000] current iteration 163 / 2000
# name = model_20_reg_6_iter_163, n_topics = 20, n_doc_passes = 5, seed_value = 263, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:44:10.889000] current iteration 164 / 2000
# name = model_20_reg_6_iter_164, n_topics = 20, n_doc_passes = 5, seed_value = 264, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:44:18.847000] current iteration 165 / 2000
# name = model_20_reg_6_iter_165, n_topics = 20, n_doc_passes = 5, seed_value = 265, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:44:26.897000] current iteration 166 / 2000
# name = model_20_reg_6_iter_166, n_topics = 20, n_doc_passes = 5, seed_value = 266, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:44:35.025000] current iteration 167 / 2000
# name = model_20_reg_6_iter_167, n_topics = 20, n_doc_passes = 5, seed_value = 267, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:44:43.399000] current iteration 168 / 2000
# name = model_20_reg_6_iter_168, n_topics = 20, n_doc_passes = 5, seed_value = 268, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:44:51.609000] current iteration 169 / 2000
# name = model_20_reg_6_iter_169, n_topics = 20, n_doc_passes = 5, seed_value = 269, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:44:59.609000] current iteration 170 / 2000
# name = model_20_reg_6_iter_170, n_topics = 20, n_doc_passes = 5, seed_value = 270, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:45:07.714000] current iteration 171 / 2000
# name = model_20_reg_6_iter_171, n_topics = 20, n_doc_passes = 5, seed_value = 271, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:45:16.018000] current iteration 172 / 2000
# name = model_20_reg_6_iter_172, n_topics = 20, n_doc_passes = 5, seed_value = 272, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:45:23.990000] current iteration 173 / 2000
# name = model_20_reg_6_iter_173, n_topics = 20, n_doc_passes = 5, seed_value = 273, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:45:32.056000] current iteration 174 / 2000
# name = model_20_reg_6_iter_174, n_topics = 20, n_doc_passes = 5, seed_value = 274, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:45:40.140000] current iteration 175 / 2000
# name = model_20_reg_6_iter_175, n_topics = 20, n_doc_passes = 5, seed_value = 275, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 16:45:48.196000] current iteration 176 / 2000
# name = model_20_reg_6_iter_176, n_topics = 20, n_doc_passes = 5, seed_value = 276, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ...
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:45:00.300000] current iteration 1943 / 2000
# name = model_20_reg_6_iter_1943, n_topics = 20, n_doc_passes = 5, seed_value = 2043, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:45:08.161000] current iteration 1944 / 2000
# name = model_20_reg_6_iter_1944, n_topics = 20, n_doc_passes = 5, seed_value = 2044, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:45:16.135000] current iteration 1945 / 2000
# name = model_20_reg_6_iter_1945, n_topics = 20, n_doc_passes = 5, seed_value = 2045, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:45:24.099000] current iteration 1946 / 2000
# name = model_20_reg_6_iter_1946, n_topics = 20, n_doc_passes = 5, seed_value = 2046, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:45:32.115000] current iteration 1947 / 2000
# name = model_20_reg_6_iter_1947, n_topics = 20, n_doc_passes = 5, seed_value = 2047, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:45:40.087000] current iteration 1948 / 2000
# name = model_20_reg_6_iter_1948, n_topics = 20, n_doc_passes = 5, seed_value = 2048, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:45:47.886000] current iteration 1949 / 2000
# name = model_20_reg_6_iter_1949, n_topics = 20, n_doc_passes = 5, seed_value = 2049, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:45:55.859000] current iteration 1950 / 2000
# name = model_20_reg_6_iter_1950, n_topics = 20, n_doc_passes = 5, seed_value = 2050, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:46:03.846000] current iteration 1951 / 2000
# name = model_20_reg_6_iter_1951, n_topics = 20, n_doc_passes = 5, seed_value = 2051, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:46:11.694000] current iteration 1952 / 2000
# name = model_20_reg_6_iter_1952, n_topics = 20, n_doc_passes = 5, seed_value = 2052, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:46:19.461000] current iteration 1953 / 2000
# name = model_20_reg_6_iter_1953, n_topics = 20, n_doc_passes = 5, seed_value = 2053, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:46:27.481000] current iteration 1954 / 2000
# name = model_20_reg_6_iter_1954, n_topics = 20, n_doc_passes = 5, seed_value = 2054, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:46:35.546000] current iteration 1955 / 2000
# name = model_20_reg_6_iter_1955, n_topics = 20, n_doc_passes = 5, seed_value = 2055, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:46:43.344000] current iteration 1956 / 2000
# name = model_20_reg_6_iter_1956, n_topics = 20, n_doc_passes = 5, seed_value = 2056, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:46:51.302000] current iteration 1957 / 2000
# name = model_20_reg_6_iter_1957, n_topics = 20, n_doc_passes = 5, seed_value = 2057, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:46:59.085000] current iteration 1958 / 2000
# name = model_20_reg_6_iter_1958, n_topics = 20, n_doc_passes = 5, seed_value = 2058, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:47:06.899000] current iteration 1959 / 2000
# name = model_20_reg_6_iter_1959, n_topics = 20, n_doc_passes = 5, seed_value = 2059, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:47:14.762000] current iteration 1960 / 2000
# name = model_20_reg_6_iter_1960, n_topics = 20, n_doc_passes = 5, seed_value = 2060, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:47:22.770000] current iteration 1961 / 2000
# name = model_20_reg_6_iter_1961, n_topics = 20, n_doc_passes = 5, seed_value = 2061, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:47:30.760000] current iteration 1962 / 2000
# name = model_20_reg_6_iter_1962, n_topics = 20, n_doc_passes = 5, seed_value = 2062, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:47:38.618000] current iteration 1963 / 2000
# name = model_20_reg_6_iter_1963, n_topics = 20, n_doc_passes = 5, seed_value = 2063, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:47:46.372000] current iteration 1964 / 2000
# name = model_20_reg_6_iter_1964, n_topics = 20, n_doc_passes = 5, seed_value = 2064, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:47:54.203000] current iteration 1965 / 2000
# name = model_20_reg_6_iter_1965, n_topics = 20, n_doc_passes = 5, seed_value = 2065, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:48:02.017000] current iteration 1966 / 2000
# name = model_20_reg_6_iter_1966, n_topics = 20, n_doc_passes = 5, seed_value = 2066, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:48:09.817000] current iteration 1967 / 2000
# name = model_20_reg_6_iter_1967, n_topics = 20, n_doc_passes = 5, seed_value = 2067, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:48:17.694000] current iteration 1968 / 2000
# name = model_20_reg_6_iter_1968, n_topics = 20, n_doc_passes = 5, seed_value = 2068, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:48:25.696000] current iteration 1969 / 2000
# name = model_20_reg_6_iter_1969, n_topics = 20, n_doc_passes = 5, seed_value = 2069, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:48:33.652000] current iteration 1970 / 2000
# name = model_20_reg_6_iter_1970, n_topics = 20, n_doc_passes = 5, seed_value = 2070, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:48:41.390000] current iteration 1971 / 2000
# name = model_20_reg_6_iter_1971, n_topics = 20, n_doc_passes = 5, seed_value = 2071, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:48:49.220000] current iteration 1972 / 2000
# name = model_20_reg_6_iter_1972, n_topics = 20, n_doc_passes = 5, seed_value = 2072, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:48:57.146000] current iteration 1973 / 2000
# name = model_20_reg_6_iter_1973, n_topics = 20, n_doc_passes = 5, seed_value = 2073, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:49:04.945000] current iteration 1974 / 2000
# name = model_20_reg_6_iter_1974, n_topics = 20, n_doc_passes = 5, seed_value = 2074, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:49:12.822000] current iteration 1975 / 2000
# name = model_20_reg_6_iter_1975, n_topics = 20, n_doc_passes = 5, seed_value = 2075, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:49:20.795000] current iteration 1976 / 2000
# name = model_20_reg_6_iter_1976, n_topics = 20, n_doc_passes = 5, seed_value = 2076, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:49:28.674000] current iteration 1977 / 2000
# name = model_20_reg_6_iter_1977, n_topics = 20, n_doc_passes = 5, seed_value = 2077, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:49:36.443000] current iteration 1978 / 2000
# name = model_20_reg_6_iter_1978, n_topics = 20, n_doc_passes = 5, seed_value = 2078, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:49:44.463000] current iteration 1979 / 2000
# name = model_20_reg_6_iter_1979, n_topics = 20, n_doc_passes = 5, seed_value = 2079, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:49:52.261000] current iteration 1980 / 2000
# name = model_20_reg_6_iter_1980, n_topics = 20, n_doc_passes = 5, seed_value = 2080, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:49:59.950000] current iteration 1981 / 2000
# name = model_20_reg_6_iter_1981, n_topics = 20, n_doc_passes = 5, seed_value = 2081, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:50:07.732000] current iteration 1982 / 2000
# name = model_20_reg_6_iter_1982, n_topics = 20, n_doc_passes = 5, seed_value = 2082, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:50:15.751000] current iteration 1983 / 2000
# name = model_20_reg_6_iter_1983, n_topics = 20, n_doc_passes = 5, seed_value = 2083, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:50:23.426000] current iteration 1984 / 2000
# name = model_20_reg_6_iter_1984, n_topics = 20, n_doc_passes = 5, seed_value = 2084, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:50:31.359000] current iteration 1985 / 2000
# name = model_20_reg_6_iter_1985, n_topics = 20, n_doc_passes = 5, seed_value = 2085, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:50:39.323000] current iteration 1986 / 2000
# name = model_20_reg_6_iter_1986, n_topics = 20, n_doc_passes = 5, seed_value = 2086, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:50:47.310000] current iteration 1987 / 2000
# name = model_20_reg_6_iter_1987, n_topics = 20, n_doc_passes = 5, seed_value = 2087, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:50:55.312000] current iteration 1988 / 2000
# name = model_20_reg_6_iter_1988, n_topics = 20, n_doc_passes = 5, seed_value = 2088, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:51:03.142000] current iteration 1989 / 2000
# name = model_20_reg_6_iter_1989, n_topics = 20, n_doc_passes = 5, seed_value = 2089, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:51:11.069000] current iteration 1990 / 2000
# name = model_20_reg_6_iter_1990, n_topics = 20, n_doc_passes = 5, seed_value = 2090, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:51:18.898000] current iteration 1991 / 2000
# name = model_20_reg_6_iter_1991, n_topics = 20, n_doc_passes = 5, seed_value = 2091, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:51:26.887000] current iteration 1992 / 2000
# name = model_20_reg_6_iter_1992, n_topics = 20, n_doc_passes = 5, seed_value = 2092, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:51:34.547000] current iteration 1993 / 2000
# name = model_20_reg_6_iter_1993, n_topics = 20, n_doc_passes = 5, seed_value = 2093, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:51:42.390000] current iteration 1994 / 2000
# name = model_20_reg_6_iter_1994, n_topics = 20, n_doc_passes = 5, seed_value = 2094, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:51:50.285000] current iteration 1995 / 2000
# name = model_20_reg_6_iter_1995, n_topics = 20, n_doc_passes = 5, seed_value = 2095, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:51:58.131000] current iteration 1996 / 2000
# name = model_20_reg_6_iter_1996, n_topics = 20, n_doc_passes = 5, seed_value = 2096, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:52:06.081000] current iteration 1997 / 2000
# name = model_20_reg_6_iter_1997, n_topics = 20, n_doc_passes = 5, seed_value = 2097, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:52:13.855000] current iteration 1998 / 2000
# name = model_20_reg_6_iter_1998, n_topics = 20, n_doc_passes = 5, seed_value = 2098, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:52:21.546000] current iteration 1999 / 2000
# name = model_20_reg_6_iter_1999, n_topics = 20, n_doc_passes = 5, seed_value = 2099, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -30
# ss_phi_regularizer, tau = -30
#
# [2017-03-09 20:52:29.345000] current iteration 2000 / 2000

# %%
tmp_models_range = create_models_range(create_model_fn_20_reg_8, 'model_reg8')
# Out:
# name = model_20_reg_8_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:53:26.827000] current iteration 1 / 2000
# name = model_20_reg_8_iter_1, n_topics = 20, n_doc_passes = 5, seed_value = 101, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:53:35.065000] current iteration 2 / 2000
# name = model_20_reg_8_iter_2, n_topics = 20, n_doc_passes = 5, seed_value = 102, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:53:43.260000] current iteration 3 / 2000
# name = model_20_reg_8_iter_3, n_topics = 20, n_doc_passes = 5, seed_value = 103, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:53:51.408000] current iteration 4 / 2000
# name = model_20_reg_8_iter_4, n_topics = 20, n_doc_passes = 5, seed_value = 104, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:53:59.489000] current iteration 5 / 2000
# name = model_20_reg_8_iter_5, n_topics = 20, n_doc_passes = 5, seed_value = 105, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:54:07.744000] current iteration 6 / 2000
# name = model_20_reg_8_iter_6, n_topics = 20, n_doc_passes = 5, seed_value = 106, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:54:15.889000] current iteration 7 / 2000
# name = model_20_reg_8_iter_7, n_topics = 20, n_doc_passes = 5, seed_value = 107, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:54:24.094000] current iteration 8 / 2000
# name = model_20_reg_8_iter_8, n_topics = 20, n_doc_passes = 5, seed_value = 108, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:54:32.185000] current iteration 9 / 2000
# name = model_20_reg_8_iter_9, n_topics = 20, n_doc_passes = 5, seed_value = 109, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:54:40.409000] current iteration 10 / 2000
# name = model_20_reg_8_iter_10, n_topics = 20, n_doc_passes = 5, seed_value = 110, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:54:48.663000] current iteration 11 / 2000
# name = model_20_reg_8_iter_11, n_topics = 20, n_doc_passes = 5, seed_value = 111, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:54:56.843000] current iteration 12 / 2000
# name = model_20_reg_8_iter_12, n_topics = 20, n_doc_passes = 5, seed_value = 112, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:55:05.034000] current iteration 13 / 2000
# name = model_20_reg_8_iter_13, n_topics = 20, n_doc_passes = 5, seed_value = 113, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:55:13.259000] current iteration 14 / 2000
# name = model_20_reg_8_iter_14, n_topics = 20, n_doc_passes = 5, seed_value = 114, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:55:21.453000] current iteration 15 / 2000
# name = model_20_reg_8_iter_15, n_topics = 20, n_doc_passes = 5, seed_value = 115, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:55:29.725000] current iteration 16 / 2000
# name = model_20_reg_8_iter_16, n_topics = 20, n_doc_passes = 5, seed_value = 116, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:55:37.947000] current iteration 17 / 2000
# name = model_20_reg_8_iter_17, n_topics = 20, n_doc_passes = 5, seed_value = 117, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:55:46.094000] current iteration 18 / 2000
# name = model_20_reg_8_iter_18, n_topics = 20, n_doc_passes = 5, seed_value = 118, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:55:54.144000] current iteration 19 / 2000
# name = model_20_reg_8_iter_19, n_topics = 20, n_doc_passes = 5, seed_value = 119, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:56:02.366000] current iteration 20 / 2000
# name = model_20_reg_8_iter_20, n_topics = 20, n_doc_passes = 5, seed_value = 120, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:56:10.557000] current iteration 21 / 2000
# name = model_20_reg_8_iter_21, n_topics = 20, n_doc_passes = 5, seed_value = 121, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:56:18.720000] current iteration 22 / 2000
# name = model_20_reg_8_iter_22, n_topics = 20, n_doc_passes = 5, seed_value = 122, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:56:26.753000] current iteration 23 / 2000
# name = model_20_reg_8_iter_23, n_topics = 20, n_doc_passes = 5, seed_value = 123, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:56:34.791000] current iteration 24 / 2000
# name = model_20_reg_8_iter_24, n_topics = 20, n_doc_passes = 5, seed_value = 124, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:56:43.044000] current iteration 25 / 2000
# name = model_20_reg_8_iter_25, n_topics = 20, n_doc_passes = 5, seed_value = 125, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:56:51.299000] current iteration 26 / 2000
# name = model_20_reg_8_iter_26, n_topics = 20, n_doc_passes = 5, seed_value = 126, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:56:59.523000] current iteration 27 / 2000
# name = model_20_reg_8_iter_27, n_topics = 20, n_doc_passes = 5, seed_value = 127, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:57:07.793000] current iteration 28 / 2000
# name = model_20_reg_8_iter_28, n_topics = 20, n_doc_passes = 5, seed_value = 128, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:57:15.985000] current iteration 29 / 2000
# name = model_20_reg_8_iter_29, n_topics = 20, n_doc_passes = 5, seed_value = 129, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:57:24.239000] current iteration 30 / 2000
# name = model_20_reg_8_iter_30, n_topics = 20, n_doc_passes = 5, seed_value = 130, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:57:32.384000] current iteration 31 / 2000
# name = model_20_reg_8_iter_31, n_topics = 20, n_doc_passes = 5, seed_value = 131, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:57:40.466000] current iteration 32 / 2000
# name = model_20_reg_8_iter_32, n_topics = 20, n_doc_passes = 5, seed_value = 132, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:57:48.564000] current iteration 33 / 2000
# name = model_20_reg_8_iter_33, n_topics = 20, n_doc_passes = 5, seed_value = 133, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:57:56.663000] current iteration 34 / 2000
# name = model_20_reg_8_iter_34, n_topics = 20, n_doc_passes = 5, seed_value = 134, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:58:04.884000] current iteration 35 / 2000
# name = model_20_reg_8_iter_35, n_topics = 20, n_doc_passes = 5, seed_value = 135, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:58:13.078000] current iteration 36 / 2000
# name = model_20_reg_8_iter_36, n_topics = 20, n_doc_passes = 5, seed_value = 136, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:58:21.208000] current iteration 37 / 2000
# name = model_20_reg_8_iter_37, n_topics = 20, n_doc_passes = 5, seed_value = 137, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:58:29.243000] current iteration 38 / 2000
# name = model_20_reg_8_iter_38, n_topics = 20, n_doc_passes = 5, seed_value = 138, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:58:37.325000] current iteration 39 / 2000
# name = model_20_reg_8_iter_39, n_topics = 20, n_doc_passes = 5, seed_value = 139, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:58:45.377000] current iteration 40 / 2000
# name = model_20_reg_8_iter_40, n_topics = 20, n_doc_passes = 5, seed_value = 140, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:58:53.525000] current iteration 41 / 2000
# name = model_20_reg_8_iter_41, n_topics = 20, n_doc_passes = 5, seed_value = 141, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:59:01.710000] current iteration 42 / 2000
# name = model_20_reg_8_iter_42, n_topics = 20, n_doc_passes = 5, seed_value = 142, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:59:09.841000] current iteration 43 / 2000
# name = model_20_reg_8_iter_43, n_topics = 20, n_doc_passes = 5, seed_value = 143, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:59:18.096000] current iteration 44 / 2000
# name = model_20_reg_8_iter_44, n_topics = 20, n_doc_passes = 5, seed_value = 144, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:59:26.302000] current iteration 45 / 2000
# name = model_20_reg_8_iter_45, n_topics = 20, n_doc_passes = 5, seed_value = 145, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:59:34.511000] current iteration 46 / 2000
# name = model_20_reg_8_iter_46, n_topics = 20, n_doc_passes = 5, seed_value = 146, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:59:42.750000] current iteration 47 / 2000
# name = model_20_reg_8_iter_47, n_topics = 20, n_doc_passes = 5, seed_value = 147, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:59:50.972000] current iteration 48 / 2000
# name = model_20_reg_8_iter_48, n_topics = 20, n_doc_passes = 5, seed_value = 148, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 20:59:59.118000] current iteration 49 / 2000
# name = model_20_reg_8_iter_49, n_topics = 20, n_doc_passes = 5, seed_value = 149, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:00:07.325000] current iteration 50 / 2000
# name = model_20_reg_8_iter_50, n_topics = 20, n_doc_passes = 5, seed_value = 150, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:00:15.506000] current iteration 51 / 2000
# name = model_20_reg_8_iter_51, n_topics = 20, n_doc_passes = 5, seed_value = 151, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:00:23.647000] current iteration 52 / 2000
# name = model_20_reg_8_iter_52, n_topics = 20, n_doc_passes = 5, seed_value = 152, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:00:31.791000] current iteration 53 / 2000
# name = model_20_reg_8_iter_53, n_topics = 20, n_doc_passes = 5, seed_value = 153, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:00:40.046000] current iteration 54 / 2000
# name = model_20_reg_8_iter_54, n_topics = 20, n_doc_passes = 5, seed_value = 154, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:00:48.286000] current iteration 55 / 2000
# name = model_20_reg_8_iter_55, n_topics = 20, n_doc_passes = 5, seed_value = 155, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:00:56.492000] current iteration 56 / 2000
# name = model_20_reg_8_iter_56, n_topics = 20, n_doc_passes = 5, seed_value = 156, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:01:04.715000] current iteration 57 / 2000
# name = model_20_reg_8_iter_57, n_topics = 20, n_doc_passes = 5, seed_value = 157, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:01:12.829000] current iteration 58 / 2000
# name = model_20_reg_8_iter_58, n_topics = 20, n_doc_passes = 5, seed_value = 158, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:01:20.943000] current iteration 59 / 2000
# name = model_20_reg_8_iter_59, n_topics = 20, n_doc_passes = 5, seed_value = 159, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:01:29.102000] current iteration 60 / 2000
# name = model_20_reg_8_iter_60, n_topics = 20, n_doc_passes = 5, seed_value = 160, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:01:37.293000] current iteration 61 / 2000
# name = model_20_reg_8_iter_61, n_topics = 20, n_doc_passes = 5, seed_value = 161, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:01:45.454000] current iteration 62 / 2000
# name = model_20_reg_8_iter_62, n_topics = 20, n_doc_passes = 5, seed_value = 162, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:01:53.645000] current iteration 63 / 2000
# name = model_20_reg_8_iter_63, n_topics = 20, n_doc_passes = 5, seed_value = 163, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:02:01.837000] current iteration 64 / 2000
# name = model_20_reg_8_iter_64, n_topics = 20, n_doc_passes = 5, seed_value = 164, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:02:10.110000] current iteration 65 / 2000
# name = model_20_reg_8_iter_65, n_topics = 20, n_doc_passes = 5, seed_value = 165, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:02:18.301000] current iteration 66 / 2000
# name = model_20_reg_8_iter_66, n_topics = 20, n_doc_passes = 5, seed_value = 166, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:02:26.523000] current iteration 67 / 2000
# name = model_20_reg_8_iter_67, n_topics = 20, n_doc_passes = 5, seed_value = 167, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:02:34.982000] current iteration 68 / 2000
# name = model_20_reg_8_iter_68, n_topics = 20, n_doc_passes = 5, seed_value = 168, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:02:43.079000] current iteration 69 / 2000
# name = model_20_reg_8_iter_69, n_topics = 20, n_doc_passes = 5, seed_value = 169, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:02:51.305000] current iteration 70 / 2000
# name = model_20_reg_8_iter_70, n_topics = 20, n_doc_passes = 5, seed_value = 170, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:02:59.463000] current iteration 71 / 2000
# name = model_20_reg_8_iter_71, n_topics = 20, n_doc_passes = 5, seed_value = 171, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:03:07.671000] current iteration 72 / 2000
# name = model_20_reg_8_iter_72, n_topics = 20, n_doc_passes = 5, seed_value = 172, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:03:15.832000] current iteration 73 / 2000
# name = model_20_reg_8_iter_73, n_topics = 20, n_doc_passes = 5, seed_value = 173, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:03:24.119000] current iteration 74 / 2000
# name = model_20_reg_8_iter_74, n_topics = 20, n_doc_passes = 5, seed_value = 174, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:03:32.287000] current iteration 75 / 2000
# name = model_20_reg_8_iter_75, n_topics = 20, n_doc_passes = 5, seed_value = 175, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:03:40.472000] current iteration 76 / 2000
# name = model_20_reg_8_iter_76, n_topics = 20, n_doc_passes = 5, seed_value = 176, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:03:48.634000] current iteration 77 / 2000
# name = model_20_reg_8_iter_77, n_topics = 20, n_doc_passes = 5, seed_value = 177, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:03:56.825000] current iteration 78 / 2000
# name = model_20_reg_8_iter_78, n_topics = 20, n_doc_passes = 5, seed_value = 178, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:04:05.066000] current iteration 79 / 2000
# name = model_20_reg_8_iter_79, n_topics = 20, n_doc_passes = 5, seed_value = 179, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:04:13.321000] current iteration 80 / 2000
# name = model_20_reg_8_iter_80, n_topics = 20, n_doc_passes = 5, seed_value = 180, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:04:21.542000] current iteration 81 / 2000
# name = model_20_reg_8_iter_81, n_topics = 20, n_doc_passes = 5, seed_value = 181, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:04:29.658000] current iteration 82 / 2000
# name = model_20_reg_8_iter_82, n_topics = 20, n_doc_passes = 5, seed_value = 182, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:04:37.770000] current iteration 83 / 2000
# name = model_20_reg_8_iter_83, n_topics = 20, n_doc_passes = 5, seed_value = 183, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:04:46.023000] current iteration 84 / 2000
# name = model_20_reg_8_iter_84, n_topics = 20, n_doc_passes = 5, seed_value = 184, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:04:54.245000] current iteration 85 / 2000
# name = model_20_reg_8_iter_85, n_topics = 20, n_doc_passes = 5, seed_value = 185, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:05:02.299000] current iteration 86 / 2000
# name = model_20_reg_8_iter_86, n_topics = 20, n_doc_passes = 5, seed_value = 186, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:05:10.474000] current iteration 87 / 2000
# name = model_20_reg_8_iter_87, n_topics = 20, n_doc_passes = 5, seed_value = 187, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:05:18.665000] current iteration 88 / 2000
# name = model_20_reg_8_iter_88, n_topics = 20, n_doc_passes = 5, seed_value = 188, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:05:26.904000] current iteration 89 / 2000
# name = model_20_reg_8_iter_89, n_topics = 20, n_doc_passes = 5, seed_value = 189, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:05:35.064000] current iteration 90 / 2000
# name = model_20_reg_8_iter_90, n_topics = 20, n_doc_passes = 5, seed_value = 190, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:05:43.194000] current iteration 91 / 2000
# name = model_20_reg_8_iter_91, n_topics = 20, n_doc_passes = 5, seed_value = 191, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:05:51.387000] current iteration 92 / 2000
# name = model_20_reg_8_iter_92, n_topics = 20, n_doc_passes = 5, seed_value = 192, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:05:59.549000] current iteration 93 / 2000
# name = model_20_reg_8_iter_93, n_topics = 20, n_doc_passes = 5, seed_value = 193, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:06:07.740000] current iteration 94 / 2000
# name = model_20_reg_8_iter_94, n_topics = 20, n_doc_passes = 5, seed_value = 194, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:06:15.963000] current iteration 95 / 2000
# name = model_20_reg_8_iter_95, n_topics = 20, n_doc_passes = 5, seed_value = 195, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:06:24.078000] current iteration 96 / 2000
# name = model_20_reg_8_iter_96, n_topics = 20, n_doc_passes = 5, seed_value = 196, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:06:32.314000] current iteration 97 / 2000
# name = model_20_reg_8_iter_97, n_topics = 20, n_doc_passes = 5, seed_value = 197, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:06:40.536000] current iteration 98 / 2000
# name = model_20_reg_8_iter_98, n_topics = 20, n_doc_passes = 5, seed_value = 198, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:06:48.668000] current iteration 99 / 2000
# name = model_20_reg_8_iter_99, n_topics = 20, n_doc_passes = 5, seed_value = 199, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:06:56.873000] current iteration 100 / 2000
# name = model_20_reg_8_iter_100, n_topics = 20, n_doc_passes = 5, seed_value = 200, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:07:05.095000] current iteration 101 / 2000
# name = model_20_reg_8_iter_101, n_topics = 20, n_doc_passes = 5, seed_value = 201, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:07:13.208000] current iteration 102 / 2000
# name = model_20_reg_8_iter_102, n_topics = 20, n_doc_passes = 5, seed_value = 202, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:07:21.447000] current iteration 103 / 2000
# name = model_20_reg_8_iter_103, n_topics = 20, n_doc_passes = 5, seed_value = 203, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:07:29.669000] current iteration 104 / 2000
# name = model_20_reg_8_iter_104, n_topics = 20, n_doc_passes = 5, seed_value = 204, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:07:37.831000] current iteration 105 / 2000
# name = model_20_reg_8_iter_105, n_topics = 20, n_doc_passes = 5, seed_value = 205, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:07:45.834000] current iteration 106 / 2000
# name = model_20_reg_8_iter_106, n_topics = 20, n_doc_passes = 5, seed_value = 206, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:07:54.058000] current iteration 107 / 2000
# name = model_20_reg_8_iter_107, n_topics = 20, n_doc_passes = 5, seed_value = 207, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:08:02.279000] current iteration 108 / 2000
# name = model_20_reg_8_iter_108, n_topics = 20, n_doc_passes = 5, seed_value = 208, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:08:10.441000] current iteration 109 / 2000
# name = model_20_reg_8_iter_109, n_topics = 20, n_doc_passes = 5, seed_value = 209, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:08:18.634000] current iteration 110 / 2000
# name = model_20_reg_8_iter_110, n_topics = 20, n_doc_passes = 5, seed_value = 210, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:08:26.887000] current iteration 111 / 2000
# name = model_20_reg_8_iter_111, n_topics = 20, n_doc_passes = 5, seed_value = 211, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:08:35.062000] current iteration 112 / 2000
# name = model_20_reg_8_iter_112, n_topics = 20, n_doc_passes = 5, seed_value = 212, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:08:43.285000] current iteration 113 / 2000
# name = model_20_reg_8_iter_113, n_topics = 20, n_doc_passes = 5, seed_value = 213, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:08:51.574000] current iteration 114 / 2000
# name = model_20_reg_8_iter_114, n_topics = 20, n_doc_passes = 5, seed_value = 214, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:08:59.624000] current iteration 115 / 2000
# name = model_20_reg_8_iter_115, n_topics = 20, n_doc_passes = 5, seed_value = 215, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:09:07.830000] current iteration 116 / 2000
# name = model_20_reg_8_iter_116, n_topics = 20, n_doc_passes = 5, seed_value = 216, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:09:16.022000] current iteration 117 / 2000
# name = model_20_reg_8_iter_117, n_topics = 20, n_doc_passes = 5, seed_value = 217, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:09:24.216000] current iteration 118 / 2000
# name = model_20_reg_8_iter_118, n_topics = 20, n_doc_passes = 5, seed_value = 218, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:09:32.392000] current iteration 119 / 2000
# name = model_20_reg_8_iter_119, n_topics = 20, n_doc_passes = 5, seed_value = 219, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:09:40.613000] current iteration 120 / 2000
# name = model_20_reg_8_iter_120, n_topics = 20, n_doc_passes = 5, seed_value = 220, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:09:48.869000] current iteration 121 / 2000
# name = model_20_reg_8_iter_121, n_topics = 20, n_doc_passes = 5, seed_value = 221, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:09:56.905000] current iteration 122 / 2000
# name = model_20_reg_8_iter_122, n_topics = 20, n_doc_passes = 5, seed_value = 222, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:10:05.097000] current iteration 123 / 2000
# name = model_20_reg_8_iter_123, n_topics = 20, n_doc_passes = 5, seed_value = 223, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:10:13.242000] current iteration 124 / 2000
# name = model_20_reg_8_iter_124, n_topics = 20, n_doc_passes = 5, seed_value = 224, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:10:21.483000] current iteration 125 / 2000
# name = model_20_reg_8_iter_125, n_topics = 20, n_doc_passes = 5, seed_value = 225, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:10:29.675000] current iteration 126 / 2000
# name = model_20_reg_8_iter_126, n_topics = 20, n_doc_passes = 5, seed_value = 226, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:10:37.914000] current iteration 127 / 2000
# name = model_20_reg_8_iter_127, n_topics = 20, n_doc_passes = 5, seed_value = 227, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:10:46.155000] current iteration 128 / 2000
# name = model_20_reg_8_iter_128, n_topics = 20, n_doc_passes = 5, seed_value = 228, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:10:54.333000] current iteration 129 / 2000
# name = model_20_reg_8_iter_129, n_topics = 20, n_doc_passes = 5, seed_value = 229, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:11:02.523000] current iteration 130 / 2000
# name = model_20_reg_8_iter_130, n_topics = 20, n_doc_passes = 5, seed_value = 230, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:11:10.715000] current iteration 131 / 2000
# name = model_20_reg_8_iter_131, n_topics = 20, n_doc_passes = 5, seed_value = 231, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:11:18.939000] current iteration 132 / 2000
# name = model_20_reg_8_iter_132, n_topics = 20, n_doc_passes = 5, seed_value = 232, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:11:27.128000] current iteration 133 / 2000
# name = model_20_reg_8_iter_133, n_topics = 20, n_doc_passes = 5, seed_value = 233, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:11:35.339000] current iteration 134 / 2000
# name = model_20_reg_8_iter_134, n_topics = 20, n_doc_passes = 5, seed_value = 234, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:11:43.531000] current iteration 135 / 2000
# name = model_20_reg_8_iter_135, n_topics = 20, n_doc_passes = 5, seed_value = 235, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:11:51.627000] current iteration 136 / 2000
# name = model_20_reg_8_iter_136, n_topics = 20, n_doc_passes = 5, seed_value = 236, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:11:59.890000] current iteration 137 / 2000
# name = model_20_reg_8_iter_137, n_topics = 20, n_doc_passes = 5, seed_value = 237, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:12:08.027000] current iteration 138 / 2000
# name = model_20_reg_8_iter_138, n_topics = 20, n_doc_passes = 5, seed_value = 238, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:12:16.234000] current iteration 139 / 2000
# name = model_20_reg_8_iter_139, n_topics = 20, n_doc_passes = 5, seed_value = 239, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:12:24.505000] current iteration 140 / 2000
# name = model_20_reg_8_iter_140, n_topics = 20, n_doc_passes = 5, seed_value = 240, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:12:32.507000] current iteration 141 / 2000
# name = model_20_reg_8_iter_141, n_topics = 20, n_doc_passes = 5, seed_value = 241, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:12:40.684000] current iteration 142 / 2000
# name = model_20_reg_8_iter_142, n_topics = 20, n_doc_passes = 5, seed_value = 242, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:12:49.002000] current iteration 143 / 2000
# name = model_20_reg_8_iter_143, n_topics = 20, n_doc_passes = 5, seed_value = 243, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:12:57.240000] current iteration 144 / 2000
# name = model_20_reg_8_iter_144, n_topics = 20, n_doc_passes = 5, seed_value = 244, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:13:05.464000] current iteration 145 / 2000
# name = model_20_reg_8_iter_145, n_topics = 20, n_doc_passes = 5, seed_value = 245, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:13:13.656000] current iteration 146 / 2000
# name = model_20_reg_8_iter_146, n_topics = 20, n_doc_passes = 5, seed_value = 246, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:13:21.929000] current iteration 147 / 2000
# name = model_20_reg_8_iter_147, n_topics = 20, n_doc_passes = 5, seed_value = 247, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:13:30.184000] current iteration 148 / 2000
# name = model_20_reg_8_iter_148, n_topics = 20, n_doc_passes = 5, seed_value = 248, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:13:38.378000] current iteration 149 / 2000
# name = model_20_reg_8_iter_149, n_topics = 20, n_doc_passes = 5, seed_value = 249, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:13:46.381000] current iteration 150 / 2000
# name = model_20_reg_8_iter_150, n_topics = 20, n_doc_passes = 5, seed_value = 250, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:13:54.541000] current iteration 151 / 2000
# name = model_20_reg_8_iter_151, n_topics = 20, n_doc_passes = 5, seed_value = 251, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:14:02.827000] current iteration 152 / 2000
# name = model_20_reg_8_iter_152, n_topics = 20, n_doc_passes = 5, seed_value = 252, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:14:11.035000] current iteration 153 / 2000
# name = model_20_reg_8_iter_153, n_topics = 20, n_doc_passes = 5, seed_value = 253, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-09 21:14:19.228000] current iteration 154 / 2000
# ...
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:21:10.495000] current iteration 1950 / 2000
# name = model_20_reg_8_iter_1950, n_topics = 20, n_doc_passes = 5, seed_value = 2050, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:21:18.765000] current iteration 1951 / 2000
# name = model_20_reg_8_iter_1951, n_topics = 20, n_doc_passes = 5, seed_value = 2051, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:21:26.895000] current iteration 1952 / 2000
# name = model_20_reg_8_iter_1952, n_topics = 20, n_doc_passes = 5, seed_value = 2052, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:21:35.101000] current iteration 1953 / 2000
# name = model_20_reg_8_iter_1953, n_topics = 20, n_doc_passes = 5, seed_value = 2053, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:21:43.308000] current iteration 1954 / 2000
# name = model_20_reg_8_iter_1954, n_topics = 20, n_doc_passes = 5, seed_value = 2054, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:21:51.611000] current iteration 1955 / 2000
# name = model_20_reg_8_iter_1955, n_topics = 20, n_doc_passes = 5, seed_value = 2055, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:21:59.785000] current iteration 1956 / 2000
# name = model_20_reg_8_iter_1956, n_topics = 20, n_doc_passes = 5, seed_value = 2056, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:22:07.930000] current iteration 1957 / 2000
# name = model_20_reg_8_iter_1957, n_topics = 20, n_doc_passes = 5, seed_value = 2057, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:22:16.124000] current iteration 1958 / 2000
# name = model_20_reg_8_iter_1958, n_topics = 20, n_doc_passes = 5, seed_value = 2058, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:22:24.315000] current iteration 1959 / 2000
# name = model_20_reg_8_iter_1959, n_topics = 20, n_doc_passes = 5, seed_value = 2059, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:22:32.554000] current iteration 1960 / 2000
# name = model_20_reg_8_iter_1960, n_topics = 20, n_doc_passes = 5, seed_value = 2060, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:22:40.840000] current iteration 1961 / 2000
# name = model_20_reg_8_iter_1961, n_topics = 20, n_doc_passes = 5, seed_value = 2061, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:22:49.141000] current iteration 1962 / 2000
# name = model_20_reg_8_iter_1962, n_topics = 20, n_doc_passes = 5, seed_value = 2062, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:22:57.241000] current iteration 1963 / 2000
# name = model_20_reg_8_iter_1963, n_topics = 20, n_doc_passes = 5, seed_value = 2063, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:23:05.543000] current iteration 1964 / 2000
# name = model_20_reg_8_iter_1964, n_topics = 20, n_doc_passes = 5, seed_value = 2064, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:23:13.765000] current iteration 1965 / 2000
# name = model_20_reg_8_iter_1965, n_topics = 20, n_doc_passes = 5, seed_value = 2065, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:23:21.896000] current iteration 1966 / 2000
# name = model_20_reg_8_iter_1966, n_topics = 20, n_doc_passes = 5, seed_value = 2066, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:23:30.072000] current iteration 1967 / 2000
# name = model_20_reg_8_iter_1967, n_topics = 20, n_doc_passes = 5, seed_value = 2067, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:23:38.201000] current iteration 1968 / 2000
# name = model_20_reg_8_iter_1968, n_topics = 20, n_doc_passes = 5, seed_value = 2068, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:23:46.408000] current iteration 1969 / 2000
# name = model_20_reg_8_iter_1969, n_topics = 20, n_doc_passes = 5, seed_value = 2069, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:23:54.710000] current iteration 1970 / 2000
# name = model_20_reg_8_iter_1970, n_topics = 20, n_doc_passes = 5, seed_value = 2070, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:24:02.854000] current iteration 1971 / 2000
# name = model_20_reg_8_iter_1971, n_topics = 20, n_doc_passes = 5, seed_value = 2071, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:24:11.032000] current iteration 1972 / 2000
# name = model_20_reg_8_iter_1972, n_topics = 20, n_doc_passes = 5, seed_value = 2072, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:24:19.239000] current iteration 1973 / 2000
# name = model_20_reg_8_iter_1973, n_topics = 20, n_doc_passes = 5, seed_value = 2073, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:24:27.462000] current iteration 1974 / 2000
# name = model_20_reg_8_iter_1974, n_topics = 20, n_doc_passes = 5, seed_value = 2074, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:24:35.719000] current iteration 1975 / 2000
# name = model_20_reg_8_iter_1975, n_topics = 20, n_doc_passes = 5, seed_value = 2075, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:24:43.924000] current iteration 1976 / 2000
# name = model_20_reg_8_iter_1976, n_topics = 20, n_doc_passes = 5, seed_value = 2076, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:24:52.164000] current iteration 1977 / 2000
# name = model_20_reg_8_iter_1977, n_topics = 20, n_doc_passes = 5, seed_value = 2077, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:25:00.263000] current iteration 1978 / 2000
# name = model_20_reg_8_iter_1978, n_topics = 20, n_doc_passes = 5, seed_value = 2078, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:25:08.501000] current iteration 1979 / 2000
# name = model_20_reg_8_iter_1979, n_topics = 20, n_doc_passes = 5, seed_value = 2079, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:25:16.692000] current iteration 1980 / 2000
# name = model_20_reg_8_iter_1980, n_topics = 20, n_doc_passes = 5, seed_value = 2080, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:25:24.966000] current iteration 1981 / 2000
# name = model_20_reg_8_iter_1981, n_topics = 20, n_doc_passes = 5, seed_value = 2081, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:25:33.234000] current iteration 1982 / 2000
# name = model_20_reg_8_iter_1982, n_topics = 20, n_doc_passes = 5, seed_value = 2082, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:25:41.443000] current iteration 1983 / 2000
# name = model_20_reg_8_iter_1983, n_topics = 20, n_doc_passes = 5, seed_value = 2083, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:25:49.480000] current iteration 1984 / 2000
# name = model_20_reg_8_iter_1984, n_topics = 20, n_doc_passes = 5, seed_value = 2084, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:25:57.514000] current iteration 1985 / 2000
# name = model_20_reg_8_iter_1985, n_topics = 20, n_doc_passes = 5, seed_value = 2085, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:26:05.737000] current iteration 1986 / 2000
# name = model_20_reg_8_iter_1986, n_topics = 20, n_doc_passes = 5, seed_value = 2086, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:26:14.055000] current iteration 1987 / 2000
# name = model_20_reg_8_iter_1987, n_topics = 20, n_doc_passes = 5, seed_value = 2087, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:26:22.184000] current iteration 1988 / 2000
# name = model_20_reg_8_iter_1988, n_topics = 20, n_doc_passes = 5, seed_value = 2088, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:26:30.360000] current iteration 1989 / 2000
# name = model_20_reg_8_iter_1989, n_topics = 20, n_doc_passes = 5, seed_value = 2089, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:26:38.552000] current iteration 1990 / 2000
# name = model_20_reg_8_iter_1990, n_topics = 20, n_doc_passes = 5, seed_value = 2090, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:26:46.728000] current iteration 1991 / 2000
# name = model_20_reg_8_iter_1991, n_topics = 20, n_doc_passes = 5, seed_value = 2091, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:26:55.014000] current iteration 1992 / 2000
# name = model_20_reg_8_iter_1992, n_topics = 20, n_doc_passes = 5, seed_value = 2092, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:27:03.189000] current iteration 1993 / 2000
# name = model_20_reg_8_iter_1993, n_topics = 20, n_doc_passes = 5, seed_value = 2093, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:27:11.413000] current iteration 1994 / 2000
# name = model_20_reg_8_iter_1994, n_topics = 20, n_doc_passes = 5, seed_value = 2094, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:27:19.560000] current iteration 1995 / 2000
# name = model_20_reg_8_iter_1995, n_topics = 20, n_doc_passes = 5, seed_value = 2095, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:27:27.750000] current iteration 1996 / 2000
# name = model_20_reg_8_iter_1996, n_topics = 20, n_doc_passes = 5, seed_value = 2096, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:27:35.912000] current iteration 1997 / 2000
# name = model_20_reg_8_iter_1997, n_topics = 20, n_doc_passes = 5, seed_value = 2097, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:27:44.181000] current iteration 1998 / 2000
# name = model_20_reg_8_iter_1998, n_topics = 20, n_doc_passes = 5, seed_value = 2098, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:27:52.357000] current iteration 1999 / 2000
# name = model_20_reg_8_iter_1999, n_topics = 20, n_doc_passes = 5, seed_value = 2099, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -20
# decorrelator_phi_regularizer, tau = -10
# ss_phi_regularizer, tau = -20
#
# [2017-03-10 01:28:00.487000] current iteration 2000 / 2000

# %%
tmp_models_range = create_models_range(create_model_fn_1, 'model_20_no_reg')
# Out:
# name = model_20_m1_iter_0, n_topics = 20, n_doc_passes = 5, seed_value = 100, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:28:59.974000] current iteration 1 / 2000
# name = model_20_m1_iter_1, n_topics = 20, n_doc_passes = 5, seed_value = 101, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:29:10.188000] current iteration 2 / 2000
# name = model_20_m1_iter_2, n_topics = 20, n_doc_passes = 5, seed_value = 102, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:29:20.255000] current iteration 3 / 2000
# name = model_20_m1_iter_3, n_topics = 20, n_doc_passes = 5, seed_value = 103, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:29:30.353000] current iteration 4 / 2000
# name = model_20_m1_iter_4, n_topics = 20, n_doc_passes = 5, seed_value = 104, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:29:40.569000] current iteration 5 / 2000
# name = model_20_m1_iter_5, n_topics = 20, n_doc_passes = 5, seed_value = 105, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:29:50.649000] current iteration 6 / 2000
# name = model_20_m1_iter_6, n_topics = 20, n_doc_passes = 5, seed_value = 106, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:30:00.793000] current iteration 7 / 2000
# name = model_20_m1_iter_7, n_topics = 20, n_doc_passes = 5, seed_value = 107, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:30:10.869000] current iteration 8 / 2000
# name = model_20_m1_iter_8, n_topics = 20, n_doc_passes = 5, seed_value = 108, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:30:21.135000] current iteration 9 / 2000
# name = model_20_m1_iter_9, n_topics = 20, n_doc_passes = 5, seed_value = 109, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:30:31.241000] current iteration 10 / 2000
# name = model_20_m1_iter_10, n_topics = 20, n_doc_passes = 5, seed_value = 110, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:30:41.256000] current iteration 11 / 2000
# name = model_20_m1_iter_11, n_topics = 20, n_doc_passes = 5, seed_value = 111, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:30:51.272000] current iteration 12 / 2000
# name = model_20_m1_iter_12, n_topics = 20, n_doc_passes = 5, seed_value = 112, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:31:01.632000] current iteration 13 / 2000
# name = model_20_m1_iter_13, n_topics = 20, n_doc_passes = 5, seed_value = 113, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:31:11.623000] current iteration 14 / 2000
# name = model_20_m1_iter_14, n_topics = 20, n_doc_passes = 5, seed_value = 114, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:31:21.761000] current iteration 15 / 2000
# name = model_20_m1_iter_15, n_topics = 20, n_doc_passes = 5, seed_value = 115, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:31:31.978000] current iteration 16 / 2000
# name = model_20_m1_iter_16, n_topics = 20, n_doc_passes = 5, seed_value = 116, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:31:42.182000] current iteration 17 / 2000
# name = model_20_m1_iter_17, n_topics = 20, n_doc_passes = 5, seed_value = 117, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:31:52.266000] current iteration 18 / 2000
# name = model_20_m1_iter_18, n_topics = 20, n_doc_passes = 5, seed_value = 118, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:32:02.375000] current iteration 19 / 2000
# name = model_20_m1_iter_19, n_topics = 20, n_doc_passes = 5, seed_value = 119, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:32:12.511000] current iteration 20 / 2000
# name = model_20_m1_iter_20, n_topics = 20, n_doc_passes = 5, seed_value = 120, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:32:22.630000] current iteration 21 / 2000
# name = model_20_m1_iter_21, n_topics = 20, n_doc_passes = 5, seed_value = 121, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:32:32.771000] current iteration 22 / 2000
# name = model_20_m1_iter_22, n_topics = 20, n_doc_passes = 5, seed_value = 122, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:32:42.883000] current iteration 23 / 2000
# name = model_20_m1_iter_23, n_topics = 20, n_doc_passes = 5, seed_value = 123, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:32:52.959000] current iteration 24 / 2000
# name = model_20_m1_iter_24, n_topics = 20, n_doc_passes = 5, seed_value = 124, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:33:03.127000] current iteration 25 / 2000
# name = model_20_m1_iter_25, n_topics = 20, n_doc_passes = 5, seed_value = 125, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:33:13.274000] current iteration 26 / 2000
# name = model_20_m1_iter_26, n_topics = 20, n_doc_passes = 5, seed_value = 126, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:33:23.344000] current iteration 27 / 2000
# name = model_20_m1_iter_27, n_topics = 20, n_doc_passes = 5, seed_value = 127, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:33:33.426000] current iteration 28 / 2000
# name = model_20_m1_iter_28, n_topics = 20, n_doc_passes = 5, seed_value = 128, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:33:43.686000] current iteration 29 / 2000
# name = model_20_m1_iter_29, n_topics = 20, n_doc_passes = 5, seed_value = 129, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:33:53.764000] current iteration 30 / 2000
# name = model_20_m1_iter_30, n_topics = 20, n_doc_passes = 5, seed_value = 130, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:34:03.904000] current iteration 31 / 2000
# name = model_20_m1_iter_31, n_topics = 20, n_doc_passes = 5, seed_value = 131, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:34:13.833000] current iteration 32 / 2000
# name = model_20_m1_iter_32, n_topics = 20, n_doc_passes = 5, seed_value = 132, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:34:23.926000] current iteration 33 / 2000
# name = model_20_m1_iter_33, n_topics = 20, n_doc_passes = 5, seed_value = 133, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:34:33.999000] current iteration 34 / 2000
# name = model_20_m1_iter_34, n_topics = 20, n_doc_passes = 5, seed_value = 134, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:34:44.064000] current iteration 35 / 2000
# name = model_20_m1_iter_35, n_topics = 20, n_doc_passes = 5, seed_value = 135, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:34:54.211000] current iteration 36 / 2000
# name = model_20_m1_iter_36, n_topics = 20, n_doc_passes = 5, seed_value = 136, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:35:04.389000] current iteration 37 / 2000
# name = model_20_m1_iter_37, n_topics = 20, n_doc_passes = 5, seed_value = 137, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:35:14.496000] current iteration 38 / 2000
# name = model_20_m1_iter_38, n_topics = 20, n_doc_passes = 5, seed_value = 138, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:35:24.639000] current iteration 39 / 2000
# name = model_20_m1_iter_39, n_topics = 20, n_doc_passes = 5, seed_value = 139, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:35:34.810000] current iteration 40 / 2000
# name = model_20_m1_iter_40, n_topics = 20, n_doc_passes = 5, seed_value = 140, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:35:44.829000] current iteration 41 / 2000
# name = model_20_m1_iter_41, n_topics = 20, n_doc_passes = 5, seed_value = 141, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:35:54.964000] current iteration 42 / 2000
# name = model_20_m1_iter_42, n_topics = 20, n_doc_passes = 5, seed_value = 142, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:36:04.978000] current iteration 43 / 2000
# name = model_20_m1_iter_43, n_topics = 20, n_doc_passes = 5, seed_value = 143, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:36:15.131000] current iteration 44 / 2000
# name = model_20_m1_iter_44, n_topics = 20, n_doc_passes = 5, seed_value = 144, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:36:25.208000] current iteration 45 / 2000
# name = model_20_m1_iter_45, n_topics = 20, n_doc_passes = 5, seed_value = 145, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:36:35.247000] current iteration 46 / 2000
# name = model_20_m1_iter_46, n_topics = 20, n_doc_passes = 5, seed_value = 146, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:36:45.402000] current iteration 47 / 2000
# name = model_20_m1_iter_47, n_topics = 20, n_doc_passes = 5, seed_value = 147, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:36:55.621000] current iteration 48 / 2000
# name = model_20_m1_iter_48, n_topics = 20, n_doc_passes = 5, seed_value = 148, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:37:05.913000] current iteration 49 / 2000
# name = model_20_m1_iter_49, n_topics = 20, n_doc_passes = 5, seed_value = 149, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:37:16.018000] current iteration 50 / 2000
# name = model_20_m1_iter_50, n_topics = 20, n_doc_passes = 5, seed_value = 150, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:37:26.188000] current iteration 51 / 2000
# name = model_20_m1_iter_51, n_topics = 20, n_doc_passes = 5, seed_value = 151, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:37:36.252000] current iteration 52 / 2000
# name = model_20_m1_iter_52, n_topics = 20, n_doc_passes = 5, seed_value = 152, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:37:46.392000] current iteration 53 / 2000
# name = model_20_m1_iter_53, n_topics = 20, n_doc_passes = 5, seed_value = 153, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:37:56.522000] current iteration 54 / 2000
# name = model_20_m1_iter_54, n_topics = 20, n_doc_passes = 5, seed_value = 154, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:38:06.553000] current iteration 55 / 2000
# name = model_20_m1_iter_55, n_topics = 20, n_doc_passes = 5, seed_value = 155, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:38:16.632000] current iteration 56 / 2000
# name = model_20_m1_iter_56, n_topics = 20, n_doc_passes = 5, seed_value = 156, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:38:26.801000] current iteration 57 / 2000
# name = model_20_m1_iter_57, n_topics = 20, n_doc_passes = 5, seed_value = 157, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:38:36.899000] current iteration 58 / 2000
# name = model_20_m1_iter_58, n_topics = 20, n_doc_passes = 5, seed_value = 158, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:38:47.008000] current iteration 59 / 2000
# name = model_20_m1_iter_59, n_topics = 20, n_doc_passes = 5, seed_value = 159, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:38:57.163000] current iteration 60 / 2000
# name = model_20_m1_iter_60, n_topics = 20, n_doc_passes = 5, seed_value = 160, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:39:07.332000] current iteration 61 / 2000
# name = model_20_m1_iter_61, n_topics = 20, n_doc_passes = 5, seed_value = 161, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:39:17.424000] current iteration 62 / 2000
# name = model_20_m1_iter_62, n_topics = 20, n_doc_passes = 5, seed_value = 162, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:39:27.495000] current iteration 63 / 2000
# name = model_20_m1_iter_63, n_topics = 20, n_doc_passes = 5, seed_value = 163, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:39:37.602000] current iteration 64 / 2000
# name = model_20_m1_iter_64, n_topics = 20, n_doc_passes = 5, seed_value = 164, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:39:47.619000] current iteration 65 / 2000
# name = model_20_m1_iter_65, n_topics = 20, n_doc_passes = 5, seed_value = 165, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:39:57.601000] current iteration 66 / 2000
# name = model_20_m1_iter_66, n_topics = 20, n_doc_passes = 5, seed_value = 166, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:40:07.692000] current iteration 67 / 2000
# name = model_20_m1_iter_67, n_topics = 20, n_doc_passes = 5, seed_value = 167, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:40:17.769000] current iteration 68 / 2000
# name = model_20_m1_iter_68, n_topics = 20, n_doc_passes = 5, seed_value = 168, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:40:28.062000] current iteration 69 / 2000
# name = model_20_m1_iter_69, n_topics = 20, n_doc_passes = 5, seed_value = 169, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:40:38.197000] current iteration 70 / 2000
# name = model_20_m1_iter_70, n_topics = 20, n_doc_passes = 5, seed_value = 170, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:40:48.336000] current iteration 71 / 2000
# name = model_20_m1_iter_71, n_topics = 20, n_doc_passes = 5, seed_value = 171, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:40:58.505000] current iteration 72 / 2000
# name = model_20_m1_iter_72, n_topics = 20, n_doc_passes = 5, seed_value = 172, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:41:08.676000] current iteration 73 / 2000
# name = model_20_m1_iter_73, n_topics = 20, n_doc_passes = 5, seed_value = 173, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:41:18.728000] current iteration 74 / 2000
# name = model_20_m1_iter_74, n_topics = 20, n_doc_passes = 5, seed_value = 174, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:41:28.900000] current iteration 75 / 2000
# name = model_20_m1_iter_75, n_topics = 20, n_doc_passes = 5, seed_value = 175, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:41:38.946000] current iteration 76 / 2000
# name = model_20_m1_iter_76, n_topics = 20, n_doc_passes = 5, seed_value = 176, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:41:49.014000] current iteration 77 / 2000
# name = model_20_m1_iter_77, n_topics = 20, n_doc_passes = 5, seed_value = 177, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:41:59.146000] current iteration 78 / 2000
# name = model_20_m1_iter_78, n_topics = 20, n_doc_passes = 5, seed_value = 178, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:42:09.250000] current iteration 79 / 2000
# name = model_20_m1_iter_79, n_topics = 20, n_doc_passes = 5, seed_value = 179, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:42:19.452000] current iteration 80 / 2000
# name = model_20_m1_iter_80, n_topics = 20, n_doc_passes = 5, seed_value = 180, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:42:29.650000] current iteration 81 / 2000
# name = model_20_m1_iter_81, n_topics = 20, n_doc_passes = 5, seed_value = 181, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:42:39.699000] current iteration 82 / 2000
# name = model_20_m1_iter_82, n_topics = 20, n_doc_passes = 5, seed_value = 182, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:42:49.839000] current iteration 83 / 2000
# name = model_20_m1_iter_83, n_topics = 20, n_doc_passes = 5, seed_value = 183, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:42:59.945000] current iteration 84 / 2000
# name = model_20_m1_iter_84, n_topics = 20, n_doc_passes = 5, seed_value = 184, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:43:10.208000] current iteration 85 / 2000
# name = model_20_m1_iter_85, n_topics = 20, n_doc_passes = 5, seed_value = 185, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:43:20.348000] current iteration 86 / 2000
# name = model_20_m1_iter_86, n_topics = 20, n_doc_passes = 5, seed_value = 186, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:43:30.581000] current iteration 87 / 2000
# name = model_20_m1_iter_87, n_topics = 20, n_doc_passes = 5, seed_value = 187, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:43:40.756000] current iteration 88 / 2000
# name = model_20_m1_iter_88, n_topics = 20, n_doc_passes = 5, seed_value = 188, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:43:50.856000] current iteration 89 / 2000
# name = model_20_m1_iter_89, n_topics = 20, n_doc_passes = 5, seed_value = 189, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:44:00.907000] current iteration 90 / 2000
# name = model_20_m1_iter_90, n_topics = 20, n_doc_passes = 5, seed_value = 190, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:44:11.128000] current iteration 91 / 2000
# name = model_20_m1_iter_91, n_topics = 20, n_doc_passes = 5, seed_value = 191, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:44:21.210000] current iteration 92 / 2000
# name = model_20_m1_iter_92, n_topics = 20, n_doc_passes = 5, seed_value = 192, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:44:31.354000] current iteration 93 / 2000
# name = model_20_m1_iter_93, n_topics = 20, n_doc_passes = 5, seed_value = 193, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:44:41.468000] current iteration 94 / 2000
# name = model_20_m1_iter_94, n_topics = 20, n_doc_passes = 5, seed_value = 194, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:44:51.578000] current iteration 95 / 2000
# name = model_20_m1_iter_95, n_topics = 20, n_doc_passes = 5, seed_value = 195, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:45:01.573000] current iteration 96 / 2000
# name = model_20_m1_iter_96, n_topics = 20, n_doc_passes = 5, seed_value = 196, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:45:11.760000] current iteration 97 / 2000
# name = model_20_m1_iter_97, n_topics = 20, n_doc_passes = 5, seed_value = 197, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:45:21.873000] current iteration 98 / 2000
# name = model_20_m1_iter_98, n_topics = 20, n_doc_passes = 5, seed_value = 198, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:45:31.990000] current iteration 99 / 2000
# name = model_20_m1_iter_99, n_topics = 20, n_doc_passes = 5, seed_value = 199, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:45:42.160000] current iteration 100 / 2000
# name = model_20_m1_iter_100, n_topics = 20, n_doc_passes = 5, seed_value = 200, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:45:52.387000] current iteration 101 / 2000
# name = model_20_m1_iter_101, n_topics = 20, n_doc_passes = 5, seed_value = 201, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:46:02.522000] current iteration 102 / 2000
# name = model_20_m1_iter_102, n_topics = 20, n_doc_passes = 5, seed_value = 202, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:46:12.692000] current iteration 103 / 2000
# name = model_20_m1_iter_103, n_topics = 20, n_doc_passes = 5, seed_value = 203, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:46:22.858000] current iteration 104 / 2000
# name = model_20_m1_iter_104, n_topics = 20, n_doc_passes = 5, seed_value = 204, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:46:33.075000] current iteration 105 / 2000
# name = model_20_m1_iter_105, n_topics = 20, n_doc_passes = 5, seed_value = 205, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:46:43.212000] current iteration 106 / 2000
# name = model_20_m1_iter_106, n_topics = 20, n_doc_passes = 5, seed_value = 206, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:46:53.321000] current iteration 107 / 2000
# name = model_20_m1_iter_107, n_topics = 20, n_doc_passes = 5, seed_value = 207, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:47:03.506000] current iteration 108 / 2000
# name = model_20_m1_iter_108, n_topics = 20, n_doc_passes = 5, seed_value = 208, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:47:13.749000] current iteration 109 / 2000
# name = model_20_m1_iter_109, n_topics = 20, n_doc_passes = 5, seed_value = 209, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:47:23.826000] current iteration 110 / 2000
# name = model_20_m1_iter_110, n_topics = 20, n_doc_passes = 5, seed_value = 210, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:47:33.976000] current iteration 111 / 2000
# name = model_20_m1_iter_111, n_topics = 20, n_doc_passes = 5, seed_value = 211, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:47:44.147000] current iteration 112 / 2000
# name = model_20_m1_iter_112, n_topics = 20, n_doc_passes = 5, seed_value = 212, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:47:54.339000] current iteration 113 / 2000
# name = model_20_m1_iter_113, n_topics = 20, n_doc_passes = 5, seed_value = 213, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:48:04.483000] current iteration 114 / 2000
# name = model_20_m1_iter_114, n_topics = 20, n_doc_passes = 5, seed_value = 214, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:48:14.555000] current iteration 115 / 2000
# name = model_20_m1_iter_115, n_topics = 20, n_doc_passes = 5, seed_value = 215, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:48:24.634000] current iteration 116 / 2000
# name = model_20_m1_iter_116, n_topics = 20, n_doc_passes = 5, seed_value = 216, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:48:34.805000] current iteration 117 / 2000
# name = model_20_m1_iter_117, n_topics = 20, n_doc_passes = 5, seed_value = 217, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:48:44.943000] current iteration 118 / 2000
# name = model_20_m1_iter_118, n_topics = 20, n_doc_passes = 5, seed_value = 218, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:48:54.995000] current iteration 119 / 2000
# name = model_20_m1_iter_119, n_topics = 20, n_doc_passes = 5, seed_value = 219, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:49:05.221000] current iteration 120 / 2000
# name = model_20_m1_iter_120, n_topics = 20, n_doc_passes = 5, seed_value = 220, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:49:15.391000] current iteration 121 / 2000
# name = model_20_m1_iter_121, n_topics = 20, n_doc_passes = 5, seed_value = 221, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:49:25.506000] current iteration 122 / 2000
# name = model_20_m1_iter_122, n_topics = 20, n_doc_passes = 5, seed_value = 222, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:49:35.691000] current iteration 123 / 2000
# name = model_20_m1_iter_123, n_topics = 20, n_doc_passes = 5, seed_value = 223, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:49:45.812000] current iteration 124 / 2000
# name = model_20_m1_iter_124, n_topics = 20, n_doc_passes = 5, seed_value = 224, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:49:55.865000] current iteration 125 / 2000
# name = model_20_m1_iter_125, n_topics = 20, n_doc_passes = 5, seed_value = 225, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:50:05.965000] current iteration 126 / 2000
# name = model_20_m1_iter_126, n_topics = 20, n_doc_passes = 5, seed_value = 226, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:50:16.117000] current iteration 127 / 2000
# name = model_20_m1_iter_127, n_topics = 20, n_doc_passes = 5, seed_value = 227, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:50:26.234000] current iteration 128 / 2000
# name = model_20_m1_iter_128, n_topics = 20, n_doc_passes = 5, seed_value = 228, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:50:36.402000] current iteration 129 / 2000
# name = model_20_m1_iter_129, n_topics = 20, n_doc_passes = 5, seed_value = 229, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:50:46.538000] current iteration 130 / 2000
# name = model_20_m1_iter_130, n_topics = 20, n_doc_passes = 5, seed_value = 230, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:50:56.622000] current iteration 131 / 2000
# name = model_20_m1_iter_131, n_topics = 20, n_doc_passes = 5, seed_value = 231, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:51:06.730000] current iteration 132 / 2000
# name = model_20_m1_iter_132, n_topics = 20, n_doc_passes = 5, seed_value = 232, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:51:17.110000] current iteration 133 / 2000
# name = model_20_m1_iter_133, n_topics = 20, n_doc_passes = 5, seed_value = 233, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:51:27.219000] current iteration 134 / 2000
# name = model_20_m1_iter_134, n_topics = 20, n_doc_passes = 5, seed_value = 234, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:51:37.237000] current iteration 135 / 2000
# name = model_20_m1_iter_135, n_topics = 20, n_doc_passes = 5, seed_value = 235, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:51:47.283000] current iteration 136 / 2000
# name = model_20_m1_iter_136, n_topics = 20, n_doc_passes = 5, seed_value = 236, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:51:57.444000] current iteration 137 / 2000
# name = model_20_m1_iter_137, n_topics = 20, n_doc_passes = 5, seed_value = 237, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:52:07.466000] current iteration 138 / 2000
# name = model_20_m1_iter_138, n_topics = 20, n_doc_passes = 5, seed_value = 238, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:52:17.634000] current iteration 139 / 2000
# name = model_20_m1_iter_139, n_topics = 20, n_doc_passes = 5, seed_value = 239, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:52:27.628000] current iteration 140 / 2000
# name = model_20_m1_iter_140, n_topics = 20, n_doc_passes = 5, seed_value = 240, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:52:37.778000] current iteration 141 / 2000
# name = model_20_m1_iter_141, n_topics = 20, n_doc_passes = 5, seed_value = 241, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:52:47.874000] current iteration 142 / 2000
# name = model_20_m1_iter_142, n_topics = 20, n_doc_passes = 5, seed_value = 242, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:52:57.866000] current iteration 143 / 2000
# name = model_20_m1_iter_143, n_topics = 20, n_doc_passes = 5, seed_value = 243, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:53:07.915000] current iteration 144 / 2000
# name = model_20_m1_iter_144, n_topics = 20, n_doc_passes = 5, seed_value = 244, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:53:18.141000] current iteration 145 / 2000
# name = model_20_m1_iter_145, n_topics = 20, n_doc_passes = 5, seed_value = 245, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:53:28.283000] current iteration 146 / 2000
# name = model_20_m1_iter_146, n_topics = 20, n_doc_passes = 5, seed_value = 246, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:53:38.255000] current iteration 147 / 2000
# name = model_20_m1_iter_147, n_topics = 20, n_doc_passes = 5, seed_value = 247, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:53:48.561000] current iteration 148 / 2000
# name = model_20_m1_iter_148, n_topics = 20, n_doc_passes = 5, seed_value = 248, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:53:58.642000] current iteration 149 / 2000
# name = model_20_m1_iter_149, n_topics = 20, n_doc_passes = 5, seed_value = 249, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:54:08.752000] current iteration 150 / 2000
# name = model_20_m1_iter_150, n_topics = 20, n_doc_passes = 5, seed_value = 250, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:54:18.878000] current iteration 151 / 2000
# name = model_20_m1_iter_151, n_topics = 20, n_doc_passes = 5, seed_value = 251, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:54:28.941000] current iteration 152 / 2000
# name = model_20_m1_iter_152, n_topics = 20, n_doc_passes = 5, seed_value = 252, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:54:39.048000] current iteration 153 / 2000
# name = model_20_m1_iter_153, n_topics = 20, n_doc_passes = 5, seed_value = 253, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:54:49.165000] current iteration 154 / 2000
# name = model_20_m1_iter_154, n_topics = 20, n_doc_passes = 5, seed_value = 254, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:54:59.246000] current iteration 155 / 2000
# name = model_20_m1_iter_155, n_topics = 20, n_doc_passes = 5, seed_value = 255, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:55:09.351000] current iteration 156 / 2000
# name = model_20_m1_iter_156, n_topics = 20, n_doc_passes = 5, seed_value = 256, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:55:19.584000] current iteration 157 / 2000
# name = model_20_m1_iter_157, n_topics = 20, n_doc_passes = 5, seed_value = 257, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:55:29.664000] current iteration 158 / 2000
# name = model_20_m1_iter_158, n_topics = 20, n_doc_passes = 5, seed_value = 258, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:55:39.697000] current iteration 159 / 2000
# name = model_20_m1_iter_159, n_topics = 20, n_doc_passes = 5, seed_value = 259, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:55:49.797000] current iteration 160 / 2000
# name = model_20_m1_iter_160, n_topics = 20, n_doc_passes = 5, seed_value = 260, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:55:59.936000] current iteration 161 / 2000
# name = model_20_m1_iter_161, n_topics = 20, n_doc_passes = 5, seed_value = 261, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:56:10.072000] current iteration 162 / 2000
# name = model_20_m1_iter_162, n_topics = 20, n_doc_passes = 5, seed_value = 262, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:56:20.178000] current iteration 163 / 2000
# name = model_20_m1_iter_163, n_topics = 20, n_doc_passes = 5, seed_value = 263, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:56:30.257000] current iteration 164 / 2000
# name = model_20_m1_iter_164, n_topics = 20, n_doc_passes = 5, seed_value = 264, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:56:40.460000] current iteration 165 / 2000
# name = model_20_m1_iter_165, n_topics = 20, n_doc_passes = 5, seed_value = 265, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:56:50.629000] current iteration 166 / 2000
# name = model_20_m1_iter_166, n_topics = 20, n_doc_passes = 5, seed_value = 266, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:57:00.794000] current iteration 167 / 2000
# name = model_20_m1_iter_167, n_topics = 20, n_doc_passes = 5, seed_value = 267, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:57:10.978000] current iteration 168 / 2000
# name = model_20_m1_iter_168, n_topics = 20, n_doc_passes = 5, seed_value = 268, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:57:21.147000] current iteration 169 / 2000
# name = model_20_m1_iter_169, n_topics = 20, n_doc_passes = 5, seed_value = 269, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:57:31.253000] current iteration 170 / 2000
# name = model_20_m1_iter_170, n_topics = 20, n_doc_passes = 5, seed_value = 270, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:57:41.277000] current iteration 171 / 2000
# name = model_20_m1_iter_171, n_topics = 20, n_doc_passes = 5, seed_value = 271, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:57:51.362000] current iteration 172 / 2000
# name = model_20_m1_iter_172, n_topics = 20, n_doc_passes = 5, seed_value = 272, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:58:01.485000] current iteration 173 / 2000
# name = model_20_m1_iter_173, n_topics = 20, n_doc_passes = 5, seed_value = 273, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:58:11.579000] current iteration 174 / 2000
# name = model_20_m1_iter_174, n_topics = 20, n_doc_passes = 5, seed_value = 274, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:58:21.655000] current iteration 175 / 2000
# name = model_20_m1_iter_175, n_topics = 20, n_doc_passes = 5, seed_value = 275, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:58:31.704000] current iteration 176 / 2000
# name = model_20_m1_iter_176, n_topics = 20, n_doc_passes = 5, seed_value = 276, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:58:41.905000] current iteration 177 / 2000
# name = model_20_m1_iter_177, n_topics = 20, n_doc_passes = 5, seed_value = 277, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:58:52.047000] current iteration 178 / 2000
# name = model_20_m1_iter_178, n_topics = 20, n_doc_passes = 5, seed_value = 278, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:59:02.066000] current iteration 179 / 2000
# name = model_20_m1_iter_179, n_topics = 20, n_doc_passes = 5, seed_value = 279, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:59:12.026000] current iteration 180 / 2000
# name = model_20_m1_iter_180, n_topics = 20, n_doc_passes = 5, seed_value = 280, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:59:22.246000] current iteration 181 / 2000
# name = model_20_m1_iter_181, n_topics = 20, n_doc_passes = 5, seed_value = 281, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:59:32.304000] current iteration 182 / 2000
# name = model_20_m1_iter_182, n_topics = 20, n_doc_passes = 5, seed_value = 282, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:59:42.355000] current iteration 183 / 2000
# name = model_20_m1_iter_183, n_topics = 20, n_doc_passes = 5, seed_value = 283, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 01:59:52.528000] current iteration 184 / 2000
# name = model_20_m1_iter_184, n_topics = 20, n_doc_passes = 5, seed_value = 284, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:00:02.726000] current iteration 185 / 2000
# name = model_20_m1_iter_185, n_topics = 20, n_doc_passes = 5, seed_value = 285, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:00:12.833000] current iteration 186 / 2000
# name = model_20_m1_iter_186, n_topics = 20, n_doc_passes = 5, seed_value = 286, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:00:22.912000] current iteration 187 / 2000
# name = model_20_m1_iter_187, n_topics = 20, n_doc_passes = 5, seed_value = 287, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:00:33.020000] current iteration 188 / 2000
# name = model_20_m1_iter_188, n_topics = 20, n_doc_passes = 5, seed_value = 288, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:00:43.162000] current iteration 189 / 2000
# name = model_20_m1_iter_189, n_topics = 20, n_doc_passes = 5, seed_value = 289, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:00:53.390000] current iteration 190 / 2000
# name = model_20_m1_iter_190, n_topics = 20, n_doc_passes = 5, seed_value = 290, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:01:03.590000] current iteration 191 / 2000
# name = model_20_m1_iter_191, n_topics = 20, n_doc_passes = 5, seed_value = 291, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:01:13.755000] current iteration 192 / 2000
# name = model_20_m1_iter_192, n_topics = 20, n_doc_passes = 5, seed_value = 292, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:01:23.957000] current iteration 193 / 2000
# name = model_20_m1_iter_193, n_topics = 20, n_doc_passes = 5, seed_value = 293, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:01:34.128000] current iteration 194 / 2000
# name = model_20_m1_iter_194, n_topics = 20, n_doc_passes = 5, seed_value = 294, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:01:44.264000] current iteration 195 / 2000
# name = model_20_m1_iter_195, n_topics = 20, n_doc_passes = 5, seed_value = 295, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:01:54.354000] current iteration 196 / 2000
# name = model_20_m1_iter_196, n_topics = 20, n_doc_passes = 5, seed_value = 296, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:02:04.530000] current iteration 197 / 2000
# name = model_20_m1_iter_197, n_topics = 20, n_doc_passes = 5, seed_value = 297, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:02:14.695000] current iteration 198 / 2000
# name = model_20_m1_iter_198, n_topics = 20, n_doc_passes = 5, seed_value = 298, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:02:24.837000] current iteration 199 / 2000
# name = model_20_m1_iter_199, n_topics = 20, n_doc_passes = 5, seed_value = 299, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:02:34.975000] current iteration 200 / 2000
# name = model_20_m1_iter_200, n_topics = 20, n_doc_passes = 5, seed_value = 300, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:02:45.113000] current iteration 201 / 2000
# name = model_20_m1_iter_201, n_topics = 20, n_doc_passes = 5, seed_value = 301, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:02:55.192000] current iteration 202 / 2000
# name = model_20_m1_iter_202, n_topics = 20, n_doc_passes = 5, seed_value = 302, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:03:05.304000] current iteration 203 / 2000
# name = model_20_m1_iter_203, n_topics = 20, n_doc_passes = 5, seed_value = 303, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:03:15.300000] current iteration 204 / 2000
# name = model_20_m1_iter_204, n_topics = 20, n_doc_passes = 5, seed_value = 304, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:03:25.443000] current iteration 205 / 2000
# name = model_20_m1_iter_205, n_topics = 20, n_doc_passes = 5, seed_value = 305, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:03:35.637000] current iteration 206 / 2000
# name = model_20_m1_iter_206, n_topics = 20, n_doc_passes = 5, seed_value = 306, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:03:45.761000] current iteration 207 / 2000
# name = model_20_m1_iter_207, n_topics = 20, n_doc_passes = 5, seed_value = 307, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:03:55.787000] current iteration 208 / 2000
# name = model_20_m1_iter_208, n_topics = 20, n_doc_passes = 5, seed_value = 308, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:04:05.902000] current iteration 209 / 2000
# name = model_20_m1_iter_209, n_topics = 20, n_doc_passes = 5, seed_value = 309, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:04:16.011000] current iteration 210 / 2000
# name = model_20_m1_iter_210, n_topics = 20, n_doc_passes = 5, seed_value = 310, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:04:26.123000] current iteration 211 / 2000
# name = model_20_m1_iter_211, n_topics = 20, n_doc_passes = 5, seed_value = 311, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:04:36.042000] current iteration 212 / 2000
# name = model_20_m1_iter_212, n_topics = 20, n_doc_passes = 5, seed_value = 312, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:04:46.193000] current iteration 213 / 2000
# name = model_20_m1_iter_213, n_topics = 20, n_doc_passes = 5, seed_value = 313, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:04:56.343000] current iteration 214 / 2000
# name = model_20_m1_iter_214, n_topics = 20, n_doc_passes = 5, seed_value = 314, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:05:06.358000] current iteration 215 / 2000
# name = model_20_m1_iter_215, n_topics = 20, n_doc_passes = 5, seed_value = 315, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:05:16.457000] current iteration 216 / 2000
# name = model_20_m1_iter_216, n_topics = 20, n_doc_passes = 5, seed_value = 316, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:05:26.734000] current iteration 217 / 2000
# name = model_20_m1_iter_217, n_topics = 20, n_doc_passes = 5, seed_value = 317, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:05:36.887000] current iteration 218 / 2000
# name = model_20_m1_iter_218, n_topics = 20, n_doc_passes = 5, seed_value = 318, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:05:46.967000] current iteration 219 / 2000
# name = model_20_m1_iter_219, n_topics = 20, n_doc_passes = 5, seed_value = 319, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:05:57.145000] current iteration 220 / 2000
# name = model_20_m1_iter_220, n_topics = 20, n_doc_passes = 5, seed_value = 320, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:06:07.408000] current iteration 221 / 2000
# name = model_20_m1_iter_221, n_topics = 20, n_doc_passes = 5, seed_value = 321, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:06:17.455000] current iteration 222 / 2000
# name = model_20_m1_iter_222, n_topics = 20, n_doc_passes = 5, seed_value = 322, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:06:27.624000] current iteration 223 / 2000
# name = model_20_m1_iter_223, n_topics = 20, n_doc_passes = 5, seed_value = 323, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:06:37.681000] current iteration 224 / 2000
# name = model_20_m1_iter_224, n_topics = 20, n_doc_passes = 5, seed_value = 324, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:06:47.873000] current iteration 225 / 2000
# name = model_20_m1_iter_225, n_topics = 20, n_doc_passes = 5, seed_value = 325, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:06:58.016000] current iteration 226 / 2000
# name = model_20_m1_iter_226, n_topics = 20, n_doc_passes = 5, seed_value = 326, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:07:07.977000] current iteration 227 / 2000
# name = model_20_m1_iter_227, n_topics = 20, n_doc_passes = 5, seed_value = 327, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:07:18.139000] current iteration 228 / 2000
# name = model_20_m1_iter_228, n_topics = 20, n_doc_passes = 5, seed_value = 328, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:07:28.346000] current iteration 229 / 2000
# name = model_20_m1_iter_229, n_topics = 20, n_doc_passes = 5, seed_value = 329, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:07:38.413000] current iteration 230 / 2000
# name = model_20_m1_iter_230, n_topics = 20, n_doc_passes = 5, seed_value = 330, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 02:07:48.475000] current iteration 231 / 2000
# name = model_20_m1_iter_231, n_topics = 20, n_doc_passes = 5, seed_value = 331, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# ...
#
# [2017-03-10 06:55:15.289000] current iteration 1925 / 2000
# name = model_20_m1_iter_1925, n_topics = 20, n_doc_passes = 5, seed_value = 2025, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:55:25.340000] current iteration 1926 / 2000
# name = model_20_m1_iter_1926, n_topics = 20, n_doc_passes = 5, seed_value = 2026, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:55:35.521000] current iteration 1927 / 2000
# name = model_20_m1_iter_1927, n_topics = 20, n_doc_passes = 5, seed_value = 2027, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:55:45.627000] current iteration 1928 / 2000
# name = model_20_m1_iter_1928, n_topics = 20, n_doc_passes = 5, seed_value = 2028, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:55:55.793000] current iteration 1929 / 2000
# name = model_20_m1_iter_1929, n_topics = 20, n_doc_passes = 5, seed_value = 2029, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:56:05.983000] current iteration 1930 / 2000
# name = model_20_m1_iter_1930, n_topics = 20, n_doc_passes = 5, seed_value = 2030, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:56:15.971000] current iteration 1931 / 2000
# name = model_20_m1_iter_1931, n_topics = 20, n_doc_passes = 5, seed_value = 2031, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:56:26.083000] current iteration 1932 / 2000
# name = model_20_m1_iter_1932, n_topics = 20, n_doc_passes = 5, seed_value = 2032, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:56:36.238000] current iteration 1933 / 2000
# name = model_20_m1_iter_1933, n_topics = 20, n_doc_passes = 5, seed_value = 2033, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:56:46.354000] current iteration 1934 / 2000
# name = model_20_m1_iter_1934, n_topics = 20, n_doc_passes = 5, seed_value = 2034, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:56:56.505000] current iteration 1935 / 2000
# name = model_20_m1_iter_1935, n_topics = 20, n_doc_passes = 5, seed_value = 2035, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:57:06.660000] current iteration 1936 / 2000
# name = model_20_m1_iter_1936, n_topics = 20, n_doc_passes = 5, seed_value = 2036, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:57:16.904000] current iteration 1937 / 2000
# name = model_20_m1_iter_1937, n_topics = 20, n_doc_passes = 5, seed_value = 2037, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:57:27.114000] current iteration 1938 / 2000
# name = model_20_m1_iter_1938, n_topics = 20, n_doc_passes = 5, seed_value = 2038, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:57:37.272000] current iteration 1939 / 2000
# name = model_20_m1_iter_1939, n_topics = 20, n_doc_passes = 5, seed_value = 2039, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:57:47.407000] current iteration 1940 / 2000
# name = model_20_m1_iter_1940, n_topics = 20, n_doc_passes = 5, seed_value = 2040, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:57:57.480000] current iteration 1941 / 2000
# name = model_20_m1_iter_1941, n_topics = 20, n_doc_passes = 5, seed_value = 2041, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:58:07.623000] current iteration 1942 / 2000
# name = model_20_m1_iter_1942, n_topics = 20, n_doc_passes = 5, seed_value = 2042, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:58:17.816000] current iteration 1943 / 2000
# name = model_20_m1_iter_1943, n_topics = 20, n_doc_passes = 5, seed_value = 2043, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:58:27.936000] current iteration 1944 / 2000
# name = model_20_m1_iter_1944, n_topics = 20, n_doc_passes = 5, seed_value = 2044, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:58:37.974000] current iteration 1945 / 2000
# name = model_20_m1_iter_1945, n_topics = 20, n_doc_passes = 5, seed_value = 2045, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:58:48.220000] current iteration 1946 / 2000
# name = model_20_m1_iter_1946, n_topics = 20, n_doc_passes = 5, seed_value = 2046, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:58:58.394000] current iteration 1947 / 2000
# name = model_20_m1_iter_1947, n_topics = 20, n_doc_passes = 5, seed_value = 2047, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:59:08.461000] current iteration 1948 / 2000
# name = model_20_m1_iter_1948, n_topics = 20, n_doc_passes = 5, seed_value = 2048, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:59:18.601000] current iteration 1949 / 2000
# name = model_20_m1_iter_1949, n_topics = 20, n_doc_passes = 5, seed_value = 2049, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:59:28.649000] current iteration 1950 / 2000
# name = model_20_m1_iter_1950, n_topics = 20, n_doc_passes = 5, seed_value = 2050, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:59:38.752000] current iteration 1951 / 2000
# name = model_20_m1_iter_1951, n_topics = 20, n_doc_passes = 5, seed_value = 2051, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:59:48.921000] current iteration 1952 / 2000
# name = model_20_m1_iter_1952, n_topics = 20, n_doc_passes = 5, seed_value = 2052, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 06:59:59.148000] current iteration 1953 / 2000
# name = model_20_m1_iter_1953, n_topics = 20, n_doc_passes = 5, seed_value = 2053, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:00:09.350000] current iteration 1954 / 2000
# name = model_20_m1_iter_1954, n_topics = 20, n_doc_passes = 5, seed_value = 2054, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:00:19.549000] current iteration 1955 / 2000
# name = model_20_m1_iter_1955, n_topics = 20, n_doc_passes = 5, seed_value = 2055, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:00:29.636000] current iteration 1956 / 2000
# name = model_20_m1_iter_1956, n_topics = 20, n_doc_passes = 5, seed_value = 2056, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:00:39.839000] current iteration 1957 / 2000
# name = model_20_m1_iter_1957, n_topics = 20, n_doc_passes = 5, seed_value = 2057, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:00:49.949000] current iteration 1958 / 2000
# name = model_20_m1_iter_1958, n_topics = 20, n_doc_passes = 5, seed_value = 2058, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:00:59.996000] current iteration 1959 / 2000
# name = model_20_m1_iter_1959, n_topics = 20, n_doc_passes = 5, seed_value = 2059, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:01:10.046000] current iteration 1960 / 2000
# name = model_20_m1_iter_1960, n_topics = 20, n_doc_passes = 5, seed_value = 2060, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:01:20.185000] current iteration 1961 / 2000
# name = model_20_m1_iter_1961, n_topics = 20, n_doc_passes = 5, seed_value = 2061, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:01:30.397000] current iteration 1962 / 2000
# name = model_20_m1_iter_1962, n_topics = 20, n_doc_passes = 5, seed_value = 2062, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:01:40.572000] current iteration 1963 / 2000
# name = model_20_m1_iter_1963, n_topics = 20, n_doc_passes = 5, seed_value = 2063, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:01:50.722000] current iteration 1964 / 2000
# name = model_20_m1_iter_1964, n_topics = 20, n_doc_passes = 5, seed_value = 2064, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:02:00.858000] current iteration 1965 / 2000
# name = model_20_m1_iter_1965, n_topics = 20, n_doc_passes = 5, seed_value = 2065, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:02:10.979000] current iteration 1966 / 2000
# name = model_20_m1_iter_1966, n_topics = 20, n_doc_passes = 5, seed_value = 2066, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:02:21.114000] current iteration 1967 / 2000
# name = model_20_m1_iter_1967, n_topics = 20, n_doc_passes = 5, seed_value = 2067, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:02:31.133000] current iteration 1968 / 2000
# name = model_20_m1_iter_1968, n_topics = 20, n_doc_passes = 5, seed_value = 2068, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:02:41.222000] current iteration 1969 / 2000
# name = model_20_m1_iter_1969, n_topics = 20, n_doc_passes = 5, seed_value = 2069, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:02:51.436000] current iteration 1970 / 2000
# name = model_20_m1_iter_1970, n_topics = 20, n_doc_passes = 5, seed_value = 2070, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:03:01.370000] current iteration 1971 / 2000
# name = model_20_m1_iter_1971, n_topics = 20, n_doc_passes = 5, seed_value = 2071, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:03:11.365000] current iteration 1972 / 2000
# name = model_20_m1_iter_1972, n_topics = 20, n_doc_passes = 5, seed_value = 2072, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:03:21.479000] current iteration 1973 / 2000
# name = model_20_m1_iter_1973, n_topics = 20, n_doc_passes = 5, seed_value = 2073, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:03:31.596000] current iteration 1974 / 2000
# name = model_20_m1_iter_1974, n_topics = 20, n_doc_passes = 5, seed_value = 2074, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:03:41.659000] current iteration 1975 / 2000
# name = model_20_m1_iter_1975, n_topics = 20, n_doc_passes = 5, seed_value = 2075, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:03:51.848000] current iteration 1976 / 2000
# name = model_20_m1_iter_1976, n_topics = 20, n_doc_passes = 5, seed_value = 2076, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:04:02.044000] current iteration 1977 / 2000
# name = model_20_m1_iter_1977, n_topics = 20, n_doc_passes = 5, seed_value = 2077, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:04:12.297000] current iteration 1978 / 2000
# name = model_20_m1_iter_1978, n_topics = 20, n_doc_passes = 5, seed_value = 2078, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:04:22.450000] current iteration 1979 / 2000
# name = model_20_m1_iter_1979, n_topics = 20, n_doc_passes = 5, seed_value = 2079, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:04:32.573000] current iteration 1980 / 2000
# name = model_20_m1_iter_1980, n_topics = 20, n_doc_passes = 5, seed_value = 2080, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:04:42.713000] current iteration 1981 / 2000
# name = model_20_m1_iter_1981, n_topics = 20, n_doc_passes = 5, seed_value = 2081, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:04:52.851000] current iteration 1982 / 2000
# name = model_20_m1_iter_1982, n_topics = 20, n_doc_passes = 5, seed_value = 2082, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:05:02.988000] current iteration 1983 / 2000
# name = model_20_m1_iter_1983, n_topics = 20, n_doc_passes = 5, seed_value = 2083, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:05:13.194000] current iteration 1984 / 2000
# name = model_20_m1_iter_1984, n_topics = 20, n_doc_passes = 5, seed_value = 2084, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:05:23.360000] current iteration 1985 / 2000
# name = model_20_m1_iter_1985, n_topics = 20, n_doc_passes = 5, seed_value = 2085, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:05:33.578000] current iteration 1986 / 2000
# name = model_20_m1_iter_1986, n_topics = 20, n_doc_passes = 5, seed_value = 2086, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:05:43.776000] current iteration 1987 / 2000
# name = model_20_m1_iter_1987, n_topics = 20, n_doc_passes = 5, seed_value = 2087, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:05:53.929000] current iteration 1988 / 2000
# name = model_20_m1_iter_1988, n_topics = 20, n_doc_passes = 5, seed_value = 2088, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:06:04.025000] current iteration 1989 / 2000
# name = model_20_m1_iter_1989, n_topics = 20, n_doc_passes = 5, seed_value = 2089, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:06:14.129000] current iteration 1990 / 2000
# name = model_20_m1_iter_1990, n_topics = 20, n_doc_passes = 5, seed_value = 2090, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:06:24.175000] current iteration 1991 / 2000
# name = model_20_m1_iter_1991, n_topics = 20, n_doc_passes = 5, seed_value = 2091, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:06:34.279000] current iteration 1992 / 2000
# name = model_20_m1_iter_1992, n_topics = 20, n_doc_passes = 5, seed_value = 2092, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:06:44.548000] current iteration 1993 / 2000
# name = model_20_m1_iter_1993, n_topics = 20, n_doc_passes = 5, seed_value = 2093, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:06:54.644000] current iteration 1994 / 2000
# name = model_20_m1_iter_1994, n_topics = 20, n_doc_passes = 5, seed_value = 2094, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:07:04.779000] current iteration 1995 / 2000
# name = model_20_m1_iter_1995, n_topics = 20, n_doc_passes = 5, seed_value = 2095, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:07:14.782000] current iteration 1996 / 2000
# name = model_20_m1_iter_1996, n_topics = 20, n_doc_passes = 5, seed_value = 2096, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:07:24.895000] current iteration 1997 / 2000
# name = model_20_m1_iter_1997, n_topics = 20, n_doc_passes = 5, seed_value = 2097, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:07:34.973000] current iteration 1998 / 2000
# name = model_20_m1_iter_1998, n_topics = 20, n_doc_passes = 5, seed_value = 2098, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:07:45.003000] current iteration 1999 / 2000
# name = model_20_m1_iter_1999, n_topics = 20, n_doc_passes = 5, seed_value = 2099, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 07:07:55.114000] current iteration 2000 / 2000

# %%
tmp_models_range = []
tmp_models_range = create_models_range(create_model_fn_2, 'model_100_no_reg', n_iterations=200)
# Out:
# name = model_100_m2_iter_0, n_topics = 100, n_doc_passes = 5, seed_value = 100, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:02:54.107000] current iteration 1 / 200
# name = model_100_m2_iter_1, n_topics = 100, n_doc_passes = 5, seed_value = 101, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:03:18.399000] current iteration 2 / 200
# name = model_100_m2_iter_2, n_topics = 100, n_doc_passes = 5, seed_value = 102, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:03:42.518000] current iteration 3 / 200
# name = model_100_m2_iter_3, n_topics = 100, n_doc_passes = 5, seed_value = 103, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:04:06.081000] current iteration 4 / 200
# name = model_100_m2_iter_4, n_topics = 100, n_doc_passes = 5, seed_value = 104, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:04:29.660000] current iteration 5 / 200
# name = model_100_m2_iter_5, n_topics = 100, n_doc_passes = 5, seed_value = 105, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:04:53.270000] current iteration 6 / 200
# name = model_100_m2_iter_6, n_topics = 100, n_doc_passes = 5, seed_value = 106, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:05:16.731000] current iteration 7 / 200
# name = model_100_m2_iter_7, n_topics = 100, n_doc_passes = 5, seed_value = 107, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:05:40.422000] current iteration 8 / 200
# name = model_100_m2_iter_8, n_topics = 100, n_doc_passes = 5, seed_value = 108, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:06:04.059000] current iteration 9 / 200
# name = model_100_m2_iter_9, n_topics = 100, n_doc_passes = 5, seed_value = 109, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:06:27.518000] current iteration 10 / 200
# name = model_100_m2_iter_10, n_topics = 100, n_doc_passes = 5, seed_value = 110, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:06:51.176000] current iteration 11 / 200
# name = model_100_m2_iter_11, n_topics = 100, n_doc_passes = 5, seed_value = 111, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:07:14.842000] current iteration 12 / 200
# name = model_100_m2_iter_12, n_topics = 100, n_doc_passes = 5, seed_value = 112, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:07:38.464000] current iteration 13 / 200
# name = model_100_m2_iter_13, n_topics = 100, n_doc_passes = 5, seed_value = 113, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:08:01.943000] current iteration 14 / 200
# name = model_100_m2_iter_14, n_topics = 100, n_doc_passes = 5, seed_value = 114, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:08:25.462000] current iteration 15 / 200
# name = model_100_m2_iter_15, n_topics = 100, n_doc_passes = 5, seed_value = 115, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:08:49.031000] current iteration 16 / 200
# name = model_100_m2_iter_16, n_topics = 100, n_doc_passes = 5, seed_value = 116, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:09:12.575000] current iteration 17 / 200
# name = model_100_m2_iter_17, n_topics = 100, n_doc_passes = 5, seed_value = 117, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:09:36.238000] current iteration 18 / 200
# name = model_100_m2_iter_18, n_topics = 100, n_doc_passes = 5, seed_value = 118, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:09:59.933000] current iteration 19 / 200
# name = model_100_m2_iter_19, n_topics = 100, n_doc_passes = 5, seed_value = 119, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:10:23.563000] current iteration 20 / 200
# name = model_100_m2_iter_20, n_topics = 100, n_doc_passes = 5, seed_value = 120, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:10:47.045000] current iteration 21 / 200
# name = model_100_m2_iter_21, n_topics = 100, n_doc_passes = 5, seed_value = 121, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:11:10.766000] current iteration 22 / 200
# name = model_100_m2_iter_22, n_topics = 100, n_doc_passes = 5, seed_value = 122, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:11:34.255000] current iteration 23 / 200
# name = model_100_m2_iter_23, n_topics = 100, n_doc_passes = 5, seed_value = 123, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:11:57.866000] current iteration 24 / 200
# name = model_100_m2_iter_24, n_topics = 100, n_doc_passes = 5, seed_value = 124, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:12:21.503000] current iteration 25 / 200
# name = model_100_m2_iter_25, n_topics = 100, n_doc_passes = 5, seed_value = 125, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:12:45.007000] current iteration 26 / 200
# name = model_100_m2_iter_26, n_topics = 100, n_doc_passes = 5, seed_value = 126, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:13:08.677000] current iteration 27 / 200
# name = model_100_m2_iter_27, n_topics = 100, n_doc_passes = 5, seed_value = 127, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:13:32.222000] current iteration 28 / 200
# name = model_100_m2_iter_28, n_topics = 100, n_doc_passes = 5, seed_value = 128, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:13:55.716000] current iteration 29 / 200
# name = model_100_m2_iter_29, n_topics = 100, n_doc_passes = 5, seed_value = 129, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:14:19.288000] current iteration 30 / 200
# name = model_100_m2_iter_30, n_topics = 100, n_doc_passes = 5, seed_value = 130, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:14:42.834000] current iteration 31 / 200
# name = model_100_m2_iter_31, n_topics = 100, n_doc_passes = 5, seed_value = 131, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:15:06.249000] current iteration 32 / 200
# name = model_100_m2_iter_32, n_topics = 100, n_doc_passes = 5, seed_value = 132, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:15:29.842000] current iteration 33 / 200
# name = model_100_m2_iter_33, n_topics = 100, n_doc_passes = 5, seed_value = 133, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:15:53.314000] current iteration 34 / 200
# name = model_100_m2_iter_34, n_topics = 100, n_doc_passes = 5, seed_value = 134, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:16:16.883000] current iteration 35 / 200
# name = model_100_m2_iter_35, n_topics = 100, n_doc_passes = 5, seed_value = 135, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:16:40.344000] current iteration 36 / 200
# name = model_100_m2_iter_36, n_topics = 100, n_doc_passes = 5, seed_value = 136, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:17:03.857000] current iteration 37 / 200
# name = model_100_m2_iter_37, n_topics = 100, n_doc_passes = 5, seed_value = 137, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:17:27.621000] current iteration 38 / 200
# name = model_100_m2_iter_38, n_topics = 100, n_doc_passes = 5, seed_value = 138, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:17:51.084000] current iteration 39 / 200
# name = model_100_m2_iter_39, n_topics = 100, n_doc_passes = 5, seed_value = 139, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:18:14.538000] current iteration 40 / 200
# name = model_100_m2_iter_40, n_topics = 100, n_doc_passes = 5, seed_value = 140, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:18:38.323000] current iteration 41 / 200
# name = model_100_m2_iter_41, n_topics = 100, n_doc_passes = 5, seed_value = 141, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:19:01.794000] current iteration 42 / 200
# name = model_100_m2_iter_42, n_topics = 100, n_doc_passes = 5, seed_value = 142, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:19:25.481000] current iteration 43 / 200
# name = model_100_m2_iter_43, n_topics = 100, n_doc_passes = 5, seed_value = 143, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:19:49.132000] current iteration 44 / 200
# name = model_100_m2_iter_44, n_topics = 100, n_doc_passes = 5, seed_value = 144, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:20:12.784000] current iteration 45 / 200
# name = model_100_m2_iter_45, n_topics = 100, n_doc_passes = 5, seed_value = 145, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:20:36.468000] current iteration 46 / 200
# name = model_100_m2_iter_46, n_topics = 100, n_doc_passes = 5, seed_value = 146, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:21:00.120000] current iteration 47 / 200
# name = model_100_m2_iter_47, n_topics = 100, n_doc_passes = 5, seed_value = 147, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:21:23.819000] current iteration 48 / 200
# name = model_100_m2_iter_48, n_topics = 100, n_doc_passes = 5, seed_value = 148, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:21:47.310000] current iteration 49 / 200
# name = model_100_m2_iter_49, n_topics = 100, n_doc_passes = 5, seed_value = 149, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:22:10.795000] current iteration 50 / 200
# name = model_100_m2_iter_50, n_topics = 100, n_doc_passes = 5, seed_value = 150, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:22:34.434000] current iteration 51 / 200
# name = model_100_m2_iter_51, n_topics = 100, n_doc_passes = 5, seed_value = 151, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:22:57.963000] current iteration 52 / 200
# name = model_100_m2_iter_52, n_topics = 100, n_doc_passes = 5, seed_value = 152, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:23:21.515000] current iteration 53 / 200
# name = model_100_m2_iter_53, n_topics = 100, n_doc_passes = 5, seed_value = 153, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:23:45.024000] current iteration 54 / 200
# name = model_100_m2_iter_54, n_topics = 100, n_doc_passes = 5, seed_value = 154, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:24:08.454000] current iteration 55 / 200
# name = model_100_m2_iter_55, n_topics = 100, n_doc_passes = 5, seed_value = 155, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:24:31.901000] current iteration 56 / 200
# name = model_100_m2_iter_56, n_topics = 100, n_doc_passes = 5, seed_value = 156, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:24:55.389000] current iteration 57 / 200
# name = model_100_m2_iter_57, n_topics = 100, n_doc_passes = 5, seed_value = 157, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:25:18.880000] current iteration 58 / 200
# name = model_100_m2_iter_58, n_topics = 100, n_doc_passes = 5, seed_value = 158, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:25:42.644000] current iteration 59 / 200
# name = model_100_m2_iter_59, n_topics = 100, n_doc_passes = 5, seed_value = 159, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:26:06.373000] current iteration 60 / 200
# name = model_100_m2_iter_60, n_topics = 100, n_doc_passes = 5, seed_value = 160, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:26:29.939000] current iteration 61 / 200
# name = model_100_m2_iter_61, n_topics = 100, n_doc_passes = 5, seed_value = 161, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:26:53.648000] current iteration 62 / 200
# name = model_100_m2_iter_62, n_topics = 100, n_doc_passes = 5, seed_value = 162, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:27:17.200000] current iteration 63 / 200
# name = model_100_m2_iter_63, n_topics = 100, n_doc_passes = 5, seed_value = 163, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:27:40.887000] current iteration 64 / 200
# name = model_100_m2_iter_64, n_topics = 100, n_doc_passes = 5, seed_value = 164, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:28:04.380000] current iteration 65 / 200
# name = model_100_m2_iter_65, n_topics = 100, n_doc_passes = 5, seed_value = 165, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:28:27.805000] current iteration 66 / 200
# name = model_100_m2_iter_66, n_topics = 100, n_doc_passes = 5, seed_value = 166, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:28:51.248000] current iteration 67 / 200
# name = model_100_m2_iter_67, n_topics = 100, n_doc_passes = 5, seed_value = 167, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:29:14.775000] current iteration 68 / 200
# name = model_100_m2_iter_68, n_topics = 100, n_doc_passes = 5, seed_value = 168, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:29:38.473000] current iteration 69 / 200
# name = model_100_m2_iter_69, n_topics = 100, n_doc_passes = 5, seed_value = 169, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:30:01.920000] current iteration 70 / 200
# name = model_100_m2_iter_70, n_topics = 100, n_doc_passes = 5, seed_value = 170, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:30:25.468000] current iteration 71 / 200
# name = model_100_m2_iter_71, n_topics = 100, n_doc_passes = 5, seed_value = 171, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:30:49.142000] current iteration 72 / 200
# name = model_100_m2_iter_72, n_topics = 100, n_doc_passes = 5, seed_value = 172, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:31:12.707000] current iteration 73 / 200
# name = model_100_m2_iter_73, n_topics = 100, n_doc_passes = 5, seed_value = 173, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:31:36.390000] current iteration 74 / 200
# name = model_100_m2_iter_74, n_topics = 100, n_doc_passes = 5, seed_value = 174, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:31:59.848000] current iteration 75 / 200
# name = model_100_m2_iter_75, n_topics = 100, n_doc_passes = 5, seed_value = 175, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:32:23.278000] current iteration 76 / 200
# name = model_100_m2_iter_76, n_topics = 100, n_doc_passes = 5, seed_value = 176, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:32:46.885000] current iteration 77 / 200
# name = model_100_m2_iter_77, n_topics = 100, n_doc_passes = 5, seed_value = 177, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:33:10.501000] current iteration 78 / 200
# name = model_100_m2_iter_78, n_topics = 100, n_doc_passes = 5, seed_value = 178, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:33:34.048000] current iteration 79 / 200
# name = model_100_m2_iter_79, n_topics = 100, n_doc_passes = 5, seed_value = 179, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:33:57.620000] current iteration 80 / 200
# name = model_100_m2_iter_80, n_topics = 100, n_doc_passes = 5, seed_value = 180, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:34:21.306000] current iteration 81 / 200
# name = model_100_m2_iter_81, n_topics = 100, n_doc_passes = 5, seed_value = 181, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:34:44.831000] current iteration 82 / 200
# name = model_100_m2_iter_82, n_topics = 100, n_doc_passes = 5, seed_value = 182, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:35:08.526000] current iteration 83 / 200
# name = model_100_m2_iter_83, n_topics = 100, n_doc_passes = 5, seed_value = 183, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:35:32.016000] current iteration 84 / 200
# name = model_100_m2_iter_84, n_topics = 100, n_doc_passes = 5, seed_value = 184, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:35:55.472000] current iteration 85 / 200
# name = model_100_m2_iter_85, n_topics = 100, n_doc_passes = 5, seed_value = 185, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:36:18.992000] current iteration 86 / 200
# name = model_100_m2_iter_86, n_topics = 100, n_doc_passes = 5, seed_value = 186, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:36:42.618000] current iteration 87 / 200
# name = model_100_m2_iter_87, n_topics = 100, n_doc_passes = 5, seed_value = 187, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:37:06.216000] current iteration 88 / 200
# name = model_100_m2_iter_88, n_topics = 100, n_doc_passes = 5, seed_value = 188, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:37:29.834000] current iteration 89 / 200
# name = model_100_m2_iter_89, n_topics = 100, n_doc_passes = 5, seed_value = 189, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:37:53.527000] current iteration 90 / 200
# name = model_100_m2_iter_90, n_topics = 100, n_doc_passes = 5, seed_value = 190, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:38:17.013000] current iteration 91 / 200
# name = model_100_m2_iter_91, n_topics = 100, n_doc_passes = 5, seed_value = 191, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:38:40.507000] current iteration 92 / 200
# name = model_100_m2_iter_92, n_topics = 100, n_doc_passes = 5, seed_value = 192, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:39:04.059000] current iteration 93 / 200
# name = model_100_m2_iter_93, n_topics = 100, n_doc_passes = 5, seed_value = 193, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:39:27.779000] current iteration 94 / 200
# name = model_100_m2_iter_94, n_topics = 100, n_doc_passes = 5, seed_value = 194, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:39:51.464000] current iteration 95 / 200
# name = model_100_m2_iter_95, n_topics = 100, n_doc_passes = 5, seed_value = 195, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:40:15.089000] current iteration 96 / 200
# name = model_100_m2_iter_96, n_topics = 100, n_doc_passes = 5, seed_value = 196, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:40:38.874000] current iteration 97 / 200
# name = model_100_m2_iter_97, n_topics = 100, n_doc_passes = 5, seed_value = 197, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:41:02.219000] current iteration 98 / 200
# name = model_100_m2_iter_98, n_topics = 100, n_doc_passes = 5, seed_value = 198, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:41:25.793000] current iteration 99 / 200
# name = model_100_m2_iter_99, n_topics = 100, n_doc_passes = 5, seed_value = 199, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:41:49.279000] current iteration 100 / 200
# name = model_100_m2_iter_100, n_topics = 100, n_doc_passes = 5, seed_value = 200, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:42:12.909000] current iteration 101 / 200
# name = model_100_m2_iter_101, n_topics = 100, n_doc_passes = 5, seed_value = 201, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:42:36.379000] current iteration 102 / 200
# name = model_100_m2_iter_102, n_topics = 100, n_doc_passes = 5, seed_value = 202, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:42:59.829000] current iteration 103 / 200
# name = model_100_m2_iter_103, n_topics = 100, n_doc_passes = 5, seed_value = 203, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:43:23.365000] current iteration 104 / 200
# name = model_100_m2_iter_104, n_topics = 100, n_doc_passes = 5, seed_value = 204, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:43:46.828000] current iteration 105 / 200
# name = model_100_m2_iter_105, n_topics = 100, n_doc_passes = 5, seed_value = 205, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:44:10.301000] current iteration 106 / 200
# name = model_100_m2_iter_106, n_topics = 100, n_doc_passes = 5, seed_value = 206, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:44:33.896000] current iteration 107 / 200
# name = model_100_m2_iter_107, n_topics = 100, n_doc_passes = 5, seed_value = 207, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:44:57.507000] current iteration 108 / 200
# name = model_100_m2_iter_108, n_topics = 100, n_doc_passes = 5, seed_value = 208, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:45:21.185000] current iteration 109 / 200
# name = model_100_m2_iter_109, n_topics = 100, n_doc_passes = 5, seed_value = 209, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:45:44.711000] current iteration 110 / 200
# name = model_100_m2_iter_110, n_topics = 100, n_doc_passes = 5, seed_value = 210, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:46:08.114000] current iteration 111 / 200
# name = model_100_m2_iter_111, n_topics = 100, n_doc_passes = 5, seed_value = 211, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:46:31.683000] current iteration 112 / 200
# name = model_100_m2_iter_112, n_topics = 100, n_doc_passes = 5, seed_value = 212, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:46:55.267000] current iteration 113 / 200
# name = model_100_m2_iter_113, n_topics = 100, n_doc_passes = 5, seed_value = 213, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:47:18.691000] current iteration 114 / 200
# name = model_100_m2_iter_114, n_topics = 100, n_doc_passes = 5, seed_value = 214, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:47:42.356000] current iteration 115 / 200
# name = model_100_m2_iter_115, n_topics = 100, n_doc_passes = 5, seed_value = 215, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:48:06.162000] current iteration 116 / 200
# name = model_100_m2_iter_116, n_topics = 100, n_doc_passes = 5, seed_value = 216, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:48:29.812000] current iteration 117 / 200
# name = model_100_m2_iter_117, n_topics = 100, n_doc_passes = 5, seed_value = 217, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:48:53.478000] current iteration 118 / 200
# name = model_100_m2_iter_118, n_topics = 100, n_doc_passes = 5, seed_value = 218, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:49:17.115000] current iteration 119 / 200
# name = model_100_m2_iter_119, n_topics = 100, n_doc_passes = 5, seed_value = 219, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:49:40.699000] current iteration 120 / 200
# name = model_100_m2_iter_120, n_topics = 100, n_doc_passes = 5, seed_value = 220, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:50:04.295000] current iteration 121 / 200
# name = model_100_m2_iter_121, n_topics = 100, n_doc_passes = 5, seed_value = 221, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:50:27.889000] current iteration 122 / 200
# name = model_100_m2_iter_122, n_topics = 100, n_doc_passes = 5, seed_value = 222, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:50:51.595000] current iteration 123 / 200
# name = model_100_m2_iter_123, n_topics = 100, n_doc_passes = 5, seed_value = 223, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:51:15.109000] current iteration 124 / 200
# name = model_100_m2_iter_124, n_topics = 100, n_doc_passes = 5, seed_value = 224, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:51:38.831000] current iteration 125 / 200
# name = model_100_m2_iter_125, n_topics = 100, n_doc_passes = 5, seed_value = 225, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:52:02.489000] current iteration 126 / 200
# name = model_100_m2_iter_126, n_topics = 100, n_doc_passes = 5, seed_value = 226, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:52:25.924000] current iteration 127 / 200
# name = model_100_m2_iter_127, n_topics = 100, n_doc_passes = 5, seed_value = 227, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:52:49.454000] current iteration 128 / 200
# name = model_100_m2_iter_128, n_topics = 100, n_doc_passes = 5, seed_value = 228, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:53:13.080000] current iteration 129 / 200
# name = model_100_m2_iter_129, n_topics = 100, n_doc_passes = 5, seed_value = 229, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:53:36.703000] current iteration 130 / 200
# name = model_100_m2_iter_130, n_topics = 100, n_doc_passes = 5, seed_value = 230, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:54:00.388000] current iteration 131 / 200
# name = model_100_m2_iter_131, n_topics = 100, n_doc_passes = 5, seed_value = 231, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:54:23.869000] current iteration 132 / 200
# name = model_100_m2_iter_132, n_topics = 100, n_doc_passes = 5, seed_value = 232, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:54:47.423000] current iteration 133 / 200
# name = model_100_m2_iter_133, n_topics = 100, n_doc_passes = 5, seed_value = 233, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:55:10.890000] current iteration 134 / 200
# name = model_100_m2_iter_134, n_topics = 100, n_doc_passes = 5, seed_value = 234, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:55:34.557000] current iteration 135 / 200
# name = model_100_m2_iter_135, n_topics = 100, n_doc_passes = 5, seed_value = 235, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:55:58.021000] current iteration 136 / 200
# name = model_100_m2_iter_136, n_topics = 100, n_doc_passes = 5, seed_value = 236, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:56:21.546000] current iteration 137 / 200
# name = model_100_m2_iter_137, n_topics = 100, n_doc_passes = 5, seed_value = 237, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:56:45.015000] current iteration 138 / 200
# name = model_100_m2_iter_138, n_topics = 100, n_doc_passes = 5, seed_value = 238, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:57:08.491000] current iteration 139 / 200
# name = model_100_m2_iter_139, n_topics = 100, n_doc_passes = 5, seed_value = 239, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:57:32.058000] current iteration 140 / 200
# name = model_100_m2_iter_140, n_topics = 100, n_doc_passes = 5, seed_value = 240, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:57:55.678000] current iteration 141 / 200
# name = model_100_m2_iter_141, n_topics = 100, n_doc_passes = 5, seed_value = 241, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:58:19.325000] current iteration 142 / 200
# name = model_100_m2_iter_142, n_topics = 100, n_doc_passes = 5, seed_value = 242, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:58:42.839000] current iteration 143 / 200
# name = model_100_m2_iter_143, n_topics = 100, n_doc_passes = 5, seed_value = 243, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:59:06.537000] current iteration 144 / 200
# name = model_100_m2_iter_144, n_topics = 100, n_doc_passes = 5, seed_value = 244, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:59:30.078000] current iteration 145 / 200
# name = model_100_m2_iter_145, n_topics = 100, n_doc_passes = 5, seed_value = 245, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 11:59:53.706000] current iteration 146 / 200
# name = model_100_m2_iter_146, n_topics = 100, n_doc_passes = 5, seed_value = 246, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:00:17.325000] current iteration 147 / 200
# name = model_100_m2_iter_147, n_topics = 100, n_doc_passes = 5, seed_value = 247, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:00:40.763000] current iteration 148 / 200
# name = model_100_m2_iter_148, n_topics = 100, n_doc_passes = 5, seed_value = 248, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:01:04.392000] current iteration 149 / 200
# name = model_100_m2_iter_149, n_topics = 100, n_doc_passes = 5, seed_value = 249, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:01:28.138000] current iteration 150 / 200
# name = model_100_m2_iter_150, n_topics = 100, n_doc_passes = 5, seed_value = 250, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:01:51.678000] current iteration 151 / 200
# name = model_100_m2_iter_151, n_topics = 100, n_doc_passes = 5, seed_value = 251, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:02:15.156000] current iteration 152 / 200
# name = model_100_m2_iter_152, n_topics = 100, n_doc_passes = 5, seed_value = 252, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:02:38.827000] current iteration 153 / 200
# name = model_100_m2_iter_153, n_topics = 100, n_doc_passes = 5, seed_value = 253, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:03:02.426000] current iteration 154 / 200
# name = model_100_m2_iter_154, n_topics = 100, n_doc_passes = 5, seed_value = 254, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:03:26.030000] current iteration 155 / 200
# name = model_100_m2_iter_155, n_topics = 100, n_doc_passes = 5, seed_value = 255, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:03:49.461000] current iteration 156 / 200
# name = model_100_m2_iter_156, n_topics = 100, n_doc_passes = 5, seed_value = 256, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:04:12.901000] current iteration 157 / 200
# name = model_100_m2_iter_157, n_topics = 100, n_doc_passes = 5, seed_value = 257, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:04:36.517000] current iteration 158 / 200
# name = model_100_m2_iter_158, n_topics = 100, n_doc_passes = 5, seed_value = 258, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:05:00.218000] current iteration 159 / 200
# name = model_100_m2_iter_159, n_topics = 100, n_doc_passes = 5, seed_value = 259, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:05:23.738000] current iteration 160 / 200
# name = model_100_m2_iter_160, n_topics = 100, n_doc_passes = 5, seed_value = 260, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:05:47.413000] current iteration 161 / 200
# name = model_100_m2_iter_161, n_topics = 100, n_doc_passes = 5, seed_value = 261, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:06:11.056000] current iteration 162 / 200
# name = model_100_m2_iter_162, n_topics = 100, n_doc_passes = 5, seed_value = 262, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:06:34.466000] current iteration 163 / 200
# name = model_100_m2_iter_163, n_topics = 100, n_doc_passes = 5, seed_value = 263, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:06:57.944000] current iteration 164 / 200
# name = model_100_m2_iter_164, n_topics = 100, n_doc_passes = 5, seed_value = 264, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:07:21.519000] current iteration 165 / 200
# name = model_100_m2_iter_165, n_topics = 100, n_doc_passes = 5, seed_value = 265, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:07:45.081000] current iteration 166 / 200
# name = model_100_m2_iter_166, n_topics = 100, n_doc_passes = 5, seed_value = 266, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:08:08.638000] current iteration 167 / 200
# name = model_100_m2_iter_167, n_topics = 100, n_doc_passes = 5, seed_value = 267, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:08:32.371000] current iteration 168 / 200
# name = model_100_m2_iter_168, n_topics = 100, n_doc_passes = 5, seed_value = 268, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:08:55.974000] current iteration 169 / 200
# name = model_100_m2_iter_169, n_topics = 100, n_doc_passes = 5, seed_value = 269, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:09:19.589000] current iteration 170 / 200
# name = model_100_m2_iter_170, n_topics = 100, n_doc_passes = 5, seed_value = 270, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:09:43.122000] current iteration 171 / 200
# name = model_100_m2_iter_171, n_topics = 100, n_doc_passes = 5, seed_value = 271, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:10:06.738000] current iteration 172 / 200
# name = model_100_m2_iter_172, n_topics = 100, n_doc_passes = 5, seed_value = 272, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:10:30.442000] current iteration 173 / 200
# name = model_100_m2_iter_173, n_topics = 100, n_doc_passes = 5, seed_value = 273, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:10:54.125000] current iteration 174 / 200
# name = model_100_m2_iter_174, n_topics = 100, n_doc_passes = 5, seed_value = 274, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:11:17.705000] current iteration 175 / 200
# name = model_100_m2_iter_175, n_topics = 100, n_doc_passes = 5, seed_value = 275, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:11:41.296000] current iteration 176 / 200
# name = model_100_m2_iter_176, n_topics = 100, n_doc_passes = 5, seed_value = 276, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:12:04.837000] current iteration 177 / 200
# name = model_100_m2_iter_177, n_topics = 100, n_doc_passes = 5, seed_value = 277, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:12:28.260000] current iteration 178 / 200
# name = model_100_m2_iter_178, n_topics = 100, n_doc_passes = 5, seed_value = 278, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:12:51.873000] current iteration 179 / 200
# name = model_100_m2_iter_179, n_topics = 100, n_doc_passes = 5, seed_value = 279, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:13:15.388000] current iteration 180 / 200
# name = model_100_m2_iter_180, n_topics = 100, n_doc_passes = 5, seed_value = 280, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:13:38.887000] current iteration 181 / 200
# name = model_100_m2_iter_181, n_topics = 100, n_doc_passes = 5, seed_value = 281, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:14:02.364000] current iteration 182 / 200
# name = model_100_m2_iter_182, n_topics = 100, n_doc_passes = 5, seed_value = 282, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:14:25.770000] current iteration 183 / 200
# name = model_100_m2_iter_183, n_topics = 100, n_doc_passes = 5, seed_value = 283, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:14:49.328000] current iteration 184 / 200
# name = model_100_m2_iter_184, n_topics = 100, n_doc_passes = 5, seed_value = 284, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:15:12.966000] current iteration 185 / 200
# name = model_100_m2_iter_185, n_topics = 100, n_doc_passes = 5, seed_value = 285, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:15:36.455000] current iteration 186 / 200
# name = model_100_m2_iter_186, n_topics = 100, n_doc_passes = 5, seed_value = 286, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:16:00.035000] current iteration 187 / 200
# name = model_100_m2_iter_187, n_topics = 100, n_doc_passes = 5, seed_value = 287, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:16:23.712000] current iteration 188 / 200
# name = model_100_m2_iter_188, n_topics = 100, n_doc_passes = 5, seed_value = 288, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:16:47.305000] current iteration 189 / 200
# name = model_100_m2_iter_189, n_topics = 100, n_doc_passes = 5, seed_value = 289, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:17:10.994000] current iteration 190 / 200
# name = model_100_m2_iter_190, n_topics = 100, n_doc_passes = 5, seed_value = 290, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:17:34.675000] current iteration 191 / 200
# name = model_100_m2_iter_191, n_topics = 100, n_doc_passes = 5, seed_value = 291, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:17:58.130000] current iteration 192 / 200
# name = model_100_m2_iter_192, n_topics = 100, n_doc_passes = 5, seed_value = 292, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:18:21.774000] current iteration 193 / 200
# name = model_100_m2_iter_193, n_topics = 100, n_doc_passes = 5, seed_value = 293, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:18:45.420000] current iteration 194 / 200
# name = model_100_m2_iter_194, n_topics = 100, n_doc_passes = 5, seed_value = 294, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:19:09.113000] current iteration 195 / 200
# name = model_100_m2_iter_195, n_topics = 100, n_doc_passes = 5, seed_value = 295, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:19:32.715000] current iteration 196 / 200
# name = model_100_m2_iter_196, n_topics = 100, n_doc_passes = 5, seed_value = 296, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:19:56.478000] current iteration 197 / 200
# name = model_100_m2_iter_197, n_topics = 100, n_doc_passes = 5, seed_value = 297, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:20:19.942000] current iteration 198 / 200
# name = model_100_m2_iter_198, n_topics = 100, n_doc_passes = 5, seed_value = 298, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:20:43.339000] current iteration 199 / 200
# name = model_100_m2_iter_199, n_topics = 100, n_doc_passes = 5, seed_value = 299, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
#
# [2017-03-10 12:21:06.937000] current iteration 200 / 200

# %%
tmp_models_range = []
tmp_models_range = create_models_range(create_model_fn_4, 'model_100_m4', n_iterations=200)
# Out:
# name = model_20_m4_iter_0, n_topics = 100, n_doc_passes = 5, seed_value = 100, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:21:43.083000] current iteration 1 / 200
# name = model_20_m4_iter_1, n_topics = 100, n_doc_passes = 5, seed_value = 101, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:22:03.468000] current iteration 2 / 200
# name = model_20_m4_iter_2, n_topics = 100, n_doc_passes = 5, seed_value = 102, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:22:23.693000] current iteration 3 / 200
# name = model_20_m4_iter_3, n_topics = 100, n_doc_passes = 5, seed_value = 103, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:22:44.155000] current iteration 4 / 200
# name = model_20_m4_iter_4, n_topics = 100, n_doc_passes = 5, seed_value = 104, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:23:04.660000] current iteration 5 / 200
# name = model_20_m4_iter_5, n_topics = 100, n_doc_passes = 5, seed_value = 105, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:23:25.163000] current iteration 6 / 200
# name = model_20_m4_iter_6, n_topics = 100, n_doc_passes = 5, seed_value = 106, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:23:45.426000] current iteration 7 / 200
# name = model_20_m4_iter_7, n_topics = 100, n_doc_passes = 5, seed_value = 107, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:24:05.607000] current iteration 8 / 200
# name = model_20_m4_iter_8, n_topics = 100, n_doc_passes = 5, seed_value = 108, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:24:25.895000] current iteration 9 / 200
# name = model_20_m4_iter_9, n_topics = 100, n_doc_passes = 5, seed_value = 109, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:24:46.187000] current iteration 10 / 200
# name = model_20_m4_iter_10, n_topics = 100, n_doc_passes = 5, seed_value = 110, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:25:06.734000] current iteration 11 / 200
# name = model_20_m4_iter_11, n_topics = 100, n_doc_passes = 5, seed_value = 111, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:25:27.368000] current iteration 12 / 200
# name = model_20_m4_iter_12, n_topics = 100, n_doc_passes = 5, seed_value = 112, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:25:47.739000] current iteration 13 / 200
# name = model_20_m4_iter_13, n_topics = 100, n_doc_passes = 5, seed_value = 113, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:26:08.087000] current iteration 14 / 200
# name = model_20_m4_iter_14, n_topics = 100, n_doc_passes = 5, seed_value = 114, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:26:28.620000] current iteration 15 / 200
# name = model_20_m4_iter_15, n_topics = 100, n_doc_passes = 5, seed_value = 115, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:26:48.964000] current iteration 16 / 200
# name = model_20_m4_iter_16, n_topics = 100, n_doc_passes = 5, seed_value = 116, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:27:09.165000] current iteration 17 / 200
# name = model_20_m4_iter_17, n_topics = 100, n_doc_passes = 5, seed_value = 117, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:27:29.491000] current iteration 18 / 200
# name = model_20_m4_iter_18, n_topics = 100, n_doc_passes = 5, seed_value = 118, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:27:49.776000] current iteration 19 / 200
# name = model_20_m4_iter_19, n_topics = 100, n_doc_passes = 5, seed_value = 119, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:28:10.023000] current iteration 20 / 200
# name = model_20_m4_iter_20, n_topics = 100, n_doc_passes = 5, seed_value = 120, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:28:30.299000] current iteration 21 / 200
# name = model_20_m4_iter_21, n_topics = 100, n_doc_passes = 5, seed_value = 121, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:28:50.623000] current iteration 22 / 200
# name = model_20_m4_iter_22, n_topics = 100, n_doc_passes = 5, seed_value = 122, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:29:10.980000] current iteration 23 / 200
# name = model_20_m4_iter_23, n_topics = 100, n_doc_passes = 5, seed_value = 123, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:29:31.603000] current iteration 24 / 200
# name = model_20_m4_iter_24, n_topics = 100, n_doc_passes = 5, seed_value = 124, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:29:52.047000] current iteration 25 / 200
# name = model_20_m4_iter_25, n_topics = 100, n_doc_passes = 5, seed_value = 125, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:30:12.296000] current iteration 26 / 200
# name = model_20_m4_iter_26, n_topics = 100, n_doc_passes = 5, seed_value = 126, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:30:32.516000] current iteration 27 / 200
# name = model_20_m4_iter_27, n_topics = 100, n_doc_passes = 5, seed_value = 127, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:30:52.996000] current iteration 28 / 200
# name = model_20_m4_iter_28, n_topics = 100, n_doc_passes = 5, seed_value = 128, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:31:13.598000] current iteration 29 / 200
# name = model_20_m4_iter_29, n_topics = 100, n_doc_passes = 5, seed_value = 129, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:31:33.994000] current iteration 30 / 200
# name = model_20_m4_iter_30, n_topics = 100, n_doc_passes = 5, seed_value = 130, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:31:54.327000] current iteration 31 / 200
# name = model_20_m4_iter_31, n_topics = 100, n_doc_passes = 5, seed_value = 131, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:32:14.750000] current iteration 32 / 200
# name = model_20_m4_iter_32, n_topics = 100, n_doc_passes = 5, seed_value = 132, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:32:35.376000] current iteration 33 / 200
# name = model_20_m4_iter_33, n_topics = 100, n_doc_passes = 5, seed_value = 133, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:32:55.700000] current iteration 34 / 200
# name = model_20_m4_iter_34, n_topics = 100, n_doc_passes = 5, seed_value = 134, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:33:15.983000] current iteration 35 / 200
# name = model_20_m4_iter_35, n_topics = 100, n_doc_passes = 5, seed_value = 135, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:33:36.476000] current iteration 36 / 200
# name = model_20_m4_iter_36, n_topics = 100, n_doc_passes = 5, seed_value = 136, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:33:56.951000] current iteration 37 / 200
# name = model_20_m4_iter_37, n_topics = 100, n_doc_passes = 5, seed_value = 137, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:34:17.208000] current iteration 38 / 200
# name = model_20_m4_iter_38, n_topics = 100, n_doc_passes = 5, seed_value = 138, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:34:37.722000] current iteration 39 / 200
# name = model_20_m4_iter_39, n_topics = 100, n_doc_passes = 5, seed_value = 139, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:34:58.194000] current iteration 40 / 200
# name = model_20_m4_iter_40, n_topics = 100, n_doc_passes = 5, seed_value = 140, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:35:18.678000] current iteration 41 / 200
# name = model_20_m4_iter_41, n_topics = 100, n_doc_passes = 5, seed_value = 141, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:35:38.984000] current iteration 42 / 200
# name = model_20_m4_iter_42, n_topics = 100, n_doc_passes = 5, seed_value = 142, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:35:59.410000] current iteration 43 / 200
# name = model_20_m4_iter_43, n_topics = 100, n_doc_passes = 5, seed_value = 143, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:36:19.893000] current iteration 44 / 200
# name = model_20_m4_iter_44, n_topics = 100, n_doc_passes = 5, seed_value = 144, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:36:40.413000] current iteration 45 / 200
# name = model_20_m4_iter_45, n_topics = 100, n_doc_passes = 5, seed_value = 145, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:37:00.871000] current iteration 46 / 200
# name = model_20_m4_iter_46, n_topics = 100, n_doc_passes = 5, seed_value = 146, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:37:21.355000] current iteration 47 / 200
# name = model_20_m4_iter_47, n_topics = 100, n_doc_passes = 5, seed_value = 147, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:37:41.661000] current iteration 48 / 200
# name = model_20_m4_iter_48, n_topics = 100, n_doc_passes = 5, seed_value = 148, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:38:01.996000] current iteration 49 / 200
# name = model_20_m4_iter_49, n_topics = 100, n_doc_passes = 5, seed_value = 149, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:38:22.290000] current iteration 50 / 200
# name = model_20_m4_iter_50, n_topics = 100, n_doc_passes = 5, seed_value = 150, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:38:42.588000] current iteration 51 / 200
# name = model_20_m4_iter_51, n_topics = 100, n_doc_passes = 5, seed_value = 151, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:39:02.896000] current iteration 52 / 200
# name = model_20_m4_iter_52, n_topics = 100, n_doc_passes = 5, seed_value = 152, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:39:23.315000] current iteration 53 / 200
# name = model_20_m4_iter_53, n_topics = 100, n_doc_passes = 5, seed_value = 153, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:39:43.953000] current iteration 54 / 200
# name = model_20_m4_iter_54, n_topics = 100, n_doc_passes = 5, seed_value = 154, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:40:04.306000] current iteration 55 / 200
# name = model_20_m4_iter_55, n_topics = 100, n_doc_passes = 5, seed_value = 155, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:40:24.789000] current iteration 56 / 200
# name = model_20_m4_iter_56, n_topics = 100, n_doc_passes = 5, seed_value = 156, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:40:45.148000] current iteration 57 / 200
# name = model_20_m4_iter_57, n_topics = 100, n_doc_passes = 5, seed_value = 157, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:41:05.427000] current iteration 58 / 200
# name = model_20_m4_iter_58, n_topics = 100, n_doc_passes = 5, seed_value = 158, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:41:25.745000] current iteration 59 / 200
# name = model_20_m4_iter_59, n_topics = 100, n_doc_passes = 5, seed_value = 159, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:41:46.231000] current iteration 60 / 200
# name = model_20_m4_iter_60, n_topics = 100, n_doc_passes = 5, seed_value = 160, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:42:06.616000] current iteration 61 / 200
# name = model_20_m4_iter_61, n_topics = 100, n_doc_passes = 5, seed_value = 161, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:42:26.959000] current iteration 62 / 200
# name = model_20_m4_iter_62, n_topics = 100, n_doc_passes = 5, seed_value = 162, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:42:47.438000] current iteration 63 / 200
# name = model_20_m4_iter_63, n_topics = 100, n_doc_passes = 5, seed_value = 163, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:43:07.926000] current iteration 64 / 200
# name = model_20_m4_iter_64, n_topics = 100, n_doc_passes = 5, seed_value = 164, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:43:28.269000] current iteration 65 / 200
# name = model_20_m4_iter_65, n_topics = 100, n_doc_passes = 5, seed_value = 165, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:43:48.552000] current iteration 66 / 200
# name = model_20_m4_iter_66, n_topics = 100, n_doc_passes = 5, seed_value = 166, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:44:08.811000] current iteration 67 / 200
# name = model_20_m4_iter_67, n_topics = 100, n_doc_passes = 5, seed_value = 167, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:44:29.116000] current iteration 68 / 200
# name = model_20_m4_iter_68, n_topics = 100, n_doc_passes = 5, seed_value = 168, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:44:49.433000] current iteration 69 / 200
# name = model_20_m4_iter_69, n_topics = 100, n_doc_passes = 5, seed_value = 169, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:45:09.804000] current iteration 70 / 200
# name = model_20_m4_iter_70, n_topics = 100, n_doc_passes = 5, seed_value = 170, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:45:30.107000] current iteration 71 / 200
# name = model_20_m4_iter_71, n_topics = 100, n_doc_passes = 5, seed_value = 171, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:45:50.704000] current iteration 72 / 200
# name = model_20_m4_iter_72, n_topics = 100, n_doc_passes = 5, seed_value = 172, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:46:11.083000] current iteration 73 / 200
# name = model_20_m4_iter_73, n_topics = 100, n_doc_passes = 5, seed_value = 173, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:46:31.587000] current iteration 74 / 200
# name = model_20_m4_iter_74, n_topics = 100, n_doc_passes = 5, seed_value = 174, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:46:51.853000] current iteration 75 / 200
# name = model_20_m4_iter_75, n_topics = 100, n_doc_passes = 5, seed_value = 175, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:47:12.444000] current iteration 76 / 200
# name = model_20_m4_iter_76, n_topics = 100, n_doc_passes = 5, seed_value = 176, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:47:32.911000] current iteration 77 / 200
# name = model_20_m4_iter_77, n_topics = 100, n_doc_passes = 5, seed_value = 177, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:47:53.277000] current iteration 78 / 200
# name = model_20_m4_iter_78, n_topics = 100, n_doc_passes = 5, seed_value = 178, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:48:13.555000] current iteration 79 / 200
# name = model_20_m4_iter_79, n_topics = 100, n_doc_passes = 5, seed_value = 179, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:48:33.837000] current iteration 80 / 200
# name = model_20_m4_iter_80, n_topics = 100, n_doc_passes = 5, seed_value = 180, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:48:54.230000] current iteration 81 / 200
# name = model_20_m4_iter_81, n_topics = 100, n_doc_passes = 5, seed_value = 181, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:49:14.830000] current iteration 82 / 200
# name = model_20_m4_iter_82, n_topics = 100, n_doc_passes = 5, seed_value = 182, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:49:35.459000] current iteration 83 / 200
# name = model_20_m4_iter_83, n_topics = 100, n_doc_passes = 5, seed_value = 183, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:49:55.831000] current iteration 84 / 200
# name = model_20_m4_iter_84, n_topics = 100, n_doc_passes = 5, seed_value = 184, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:50:16.360000] current iteration 85 / 200
# name = model_20_m4_iter_85, n_topics = 100, n_doc_passes = 5, seed_value = 185, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:50:36.690000] current iteration 86 / 200
# name = model_20_m4_iter_86, n_topics = 100, n_doc_passes = 5, seed_value = 186, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:50:57.072000] current iteration 87 / 200
# name = model_20_m4_iter_87, n_topics = 100, n_doc_passes = 5, seed_value = 187, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:51:17.469000] current iteration 88 / 200
# name = model_20_m4_iter_88, n_topics = 100, n_doc_passes = 5, seed_value = 188, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:51:37.703000] current iteration 89 / 200
# name = model_20_m4_iter_89, n_topics = 100, n_doc_passes = 5, seed_value = 189, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:51:58.163000] current iteration 90 / 200
# name = model_20_m4_iter_90, n_topics = 100, n_doc_passes = 5, seed_value = 190, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:52:18.481000] current iteration 91 / 200
# name = model_20_m4_iter_91, n_topics = 100, n_doc_passes = 5, seed_value = 191, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:52:38.831000] current iteration 92 / 200
# name = model_20_m4_iter_92, n_topics = 100, n_doc_passes = 5, seed_value = 192, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:52:59.345000] current iteration 93 / 200
# name = model_20_m4_iter_93, n_topics = 100, n_doc_passes = 5, seed_value = 193, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:53:19.701000] current iteration 94 / 200
# name = model_20_m4_iter_94, n_topics = 100, n_doc_passes = 5, seed_value = 194, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:53:40.262000] current iteration 95 / 200
# name = model_20_m4_iter_95, n_topics = 100, n_doc_passes = 5, seed_value = 195, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:54:00.588000] current iteration 96 / 200
# name = model_20_m4_iter_96, n_topics = 100, n_doc_passes = 5, seed_value = 196, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:54:20.921000] current iteration 97 / 200
# name = model_20_m4_iter_97, n_topics = 100, n_doc_passes = 5, seed_value = 197, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:54:41.272000] current iteration 98 / 200
# name = model_20_m4_iter_98, n_topics = 100, n_doc_passes = 5, seed_value = 198, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:55:01.654000] current iteration 99 / 200
# name = model_20_m4_iter_99, n_topics = 100, n_doc_passes = 5, seed_value = 199, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:55:22.061000] current iteration 100 / 200
# name = model_20_m4_iter_100, n_topics = 100, n_doc_passes = 5, seed_value = 200, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:55:42.334000] current iteration 101 / 200
# name = model_20_m4_iter_101, n_topics = 100, n_doc_passes = 5, seed_value = 201, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:56:02.639000] current iteration 102 / 200
# name = model_20_m4_iter_102, n_topics = 100, n_doc_passes = 5, seed_value = 202, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:56:23.036000] current iteration 103 / 200
# name = model_20_m4_iter_103, n_topics = 100, n_doc_passes = 5, seed_value = 203, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:56:43.418000] current iteration 104 / 200
# name = model_20_m4_iter_104, n_topics = 100, n_doc_passes = 5, seed_value = 204, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:57:03.809000] current iteration 105 / 200
# name = model_20_m4_iter_105, n_topics = 100, n_doc_passes = 5, seed_value = 205, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:57:24.161000] current iteration 106 / 200
# name = model_20_m4_iter_106, n_topics = 100, n_doc_passes = 5, seed_value = 206, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:57:44.395000] current iteration 107 / 200
# name = model_20_m4_iter_107, n_topics = 100, n_doc_passes = 5, seed_value = 207, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:58:04.699000] current iteration 108 / 200
# name = model_20_m4_iter_108, n_topics = 100, n_doc_passes = 5, seed_value = 208, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:58:25.014000] current iteration 109 / 200
# name = model_20_m4_iter_109, n_topics = 100, n_doc_passes = 5, seed_value = 209, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:58:45.269000] current iteration 110 / 200
# name = model_20_m4_iter_110, n_topics = 100, n_doc_passes = 5, seed_value = 210, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:59:05.538000] current iteration 111 / 200
# name = model_20_m4_iter_111, n_topics = 100, n_doc_passes = 5, seed_value = 211, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:59:25.859000] current iteration 112 / 200
# name = model_20_m4_iter_112, n_topics = 100, n_doc_passes = 5, seed_value = 212, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 12:59:46.165000] current iteration 113 / 200
# name = model_20_m4_iter_113, n_topics = 100, n_doc_passes = 5, seed_value = 213, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:00:06.517000] current iteration 114 / 200
# name = model_20_m4_iter_114, n_topics = 100, n_doc_passes = 5, seed_value = 214, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:00:26.853000] current iteration 115 / 200
# name = model_20_m4_iter_115, n_topics = 100, n_doc_passes = 5, seed_value = 215, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:00:47.177000] current iteration 116 / 200
# name = model_20_m4_iter_116, n_topics = 100, n_doc_passes = 5, seed_value = 216, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:01:07.458000] current iteration 117 / 200
# name = model_20_m4_iter_117, n_topics = 100, n_doc_passes = 5, seed_value = 217, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:01:27.962000] current iteration 118 / 200
# name = model_20_m4_iter_118, n_topics = 100, n_doc_passes = 5, seed_value = 218, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:01:48.277000] current iteration 119 / 200
# name = model_20_m4_iter_119, n_topics = 100, n_doc_passes = 5, seed_value = 219, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:02:08.909000] current iteration 120 / 200
# name = model_20_m4_iter_120, n_topics = 100, n_doc_passes = 5, seed_value = 220, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:02:29.499000] current iteration 121 / 200
# name = model_20_m4_iter_121, n_topics = 100, n_doc_passes = 5, seed_value = 221, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:02:49.900000] current iteration 122 / 200
# name = model_20_m4_iter_122, n_topics = 100, n_doc_passes = 5, seed_value = 222, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:03:10.330000] current iteration 123 / 200
# name = model_20_m4_iter_123, n_topics = 100, n_doc_passes = 5, seed_value = 223, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:03:30.885000] current iteration 124 / 200
# name = model_20_m4_iter_124, n_topics = 100, n_doc_passes = 5, seed_value = 224, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:03:51.287000] current iteration 125 / 200
# name = model_20_m4_iter_125, n_topics = 100, n_doc_passes = 5, seed_value = 225, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:04:11.812000] current iteration 126 / 200
# name = model_20_m4_iter_126, n_topics = 100, n_doc_passes = 5, seed_value = 226, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:04:32.213000] current iteration 127 / 200
# name = model_20_m4_iter_127, n_topics = 100, n_doc_passes = 5, seed_value = 227, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:04:52.524000] current iteration 128 / 200
# name = model_20_m4_iter_128, n_topics = 100, n_doc_passes = 5, seed_value = 228, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:05:13.075000] current iteration 129 / 200
# name = model_20_m4_iter_129, n_topics = 100, n_doc_passes = 5, seed_value = 229, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:05:33.535000] current iteration 130 / 200
# name = model_20_m4_iter_130, n_topics = 100, n_doc_passes = 5, seed_value = 230, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:05:53.815000] current iteration 131 / 200
# name = model_20_m4_iter_131, n_topics = 100, n_doc_passes = 5, seed_value = 231, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:06:14.106000] current iteration 132 / 200
# name = model_20_m4_iter_132, n_topics = 100, n_doc_passes = 5, seed_value = 232, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:06:34.511000] current iteration 133 / 200
# name = model_20_m4_iter_133, n_topics = 100, n_doc_passes = 5, seed_value = 233, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:06:54.908000] current iteration 134 / 200
# name = model_20_m4_iter_134, n_topics = 100, n_doc_passes = 5, seed_value = 234, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:07:15.363000] current iteration 135 / 200
# name = model_20_m4_iter_135, n_topics = 100, n_doc_passes = 5, seed_value = 235, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:07:35.913000] current iteration 136 / 200
# name = model_20_m4_iter_136, n_topics = 100, n_doc_passes = 5, seed_value = 236, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:07:56.370000] current iteration 137 / 200
# name = model_20_m4_iter_137, n_topics = 100, n_doc_passes = 5, seed_value = 237, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:08:16.621000] current iteration 138 / 200
# name = model_20_m4_iter_138, n_topics = 100, n_doc_passes = 5, seed_value = 238, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:08:36.905000] current iteration 139 / 200
# name = model_20_m4_iter_139, n_topics = 100, n_doc_passes = 5, seed_value = 239, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:08:57.481000] current iteration 140 / 200
# name = model_20_m4_iter_140, n_topics = 100, n_doc_passes = 5, seed_value = 240, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:09:18.054000] current iteration 141 / 200
# name = model_20_m4_iter_141, n_topics = 100, n_doc_passes = 5, seed_value = 241, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:09:38.356000] current iteration 142 / 200
# name = model_20_m4_iter_142, n_topics = 100, n_doc_passes = 5, seed_value = 242, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:09:58.700000] current iteration 143 / 200
# name = model_20_m4_iter_143, n_topics = 100, n_doc_passes = 5, seed_value = 243, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:10:19.029000] current iteration 144 / 200
# name = model_20_m4_iter_144, n_topics = 100, n_doc_passes = 5, seed_value = 244, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:10:39.356000] current iteration 145 / 200
# name = model_20_m4_iter_145, n_topics = 100, n_doc_passes = 5, seed_value = 245, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:10:59.628000] current iteration 146 / 200
# name = model_20_m4_iter_146, n_topics = 100, n_doc_passes = 5, seed_value = 246, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:11:20.173000] current iteration 147 / 200
# name = model_20_m4_iter_147, n_topics = 100, n_doc_passes = 5, seed_value = 247, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:11:40.657000] current iteration 148 / 200
# name = model_20_m4_iter_148, n_topics = 100, n_doc_passes = 5, seed_value = 248, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:12:01.086000] current iteration 149 / 200
# name = model_20_m4_iter_149, n_topics = 100, n_doc_passes = 5, seed_value = 249, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:12:21.434000] current iteration 150 / 200
# name = model_20_m4_iter_150, n_topics = 100, n_doc_passes = 5, seed_value = 250, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:12:41.736000] current iteration 151 / 200
# name = model_20_m4_iter_151, n_topics = 100, n_doc_passes = 5, seed_value = 251, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:13:02.162000] current iteration 152 / 200
# name = model_20_m4_iter_152, n_topics = 100, n_doc_passes = 5, seed_value = 252, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:13:22.801000] current iteration 153 / 200
# name = model_20_m4_iter_153, n_topics = 100, n_doc_passes = 5, seed_value = 253, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:13:43.325000] current iteration 154 / 200
# name = model_20_m4_iter_154, n_topics = 100, n_doc_passes = 5, seed_value = 254, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:14:03.633000] current iteration 155 / 200
# name = model_20_m4_iter_155, n_topics = 100, n_doc_passes = 5, seed_value = 255, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:14:23.998000] current iteration 156 / 200
# name = model_20_m4_iter_156, n_topics = 100, n_doc_passes = 5, seed_value = 256, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:14:44.261000] current iteration 157 / 200
# name = model_20_m4_iter_157, n_topics = 100, n_doc_passes = 5, seed_value = 257, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:15:04.645000] current iteration 158 / 200
# name = model_20_m4_iter_158, n_topics = 100, n_doc_passes = 5, seed_value = 258, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:15:25.276000] current iteration 159 / 200
# name = model_20_m4_iter_159, n_topics = 100, n_doc_passes = 5, seed_value = 259, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:15:45.566000] current iteration 160 / 200
# name = model_20_m4_iter_160, n_topics = 100, n_doc_passes = 5, seed_value = 260, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:16:05.836000] current iteration 161 / 200
# name = model_20_m4_iter_161, n_topics = 100, n_doc_passes = 5, seed_value = 261, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:16:26.149000] current iteration 162 / 200
# name = model_20_m4_iter_162, n_topics = 100, n_doc_passes = 5, seed_value = 262, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:16:46.795000] current iteration 163 / 200
# name = model_20_m4_iter_163, n_topics = 100, n_doc_passes = 5, seed_value = 263, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:17:07.018000] current iteration 164 / 200
# name = model_20_m4_iter_164, n_topics = 100, n_doc_passes = 5, seed_value = 264, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:17:27.404000] current iteration 165 / 200
# name = model_20_m4_iter_165, n_topics = 100, n_doc_passes = 5, seed_value = 265, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:17:47.719000] current iteration 166 / 200
# name = model_20_m4_iter_166, n_topics = 100, n_doc_passes = 5, seed_value = 266, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:18:07.948000] current iteration 167 / 200
# name = model_20_m4_iter_167, n_topics = 100, n_doc_passes = 5, seed_value = 267, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:18:28.361000] current iteration 168 / 200
# name = model_20_m4_iter_168, n_topics = 100, n_doc_passes = 5, seed_value = 268, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:18:48.977000] current iteration 169 / 200
# name = model_20_m4_iter_169, n_topics = 100, n_doc_passes = 5, seed_value = 269, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:19:09.257000] current iteration 170 / 200
# name = model_20_m4_iter_170, n_topics = 100, n_doc_passes = 5, seed_value = 270, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:19:29.824000] current iteration 171 / 200
# name = model_20_m4_iter_171, n_topics = 100, n_doc_passes = 5, seed_value = 271, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:19:50.357000] current iteration 172 / 200
# name = model_20_m4_iter_172, n_topics = 100, n_doc_passes = 5, seed_value = 272, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:20:10.634000] current iteration 173 / 200
# name = model_20_m4_iter_173, n_topics = 100, n_doc_passes = 5, seed_value = 273, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:20:30.963000] current iteration 174 / 200
# name = model_20_m4_iter_174, n_topics = 100, n_doc_passes = 5, seed_value = 274, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:20:51.278000] current iteration 175 / 200
# name = model_20_m4_iter_175, n_topics = 100, n_doc_passes = 5, seed_value = 275, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:21:11.547000] current iteration 176 / 200
# name = model_20_m4_iter_176, n_topics = 100, n_doc_passes = 5, seed_value = 276, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:21:31.956000] current iteration 177 / 200
# name = model_20_m4_iter_177, n_topics = 100, n_doc_passes = 5, seed_value = 277, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:21:52.285000] current iteration 178 / 200
# name = model_20_m4_iter_178, n_topics = 100, n_doc_passes = 5, seed_value = 278, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:22:12.521000] current iteration 179 / 200
# name = model_20_m4_iter_179, n_topics = 100, n_doc_passes = 5, seed_value = 279, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:22:32.940000] current iteration 180 / 200
# name = model_20_m4_iter_180, n_topics = 100, n_doc_passes = 5, seed_value = 280, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:22:53.427000] current iteration 181 / 200
# name = model_20_m4_iter_181, n_topics = 100, n_doc_passes = 5, seed_value = 281, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:23:13.816000] current iteration 182 / 200
# name = model_20_m4_iter_182, n_topics = 100, n_doc_passes = 5, seed_value = 282, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:23:34.314000] current iteration 183 / 200
# name = model_20_m4_iter_183, n_topics = 100, n_doc_passes = 5, seed_value = 283, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:23:54.745000] current iteration 184 / 200
# name = model_20_m4_iter_184, n_topics = 100, n_doc_passes = 5, seed_value = 284, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:24:15.146000] current iteration 185 / 200
# name = model_20_m4_iter_185, n_topics = 100, n_doc_passes = 5, seed_value = 285, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:24:35.722000] current iteration 186 / 200
# name = model_20_m4_iter_186, n_topics = 100, n_doc_passes = 5, seed_value = 286, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:24:56.298000] current iteration 187 / 200
# name = model_20_m4_iter_187, n_topics = 100, n_doc_passes = 5, seed_value = 287, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:25:16.788000] current iteration 188 / 200
# name = model_20_m4_iter_188, n_topics = 100, n_doc_passes = 5, seed_value = 288, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:25:37.203000] current iteration 189 / 200
# name = model_20_m4_iter_189, n_topics = 100, n_doc_passes = 5, seed_value = 289, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:25:57.585000] current iteration 190 / 200
# name = model_20_m4_iter_190, n_topics = 100, n_doc_passes = 5, seed_value = 290, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:26:17.863000] current iteration 191 / 200
# name = model_20_m4_iter_191, n_topics = 100, n_doc_passes = 5, seed_value = 291, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:26:38.195000] current iteration 192 / 200
# name = model_20_m4_iter_192, n_topics = 100, n_doc_passes = 5, seed_value = 292, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:26:58.657000] current iteration 193 / 200
# name = model_20_m4_iter_193, n_topics = 100, n_doc_passes = 5, seed_value = 293, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:27:19.139000] current iteration 194 / 200
# name = model_20_m4_iter_194, n_topics = 100, n_doc_passes = 5, seed_value = 294, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:27:39.520000] current iteration 195 / 200
# name = model_20_m4_iter_195, n_topics = 100, n_doc_passes = 5, seed_value = 295, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:28:00.170000] current iteration 196 / 200
# name = model_20_m4_iter_196, n_topics = 100, n_doc_passes = 5, seed_value = 296, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:28:20.606000] current iteration 197 / 200
# name = model_20_m4_iter_197, n_topics = 100, n_doc_passes = 5, seed_value = 297, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:28:41.149000] current iteration 198 / 200
# name = model_20_m4_iter_198, n_topics = 100, n_doc_passes = 5, seed_value = 298, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:29:01.522000] current iteration 199 / 200
# name = model_20_m4_iter_199, n_topics = 100, n_doc_passes = 5, seed_value = 299, n_iterations = 20, top_tokens_score = 15, topic_kernel_score = 0.25
# ss_theta_regularizer, tau = -0.5
# decorrelator_phi_regularizer, tau = 10
# ss_phi_regularizer, tau = -2
#
# [2017-03-10 13:29:21.843000] current iteration 200 / 200
